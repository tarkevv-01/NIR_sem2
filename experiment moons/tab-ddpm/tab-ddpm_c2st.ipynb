# %%
# !pip install numpy==1.24.4 --force-reinstall --no-deps
# !pip install scipy==1.10.1 --force-reinstall

# !pip install --upgrade torch torchvision torchaudio

# !pip install networkx==2.8.8 --force-reinstall

# !pip install scikit-learn==1.4.2 --force-reinstall

# !pip install synthcity==0.2.12
# !pip install opacus==1.4.0

# !pip install hyperopt==0.2.7
# !pip install xgboost==2.0.3

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from synthcity.plugins import Plugins
from synthcity.plugins.generic.plugin_ddpm import TabDDPMPlugin as DDPM
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm

# %%
dir_datasets = '/kaggle/input/nir-sem02-moons/data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'moons_dataset.csv')

# Словарь датасетов для удобства
datasets = {
    'two_moons': {
                    "data": real_data_1,
                    "task": "regression",
                    "target": "x2",
                    "num_columns":
                    ["x1"],
                    "cat_columns":
                    []
                },
}


for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print()
# Out:
#  Информация о датасете two_moons:
#  Количество строк: 3000
#  Количество колонок: 2
#  Колонки: ['x1', 'x2']
#  Задача: regression
#  Целевая переменная: x2
#  Числовые признаки: ['x1']

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
# Определение пространства поиска гиперпараметров для DDPM
ddpm_space = {
    'batch_size': hp.choice('batch_size', [256, 4096]),
    'lr': hp.qloguniform('lr', np.log(1e-4), np.log(1e-3), 1e-5),
    'num_timesteps': hp.choice('num_timesteps', [1000]),
    'n_layers_hidden': hp.choice('n_layers_hidden', [2, 4, 6, 8]),
    'n_units_hidden': hp.choice('n_units_hidden', [128, 256, 512, 1024]),
    'n_iter': hp.choice('n_iter', [20000]),
    'transformation_num_type': hp.choice('transformation_num_type', ['None']),
    'transformation_cat_type': hp.choice('transformation_cat_type', ['None'])
}

# %%
def evaluate_c2st(real, synthetic):
    real_copy = real.copy()
    if hasattr(synthetic, "dataframe"):
        synthetic = synthetic.dataframe()

    synthetic_copy = synthetic.copy()

    # Добавление меток
    real_copy['label'] = 1
    synthetic_copy['label'] = 0

    # Объединение данных
    df = pd.concat([real_copy, synthetic_copy], ignore_index=True)

    # Определение категориальных колонок
    categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()
    categorical_columns = [col for col in categorical_columns if col != 'label']

    # Label Encoding для категориальных признаков
    for col in categorical_columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))

    # Разделение на признаки и метки
    X = df.drop(columns='label')
    y = df['label']

    # Разделение на обучающую и тестовую выборки
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y, random_state=RANDOM_SEED
    )
    # Обучение XGBoost
    clf = XGBClassifier(
        random_state=RANDOM_SEED
    )
    clf.fit(X_train, y_train)

    # Предсказания
    y_pred_proba = clf.predict_proba(X_test)[:, 1]

    return roc_auc_score(y_test, y_pred_proba)

# %%
import sys
import os
import builtins
import contextlib

@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        old_print = builtins.print
        builtins.print = lambda *args, **kwargs: None
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr
            builtins.print = old_print

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    data = process_data(dataset_info['data'], dataset_info['num_columns'], params['transformation_num_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    c2st_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        # Создание и обучение DDPM с заданными параметрами
        ddpm = DDPM(
            lr=params['lr'],
            num_timesteps=params['num_timesteps'],
            model_params = dict(n_layers_hidden=params['n_layers_hidden'],
                                n_units_hidden=params['n_units_hidden'],
                                dropout=0.0),
            batch_size=params['batch_size'],
            #n_iter=params['n_iter']
        )
        # Обучение модели на реальных данных
        with suppress_all_output():
          ddpm.fit(train_data)

        # Генерация синтетических данных
        synthetic_data = ddpm.generate(len(test_data))


        score = evaluate_c2st(test_data, synthetic_data)
        c2st_scores.append(score)

    return np.mean(c2st_scores)

# %%
from hyperopt import space_eval

def optimize_dataset(dataset_name, dataset, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")
    trials = Trials()
    
    def objective(params):
        print("="*50)
        c2st_score = generate_and_evaluate(params, dataset)
        print(c2st_score)
        print(params)
        print("="*50)
        return {
            'loss': c2st_score,
            'status': STATUS_OK,
            'c2st_score': c2st_score
        }
    
    rng = np.random.default_rng(RANDOM_SEED)
    best = fmin(
        fn=objective,
        space=ddpm_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )
    
    # Автоматическое декодирование параметров
    best_params = space_eval(ddpm_space, best)
    
    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_c2st = best_trial['result'].get('c2st_score', None)
    
    results = {
        'best_params': best_params,
        'best_c2st': best_c2st,
        'c2st_diff_from_optimal': best_trial['result']['loss']
    }
    
    print(f"Лучший C2ST для {dataset_name}: {best_c2st}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)
    
    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 100

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: two_moons
# ==================================================
# 0.5307481481481481
# {'batch_size': 256, 'lr': 0.00042, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5190592592592593
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6554481481481481
# {'batch_size': 256, 'lr': 0.00012000000000000002, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5637222222222221
# {'batch_size': 4096, 'lr': 0.00016, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5456907407407408
# {'batch_size': 256, 'lr': 0.00012000000000000002, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5591555555555555
# {'batch_size': 4096, 'lr': 0.00014000000000000001, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5308555555555556
# {'batch_size': 256, 'lr': 0.00099, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5250981481481481
# {'batch_size': 256, 'lr': 0.00068, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5163333333333333
# {'batch_size': 256, 'lr': 0.00059, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.543561111111111
# {'batch_size': 4096, 'lr': 0.00030000000000000003, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7617722222222222
# {'batch_size': 4096, 'lr': 0.00011, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5305833333333334
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5405129629629629
# {'batch_size': 256, 'lr': 0.00054, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6018444444444445
# {'batch_size': 4096, 'lr': 0.00029, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5362425925925927
# {'batch_size': 256, 'lr': 0.0008, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5438203703703705
# {'batch_size': 256, 'lr': 0.00097, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5297092592592593
# {'batch_size': 256, 'lr': 0.0006500000000000001, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5732055555555555
# {'batch_size': 4096, 'lr': 0.00013000000000000002, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5337851851851851
# {'batch_size': 256, 'lr': 0.00071, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5375388888888889
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5305574074074074
# {'batch_size': 4096, 'lr': 0.00022, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5259962962962963
# {'batch_size': 4096, 'lr': 0.00039000000000000005, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5497518518518518
# {'batch_size': 256, 'lr': 0.00021, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5208370370370371
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5391166666666667
# {'batch_size': 256, 'lr': 0.00036, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5368314814814815
# {'batch_size': 4096, 'lr': 0.00084, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5358481481481482
# {'batch_size': 256, 'lr': 0.00025, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5457074074074074
# {'batch_size': 4096, 'lr': 0.00047000000000000004, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5278574074074074
# {'batch_size': 256, 'lr': 0.0006000000000000001, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6027148148148148
# {'batch_size': 4096, 'lr': 0.00033000000000000005, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5208925925925926
# {'batch_size': 256, 'lr': 0.00045000000000000004, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5327222222222222
# {'batch_size': 256, 'lr': 0.00018, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6350370370370371
# {'batch_size': 4096, 'lr': 0.00026000000000000003, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5371092592592591
# {'batch_size': 256, 'lr': 0.00035000000000000005, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5287555555555555
# {'batch_size': 4096, 'lr': 0.00076, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5370537037037036
# {'batch_size': 256, 'lr': 0.0006000000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5403851851851852
# {'batch_size': 4096, 'lr': 0.0009500000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5349500000000001
# {'batch_size': 256, 'lr': 0.00044, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5274907407407408
# {'batch_size': 4096, 'lr': 0.0008500000000000001, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5457148148148149
# {'batch_size': 256, 'lr': 0.00017, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5345777777777778
# {'batch_size': 4096, 'lr': 0.00038, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5372925925925925
# {'batch_size': 256, 'lr': 0.00028000000000000003, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.654988888888889
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5444
# {'batch_size': 256, 'lr': 0.0005700000000000001, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.53425
# {'batch_size': 4096, 'lr': 0.00031, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5249518518518519
# {'batch_size': 256, 'lr': 0.0006600000000000001, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7530333333333333
# {'batch_size': 4096, 'lr': 0.0001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5243777777777777
# {'batch_size': 256, 'lr': 0.00042, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5596666666666666
# {'batch_size': 4096, 'lr': 0.00015000000000000001, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5497518518518518
# {'batch_size': 256, 'lr': 0.00021, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5407666666666667
# {'batch_size': 4096, 'lr': 0.0007300000000000001, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5328648148148147
# {'batch_size': 256, 'lr': 0.0008900000000000001, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5337259259259259
# {'batch_size': 4096, 'lr': 0.00062, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5257407407407407
# {'batch_size': 256, 'lr': 0.00025, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5243685185185185
# {'batch_size': 4096, 'lr': 0.00054, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.53415
# {'batch_size': 256, 'lr': 0.00034, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5307000000000001
# {'batch_size': 4096, 'lr': 0.001, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5369018518518519
# {'batch_size': 256, 'lr': 0.00039000000000000005, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.547637037037037
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5300592592592593
# {'batch_size': 256, 'lr': 0.0007700000000000001, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5463537037037037
# {'batch_size': 4096, 'lr': 0.00028000000000000003, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5392944444444445
# {'batch_size': 256, 'lr': 0.0006900000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5320518518518518
# {'batch_size': 4096, 'lr': 0.00019, 'n_iter': 20000, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6554481481481481
# {'batch_size': 256, 'lr': 0.00012000000000000002, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5193074074074074
# {'batch_size': 4096, 'lr': 0.00030000000000000003, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5287203703703703
# {'batch_size': 4096, 'lr': 0.00023, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5165333333333333
# {'batch_size': 4096, 'lr': 0.00036, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5350222222222222
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5230018518518519
# {'batch_size': 4096, 'lr': 0.00037000000000000005, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5230314814814815
# {'batch_size': 4096, 'lr': 0.00032, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5113037037037036
# {'batch_size': 4096, 'lr': 0.0004, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5418388888888889
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5349351851851852
# {'batch_size': 4096, 'lr': 0.00048000000000000007, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5137722222222223
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5445833333333333
# {'batch_size': 4096, 'lr': 0.0005300000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5384481481481481
# {'batch_size': 4096, 'lr': 0.00063, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5349203703703703
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5454722222222221
# {'batch_size': 4096, 'lr': 0.00046, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5366759259259258
# {'batch_size': 256, 'lr': 0.0008500000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.528762962962963
# {'batch_size': 4096, 'lr': 0.00093, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 128, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5351037037037037
# {'batch_size': 256, 'lr': 0.00051, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5611333333333334
# {'batch_size': 4096, 'lr': 0.00058, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5152129629629629
# {'batch_size': 256, 'lr': 0.00072, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5337240740740742
# {'batch_size': 256, 'lr': 0.00079, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5384944444444444
# {'batch_size': 4096, 'lr': 0.00072, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5394
# {'batch_size': 256, 'lr': 0.00063, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5425925925925926
# {'batch_size': 4096, 'lr': 0.00034, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5264462962962962
# {'batch_size': 4096, 'lr': 0.0004, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5391574074074074
# {'batch_size': 256, 'lr': 0.00068, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5412814814814815
# {'batch_size': 4096, 'lr': 0.0008100000000000001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5416703703703704
# {'batch_size': 256, 'lr': 0.0009000000000000001, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5344000000000001
# {'batch_size': 4096, 'lr': 0.00045000000000000004, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.525687037037037
# {'batch_size': 256, 'lr': 0.00075, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5319166666666667
# {'batch_size': 4096, 'lr': 0.00055, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5354185185185186
# {'batch_size': 256, 'lr': 0.0005, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5292333333333333
# {'batch_size': 4096, 'lr': 0.00026000000000000003, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5468092592592594
# {'batch_size': 4096, 'lr': 0.00059, 'n_iter': 20000, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5215296296296297
# {'batch_size': 256, 'lr': 0.001, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5686537037037037
# {'batch_size': 4096, 'lr': 0.00013000000000000002, 'n_iter': 20000, 'n_layers_hidden': 8, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5320407407407407
# {'batch_size': 256, 'lr': 0.00067, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# ==================================================
# 100%|██████████| 100/100 [3:37:14<00:00, 130.34s/trial, best loss: 0.5113037037037036]
# Лучший C2ST для two_moons: 0.5113037037037036
# Лучшие параметры: {'batch_size': 4096, 'lr': 0.0004, 'n_iter': 20000, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_cat_type': 'None', 'transformation_num_type': 'None'}
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_c2st'])
# Out:
# two_moons 0.5113037037037036
