# %%
# !pip install sdv
# !pip install sdmetrics

# %%
# !unrar x data.rar

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from hyperopt import space_eval
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
from sklearn.metrics import f1_score, r2_score
from xgboost import XGBClassifier, XGBRegressor
from sdmetrics.reports.single_table import QualityReport
#from sdmetrics.metadata import SingleTableMetadata
import pandas as pd

# %%
dir_datasets = '/kaggle/input/nir-sem02-moons/data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'moons_dataset.csv')

# Словарь датасетов для удобства
datasets = {
    'two_moons': {
                    "data": real_data_1,
                    "task": "regression",
                    "target": "x2",
                    "num_columns":
                    ["x1"],
                    "cat_columns":
                    []
                },
}


for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f"Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете two_moons:
#  Количество строк: 3000
#  Количество колонок: 2
#  Колонки: ['x1', 'x2']
#  Задача: regression
#  Целевая переменная: x2
#  Числовые признаки: ['x1']
# Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    # Learning rates
    'discriminator_lr': hp.qloguniform('discriminator_lr',
                                                 np.log(5e-5), np.log(1e-2), 5e-5),
    'generator_lr': hp.qloguniform('generator_lr',
                                             np.log(5e-5), np.log(1e-2), 5e-5),

    # Batch size
    'batch_size': hp.choice('batch_size', [50, 100, 250, 500, 1000]),

    # Embedding dimensions
    'embedding_dim': hp.choice('embedding_dim', [32, 64, 128, 256]),

    # Network architecture
    'generator_dim': hp.choice('generator_dim', [[128, 128], [128, 128, 128], [128, 128, 128, 128],
                                                [256, 256], [256, 256, 256], [256, 256, 256, 256]]),
    'discriminator_dim': hp.choice('discriminator_dim', [[256, 256], [256, 256, 256],
                                                        [128, 128], [128, 128, 128]]),

    # Decay parameters
    'generator_decay': hp.qloguniform('generator_decay',
                                     np.log(1e-6), np.log(1e-5), 1e-6),
    'discriminator_decay': hp.qloguniform('discriminator_decay',
                                         np.log(1e-6), np.log(1e-5), 1e-6),

    # Frequency
    'log_frequency': hp.choice('log_frequency', [False, True]),
    'transformation_num_type': hp.choice('transformation_num_type', ['CDF', 'PLE_CDF']),
    'transformation_cat_type': hp.choice('transformation_cat_type', ['OHE']),
    'epochs': hp.choice('epochs', [400]),

}

# %%
def evaluate_shape(real_data, synthetic_data, cat_columns):
    """
    Прямое использование метрик SDMetrics без QualityReport.
    Для случаев, когда QualityReport не работает.
    """
    # Подавляем предупреждения SciPy для KS-теста
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore", message="ks_2samp: Exact calculation unsuccessful")

        # Обработка входных данных
        if hasattr(synthetic_data, "dataframe"):
            synthetic = synthetic_data.dataframe()
        else:
            synthetic = synthetic_data.copy()

        real_data = pd.get_dummies(real_data, columns=cat_columns, drop_first=True)
        synthetic = pd.get_dummies(synthetic, columns=cat_columns, drop_first=True)

        # После get_dummies
        real_data = real_data.astype(float)
        synthetic = synthetic.astype(float)

        # Пытаемся использовать прямые метрики
        shape_scores = []

        from sdmetrics.single_column import KSComplement

        for column in real_data.select_dtypes(include=['number']).columns:
            if column in synthetic.columns:
                try:
                    # Проверяем, есть ли достаточно данных и вариативность
                    real_col = real_data[column].dropna()
                    synth_col = synthetic[column].dropna()

                    if len(real_col) > 0 and len(synth_col) > 0:
                        # Проверяем на константные значения
                        if real_col.nunique() > 1 and synth_col.nunique() > 1:
                            ks_score = KSComplement.compute(
                                real_data=real_col,
                                synthetic_data=synth_col
                            )
                            shape_scores.append(ks_score)
                        else:
                            # Для константных колонок используем простую проверку
                            if real_col.iloc[0] == synth_col.iloc[0]:
                                shape_scores.append(1.0)  # Идеальное совпадение
                            else:
                                shape_scores.append(0.0)  # Разные константы

                except Exception as e:
                    print(f"Ошибка при вычислении KS для колонки {column}: {e}")
                    continue

        return sum(shape_scores) / len(shape_scores) if shape_scores else 0.0

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_shape_scores(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    data = process_data(dataset_info['data'], dataset_info['num_columns'], params['transformation_num_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    shape_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение ctgan с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
            epochs=params['epochs']
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        # Вычисляем Shape-score
        score = evaluate_shape(
            test_data,
            synthetic_data,
        dataset_info["cat_columns"])

        shape_scores.append(score)

    return np.mean(shape_scores)

# %%
def optimize_dataset(dataset_name, dataset_info, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        shape_score = generate_and_evaluate_shape_scores(params, dataset_info)

        print(f"Shape-score: {shape_score}")
        print(params)
        print("="*50)

        # Для Shape-score мы хотим максимизировать метрику, поэтому возвращаем отрицательное значение
        return {
            'loss': -shape_score,  # отрицательное для максимизации
            'status': STATUS_OK,
            'shape_score': shape_score
        }

    # Запускаем оптимизацию с помощью TPE алгоритма
    rng = np.random.default_rng(42)  # Используем фиксированный seed
    best = fmin(
        fn=objective,
        space=ctgan_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Автоматическое декодирование параметров
    best_params = space_eval(ctgan_space, best)

    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_shape_score = best_trial['result'].get('shape_score', None)

    results = {
        'best_params': best_params,
        'best_shape_score': best_shape_score,
        'shape_score_diff_from_optimal': -best_trial['result']['loss']  # убираем минус для читаемости
    }

    print(f"Лучший Shape-score для {dataset_name}: {best_shape_score}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 100

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: two_moons
# ==================================================
# Shape-score: 0.8986666666666666
# {'batch_size': 50, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0029000000000000002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9405
# {'batch_size': 50, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00125, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9511666666666666
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.863
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9250000000000002
# {'batch_size': 250, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9183333333333333
# {'batch_size': 250, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0061, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8591666666666667
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00075, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.009850000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8210000000000001
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00405, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8985
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00965, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8446666666666666
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0016, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0006500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9128333333333334
# {'batch_size': 250, 'discriminator_decay': 7e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0077, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.6121666666666666
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00125, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9365
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00365, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0024000000000000002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9125
# {'batch_size': 50, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0028, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8028333333333334
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.006050000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8885000000000001
# {'batch_size': 50, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0047, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00935, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9278333333333334
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00025, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0037500000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8921666666666667
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8778333333333334
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0045000000000000005, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7921666666666667
# {'batch_size': 250, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0022, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8693333333333332
# {'batch_size': 1000, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.85
# {'batch_size': 1000, 'discriminator_decay': 9e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8936666666666667
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9215
# {'batch_size': 50, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.815
# {'batch_size': 1000, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00055, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00165, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9313333333333333
# {'batch_size': 50, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00185, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8816666666666667
# {'batch_size': 50, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8601666666666666
# {'batch_size': 1000, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00095, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9078333333333334
# {'batch_size': 50, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00235, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9043333333333333
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9138333333333333
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0008500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9431666666666666
# {'batch_size': 50, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00655, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9338333333333333
# {'batch_size': 50, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0007, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0064, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7811666666666667
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9161666666666667
# {'batch_size': 250, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.855
# {'batch_size': 50, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00685, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8781666666666667
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9543333333333334
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9380000000000001
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9245000000000001
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0056500000000000005, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9550000000000001
# {'batch_size': 500, 'discriminator_decay': 9e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.002, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9321666666666667
# {'batch_size': 500, 'discriminator_decay': 9e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0099, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9413333333333332
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.002, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9511666666666666
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.003, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9285
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0076, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.932
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0025, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9436666666666667
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8553333333333333
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 5e-05, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9075000000000001
# {'batch_size': 100, 'discriminator_decay': 9e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00315, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0005, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9128333333333334
# {'batch_size': 250, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9258333333333333
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00035, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.924
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9331666666666667
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9611666666666666
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0015, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9043333333333333
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0078000000000000005, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.915
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0056, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9353333333333333
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00205, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9471666666666666
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0015, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9015
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.005, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9078333333333334
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0036000000000000003, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9048333333333334
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9265
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00295, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8898333333333333
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00235, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0014500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.912
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0068000000000000005, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9243333333333333
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00025, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9536666666666666
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0011, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9448333333333333
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0015, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9501666666666666
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9323333333333333
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9631666666666666
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00165, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9428333333333333
# {'batch_size': 500, 'discriminator_decay': 9e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00185, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9296666666666668
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00335, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9426666666666667
# {'batch_size': 500, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0026000000000000003, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9551666666666666
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00425, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.878
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00415, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.952
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00805, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9255
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0045000000000000005, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9518333333333334
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9385
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0028, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9131666666666667
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0016, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9135
# {'batch_size': 1000, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8953333333333333
# {'batch_size': 50, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0095, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9250000000000002
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0023, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9386666666666666
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0061, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 0.005200000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9015000000000001
# {'batch_size': 250, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00495, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0005, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9321666666666667
# {'batch_size': 50, 'discriminator_decay': 7e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8623333333333334
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00175, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00885, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9388333333333333
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00055, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8584999999999999
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0034500000000000004, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.906
# {'batch_size': 250, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0022500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.922
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9571666666666667
# {'batch_size': 1000, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00305, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9441666666666667
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9421666666666667
# {'batch_size': 250, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8828333333333332
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00215, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00185, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8538333333333333
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9426666666666667
# {'batch_size': 50, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00115, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8889999999999999
# {'batch_size': 500, 'discriminator_decay': 9e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8386666666666667
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00895, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0007, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.932
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00265, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# 100%|██████████| 100/100 [4:52:41<00:00, 175.62s/trial, best loss: -0.9631666666666666]
# Лучший Shape-score для two_moons: 0.9631666666666666
# Лучшие параметры: {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00165, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_shape_score'])
# Out:
# two_moons 0.9631666666666666
