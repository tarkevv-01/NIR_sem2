# %%
# !pip install sdv
# Out:
# Collecting sdv
#   Downloading sdv-1.22.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.26.4)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Collecting copulas>=0.12.1 (from sdv)
#   Downloading copulas-0.12.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting ctgan>=0.11.0 (from sdv)
#   Downloading ctgan-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Downloading deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.17.0 (from sdv)
#   Downloading rdt-1.17.0-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.21.0 (from sdv)
#   Downloading sdmetrics-0.21.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.15.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (1.2.2)
# Collecting Faker>=17 (from rdt>=1.17.0->sdv)
#   Downloading faker-37.3.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.0->sdv) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# Downloading sdv-1.22.1-py3-none-any.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading copulas-0.12.2-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.2 MB/s eta 0:00:00
# Downloading ctgan-0.11.0-py3-none-any.whl (24 kB)
# Downloading deepecho-0.7.0-py3-none-any.whl (27 kB)
# Downloading rdt-1.17.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 3.0 MB/s eta 0:00:00
# Downloading sdmetrics-0.21.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 kB 14.6 MB/s eta 0:00:00
# Downloading faker-37.3.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 45.8 MB/s eta 0:00:0000:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.7 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, Faker, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, rdt, copulas, sdmetrics, deepecho, ctgan, sdv
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed Faker-37.3.0 copulas-0.12.2 ctgan-0.11.0 deepecho-0.7.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rdt-1.17.0 sdmetrics-0.21.0 sdv-1.22.1

# %%
# !unrar x data.rar
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
# Cannot open data.rar
# No such file or directory
# No files to extract

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from hyperopt import space_eval
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
from sklearn.metrics import f1_score, r2_score
from xgboost import XGBClassifier, XGBRegressor

# %%
dir_datasets = '/kaggle/input/nir02-moons/data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'moons_dataset.csv')

# Словарь датасетов для удобства
datasets = {
    'two_moons': {
                    "data": real_data_1,
                    "task": "regression",
                    "target": "x2",
                    "num_columns":
                    ["x1"],
                    "cat_columns":
                    []
                },
}


for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f"Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете two_moons:
#  Количество строк: 3000
#  Количество колонок: 2
#  Колонки: ['x1', 'x2']
#  Задача: regression
#  Целевая переменная: x2
#  Числовые признаки: ['x1']
# Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    # Learning rates
    'discriminator_lr': hp.qloguniform('discriminator_lr',
                                                 np.log(5e-5), np.log(1e-2), 5e-5),
    'generator_lr': hp.qloguniform('generator_lr',
                                             np.log(5e-5), np.log(1e-2), 5e-5),

    # Batch size
    'batch_size': hp.choice('batch_size', [50, 100, 250, 500, 1000]),

    # Embedding dimensions
    'embedding_dim': hp.choice('embedding_dim', [32, 64, 128, 256]),

    # Network architecture
    'generator_dim': hp.choice('generator_dim', [[128, 128], [128, 128, 128], [128, 128, 128, 128],
                                                [256, 256], [256, 256, 256], [256, 256, 256, 256]]),
    'discriminator_dim': hp.choice('discriminator_dim', [[256, 256], [256, 256, 256],
                                                        [128, 128], [128, 128, 128]]),

    # Decay parameters
    'generator_decay': hp.qloguniform('generator_decay',
                                     np.log(1e-6), np.log(1e-5), 1e-6),
    'discriminator_decay': hp.qloguniform('discriminator_decay',
                                         np.log(1e-6), np.log(1e-5), 1e-6),

    # Frequency
    'log_frequency': hp.choice('log_frequency', [False, True]),
    'transformation_num_type': hp.choice('transformation_num_type', ['CDF', 'PLE_CDF']),
    'transformation_cat_type': hp.choice('transformation_cat_type', ['OHE']),
    'epochs': hp.choice('epochs', [400]),

}

# %%
def evaluate_ml_efficacy(real_train, synthetic_train, real_test, target_column, num_columns, cat_columns, task_type='classification'):
    """
    Вычисляет ML-Efficacy метрику

    Args:
        real_train: реальные тренировочные данные
        synthetic_train: синтетические тренировочные данные
        real_test: реальные тестовые данные
        target_column: название целевой колонки
        task_type: 'classification' или 'regression'

    Returns:
        ml_efficacy_score: отношение качества модели на синтетических данных к качеству на реальных
    """

    # Подготовка данных
    real_train_copy = real_train.copy()

    # Обработка синтетических данных (если это объект с методом dataframe)
    if hasattr(synthetic_train, "dataframe"):
        synthetic_train = synthetic_train.dataframe()
    synthetic_train_copy = synthetic_train.copy()

    real_test_copy = real_test.copy()

    # Определение категориальных колонок (исключая целевую)
    feature_columns = num_columns
    categorical_columns = cat_columns

    # Label Encoding для категориальных признаков
    label_encoders = {}
    for col in categorical_columns:
        le = LabelEncoder()
        # Обучаем на реальных данных
        combined_values = pd.concat([real_train_copy[col], real_test_copy[col]]).astype(str)
        le.fit(combined_values)
        label_encoders[col] = le

        # Применяем к реальным данным
        real_train_copy[col] = le.transform(real_train_copy[col].astype(str))
        real_test_copy[col] = le.transform(real_test_copy[col].astype(str))

        # Применяем к синтетическим данным, обрабатываем неизвестные значения
        synthetic_values = synthetic_train_copy[col].astype(str)
        known_values = set(le.classes_)
        synthetic_values = synthetic_values.apply(lambda x: x if x in known_values else le.classes_[0])
        synthetic_train_copy[col] = le.transform(synthetic_values)

    # Разделение на признаки и целевую переменную
    X_real_train = real_train_copy.drop(columns=[target_column])
    y_real_train = real_train_copy[target_column]

    X_synthetic_train = synthetic_train_copy.drop(columns=[target_column])
    y_synthetic_train = synthetic_train_copy[target_column]

    X_real_test = real_test_copy.drop(columns=[target_column])
    y_real_test = real_test_copy[target_column]

    # Выбор модели в зависимости от типа задачи
    if task_type == 'classification':
        model_real = XGBClassifier(random_state=42, eval_metric='logloss')
        model_synthetic = XGBClassifier(random_state=42, eval_metric='logloss')
        score_func = f1_score
        score_kwargs = {'average': 'weighted'} if len(np.unique(y_real_train)) > 2 else {'average': 'binary'}
    else:  # regression
        model_real = XGBRegressor(random_state=42)
        model_synthetic = XGBRegressor(random_state=42)
        score_func = r2_score
        score_kwargs = {}

    try:
        # Обучение модели на реальных данных
        model_real.fit(X_real_train, y_real_train)
        y_pred_real = model_real.predict(X_real_test)
        score_real = score_func(y_real_test, y_pred_real, **score_kwargs)

        # Обучение модели на синтетических данных
        model_synthetic.fit(X_synthetic_train, y_synthetic_train)
        y_pred_synthetic = model_synthetic.predict(X_real_test)
        score_synthetic = score_func(y_real_test, y_pred_synthetic, **score_kwargs)

        # Вычисление ML-Efficacy
        if score_real > 0:
            ml_efficacy = score_synthetic / score_real
        else:
            ml_efficacy = 0.0

        return ml_efficacy

    except Exception as e:
        print(f"Ошибка при вычислении ML-Efficacy: {e}")
        return 0.0

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_ml_efficacy(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    task_type = dataset_info['task']
    target_column = dataset_info['target']
    data = process_data(dataset_info['data'], dataset_info['num_columns'], dataset_info["cat_columns"], params['transformation_num_type'], params['transformation_cat_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    ml_efficacy_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение CTGAN с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
            epochs=params['epochs']
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        # Вычисляем ML-Efficacy
        score = evaluate_ml_efficacy(
            real_train=train_data,
            synthetic_train=synthetic_data,
            real_test=test_data,
            target_column=target_column,
            num_columns = dataset_info["num_columns"],
            cat_columns = dataset_info["cat_columns"],
            task_type=task_type
        )
        ml_efficacy_scores.append(score)

    return np.mean(ml_efficacy_scores)

# %%
def optimize_dataset(dataset_name, dataset_info, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        ml_efficacy_score = generate_and_evaluate_ml_efficacy(params, dataset_info)

        print(f"ML-Efficacy: {ml_efficacy_score}")
        print(params)
        print("="*50)

        # Для ML-Efficacy мы хотим максимизировать метрику, поэтому возвращаем отрицательное значение
        return {
            'loss': -ml_efficacy_score,  # отрицательное для максимизации
            'status': STATUS_OK,
            'ml_efficacy_score': ml_efficacy_score
        }

    # Запускаем оптимизацию с помощью TPE алгоритма
    rng = np.random.default_rng(42)  # Используем фиксированный seed
    best = fmin(
        fn=objective,
        space=ctgan_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Автоматическое декодирование параметров
    best_params = space_eval(ctgan_space, best)


    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_ml_efficacy = best_trial['result'].get('ml_efficacy_score', None)

    results = {
        'best_params': best_params,
        'best_ml_efficacy': best_ml_efficacy,
        'ml_efficacy_diff_from_optimal': -best_trial['result']['loss']  # убираем минус для читаемости
    }

    print(f"Лучший ML-Efficacy для {dataset_name}: {best_ml_efficacy}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 100

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: two_moons
# ==================================================
# ML-Efficacy: -0.42761543183442985
# {'batch_size': 50, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0029000000000000002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.01841243010884735
# {'batch_size': 50, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00125, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.40878577042036907
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.48936179434622434
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.0786270706437046
# {'batch_size': 250, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.3472286981583574
# {'batch_size': 250, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0061, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.21126029151075798
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00075, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.009850000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.2989161650278445
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00405, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7689823639811676
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00965, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.32124922409069273
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0016, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0006500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7675646759227085
# {'batch_size': 250, 'discriminator_decay': 7e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0077, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -2.8084236943931757
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00125, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.02743067351477244
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00365, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0024000000000000002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.1410779816685475
# {'batch_size': 50, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0028, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.0999463287843767
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.006050000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7134682523747156
# {'batch_size': 50, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0047, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00935, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.22144743296543742
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00025, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0037500000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.042131534568539415
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.2624235334835952
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0045000000000000005, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.22331053176888224
# {'batch_size': 250, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0022, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.34143717740791213
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.6818685656594592
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -3.3571949519580255
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 5e-05, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00185, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.1750176672315044
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0019, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.009917684207953558
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0037, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.023020135946813573
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.1949311597767125
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.006050000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.14691045710954306
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.043251302075990955
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0022500000000000003, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.08629312849720812
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.05043912716544915
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00095, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.0529836529342976
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00095, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.09195580816577992
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0011, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0016, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.092952015348701
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0015, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.44026356993363375
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0007, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00115, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.04456398098227043
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0008, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0005, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.02573788337331062
# {'batch_size': 100, 'discriminator_decay': 9e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0014, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0016, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.6479516024650773
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00035, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0028, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7092805594787843
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0022500000000000003, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0074, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.10679169478451095
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00095, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0010500000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.14520416005465953
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0018000000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.03144697978986348
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00075, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00315, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.013023681161097785
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.05495511155925051
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0004, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.005050000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -2.6584281095023097
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00115, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.4258156776700493
# {'batch_size': 250, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0076500000000000005, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0006500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.6362809143036011
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00555, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.005854359245737822
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0029000000000000002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.1429051225471341
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.31563164881892236
# {'batch_size': 250, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00025, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.11111102183289984
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.6754231927891062
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.2045342053600399
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7393442620124882
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.20075162358113915
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.06704071189994769
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.11087926130098948
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.14773402194945975
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00035, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0034000000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.33696100324204936
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00395, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00855, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.13543049277341382
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.1806755982865821
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00025, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00055, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.3069800344330045
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00255, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.03434559239899436
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.5539271123874698
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.041927024665355916
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00075, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.40313686703598944
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.30815927727656933
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7921341682569444
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.4301206687090832
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.9787941075217588
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.08685419545160933
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.16611187599876565
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.17057327587963758
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00025, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.11505341993021674
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.062713404132162
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.8959888545206147
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00035, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.10140596763922292
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.011602208825715268
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.21810087393610836
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.07639617695118008
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.07789865987272411
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.2115944064089695
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.0787387343830194
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.1649863835651851
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.2209167315996439
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0006500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.4740084402902638
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.06919931371314372
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0005, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.02905391070899414
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0002, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.13980533760350747
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.25697709966319565
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -2.7139209908883495
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0009000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.34691485677934586
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00025, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00055, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.34153786973674727
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.9936476537081873
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00075, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.06682309733938498
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0013000000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.12510246529759358
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.1161344628025591
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 5e-05, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.05425782046981605
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.05596239655247321
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.13539491534957937
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# 100%|██████████| 100/100 [6:06:54<00:00, 220.14s/trial, best loss: -0.40313686703598944]
# Лучший ML-Efficacy для two_moons: 0.40313686703598944
# Лучшие параметры: {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_ml_efficacy'])
# Out:
# two_moons 0.40313686703598944
