# %%
# !pip install sdv
# !pip install sdmetrics
# Out:
# Collecting sdv
#   Downloading sdv-1.22.1-py3-none-any.whl.metadata (14 kB)
# Collecting boto3<2.0.0,>=1.28 (from sdv)
#   Downloading boto3-1.38.29-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<2.0.0,>=1.31 (from sdv)
#   Downloading botocore-1.38.29-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Collecting copulas>=0.12.1 (from sdv)
#   Downloading copulas-0.12.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting ctgan>=0.11.0 (from sdv)
#   Downloading ctgan-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Downloading deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.17.0 (from sdv)
#   Downloading rdt-1.17.0-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.21.0 (from sdv)
#   Downloading sdmetrics-0.21.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.15.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (1.6.1)
# Collecting Faker>=17 (from rdt>=1.17.0->sdv)
#   Downloading faker-37.3.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# Downloading sdv-1.22.1-py3-none-any.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 7.2 MB/s eta 0:00:00
# Downloading boto3-1.38.29-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 13.5 MB/s eta 0:00:00
# Downloading botocore-1.38.29-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 125.5 MB/s eta 0:00:00
# Downloading copulas-0.12.2-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.3 MB/s eta 0:00:00
# Downloading ctgan-0.11.0-py3-none-any.whl (24 kB)
# Downloading deepecho-0.7.0-py3-none-any.whl (27 kB)
# Downloading rdt-1.17.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 7.1 MB/s eta 0:00:00
# Downloading sdmetrics-0.21.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 kB 18.7 MB/s eta 0:00:00
# Downloading faker-37.3.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 84.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jmespath, Faker, nvidia-cusparse-cu12, nvidia-cudnn-cu12, botocore, s3transfer, rdt, nvidia-cusolver-cu12, copulas, sdmetrics, boto3, deepecho, ctgan, sdv
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed Faker-37.3.0 boto3-1.38.29 botocore-1.38.29 copulas-0.12.2 ctgan-0.11.0 deepecho-0.7.0 jmespath-1.0.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rdt-1.17.0 s3transfer-0.13.0 sdmetrics-0.21.0 sdv-1.22.1
# Requirement already satisfied: sdmetrics in /usr/local/lib/python3.11/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (1.6.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (1.15.3)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (0.12.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (4.67.1)
# Requirement already satisfied: plotly>=5.19.0 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (5.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdmetrics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdmetrics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdmetrics) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.19.0->sdmetrics) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.19.0->sdmetrics) (24.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->sdmetrics) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->sdmetrics) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->sdmetrics) (1.17.0)

# %%
# !unrar x data.rar
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from data.rar
#
# Creating    data                                                      OK
#   OK
# All OK

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from hyperopt import space_eval
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
from sklearn.metrics import f1_score, r2_score
from xgboost import XGBClassifier, XGBRegressor

# %%
dir_datasets = 'data/'

# Загрузка реальных датасетов
# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'moons_dataset.csv')

# Словарь датасетов для удобства
datasets = {
    'two_moons': {
                    "data": real_data_1,
                    "task": "regression",
                    "target": "x2",
                    "num_columns":
                    ["x1"],
                    "cat_columns":
                    []
                },
}


for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f"Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете two_moons:
#  Количество строк: 3000
#  Количество колонок: 2
#  Колонки: ['x1', 'x2']
#  Задача: regression
#  Целевая переменная: x2
#  Числовые признаки: ['x1']
# Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    # Learning rates
    'discriminator_lr': hp.qloguniform('discriminator_lr',
                                                 np.log(5e-5), np.log(1e-2), 5e-5),
    'generator_lr': hp.qloguniform('generator_lr',
                                             np.log(5e-5), np.log(1e-2), 5e-5),

    # Batch size
    'batch_size': hp.choice('batch_size', [50, 100, 250, 500, 1000]),

    # Embedding dimensions
    'embedding_dim': hp.choice('embedding_dim', [32, 64, 128, 256]),

    # Network architecture
    'generator_dim': hp.choice('generator_dim', [[128, 128], [128, 128, 128], [128, 128, 128, 128],
                                                [256, 256], [256, 256, 256], [256, 256, 256, 256]]),
    'discriminator_dim': hp.choice('discriminator_dim', [[256, 256], [256, 256, 256],
                                                        [128, 128], [128, 128, 128]]),

    # Decay parameters
    'generator_decay': hp.qloguniform('generator_decay',
                                     np.log(1e-6), np.log(1e-5), 1e-6),
    'discriminator_decay': hp.qloguniform('discriminator_decay',
                                         np.log(1e-6), np.log(1e-5), 1e-6),

    # Frequency
    'log_frequency': hp.choice('log_frequency', [False, True]),
    'transformation_num_type': hp.choice('transformation_num_type', ['CDF', 'PLE_CDF']),
    'transformation_cat_type': hp.choice('transformation_cat_type', ['OHE']),
    'epochs': hp.choice('epochs', [400]),

}

# %%
def evaluate_pair(real_data, synthetic_data, cat_columns):
    # One-hot энкодинг для категориальных признаков
    real_data_encoded = pd.get_dummies(real_data, columns=cat_columns, drop_first=True)

    if hasattr(synthetic_data, "dataframe"):
        synthetic = synthetic_data.dataframe()
    else:
        synthetic = synthetic_data

    synthetic_encoded = pd.get_dummies(synthetic, columns=cat_columns, drop_first=True)

    # После get_dummies
    real_data_encoded = real_data_encoded.astype(float)
    synthetic_encoded = synthetic_encoded.astype(float)

    # Корреляции
    corr_real = real_data_encoded.corr()
    corr_synth = synthetic_encoded.corr()

    # Абсолютное отклонение корреляций
    pairwise_diff = np.abs(corr_real - corr_synth)

    # Усреднённое отклонение
    mean_diff = pairwise_diff.mean().mean()

    # Проверяем на NaN
    if np.isnan(mean_diff):
        print("Warning: mean_diff is NaN, returning 0")
        return 0.0

    return 1 - mean_diff  # ближе к 1 — лучше

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_pair_scores(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    data = process_data(dataset_info['data'], dataset_info['num_columns'], params['transformation_num_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    pair_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение DDPM с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
            epochs=params['epochs']
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        # Вычисляем Pair-score
        score = evaluate_pair(
            test_data,
            synthetic_data,
            dataset_info["cat_columns"]
        )
        pair_scores.append(score)

    return np.mean(pair_scores)

# %%
def optimize_dataset(dataset_name, dataset_info, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        pair_score = generate_and_evaluate_pair_scores(params, dataset_info)

        print(f"Pair-score: {pair_score}")
        print(params)
        print("="*50)

        # Для ML-Efficacy мы хотим максимизировать метрику, поэтому возвращаем отрицательное значение
        return {
            'loss': -pair_score,  # отрицательное для максимизации
            'status': STATUS_OK,
            'pair_score': pair_score
        }

    # Запускаем оптимизацию с помощью TPE алгоритма
    rng = np.random.default_rng(42)  # Используем фиксированный seed
    best = fmin(
        fn=objective,
        space=ctgan_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Автоматическое декодирование параметров
    best_params = space_eval(ctgan_space, best)

    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_pair_score = best_trial['result'].get('pair_score', None)

    results = {
        'best_params': best_params,
        'best_pair_score': best_pair_score,
        'pair_score_diff_from_optimal': -best_trial['result']['loss']  # убираем минус для читаемости
    }

    print(f"Лучший Pair-score для {dataset_name}: {best_pair_score}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 100

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: two_moons
# ==================================================
# Pair-score: 0.844123020754795
# {'batch_size': 50, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0029000000000000002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9437151503217235
# {'batch_size': 50, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00125, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8156043004947535
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.7889034094693009
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9335974076423005
# {'batch_size': 250, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8608876944461447
# {'batch_size': 250, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0061, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9025829657310688
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00075, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.009850000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8122003320258617
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00405, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.743065444101274
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00965, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9354378978488272
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0016, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0006500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8386042485285649
# {'batch_size': 250, 'discriminator_decay': 7e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0077, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.7614610457922705
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0002, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00125, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8986429529322472
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00365, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0024000000000000002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9162412207754856
# {'batch_size': 50, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0028, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8619220838157263
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.006050000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.7768931395984554
# {'batch_size': 50, 'discriminator_decay': 4e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0047, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00935, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9311369493470077
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00025, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0037500000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9729356427408842
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 9e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.961514606809283
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00030000000000000003, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0045000000000000005, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.824117820747022
# {'batch_size': 250, 'discriminator_decay': 6e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0022, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9815545359964158
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9076711345528179
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8920997440717615
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 5e-05, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9612628123408108
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9440612143699735
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9420689103984144
# {'batch_size': 50, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9733519472002664
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9699020221143858
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0016, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.978372760113012
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0022, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0009000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9681094854541253
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0024000000000000002, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00095, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9322693819841116
# {'batch_size': 500, 'discriminator_decay': 9.999999999999999e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0018000000000000002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9671176367423809
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128), 'generator_lr': 0.0009000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9646110174216321
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9676524092602653
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0022, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9926523828780941
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00165, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9225028172015385
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0017000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.949465204297827
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (256, 256), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9584706168712659
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0015, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8416940646523003
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00395, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0076500000000000005, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8418322109240882
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00035, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0005, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9719320947031235
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00125, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9419214160774168
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.783824830730505
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0054, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256), 'generator_lr': 0.003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.7113753162785597
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 5e-05, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0007, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8003288474981552
# {'batch_size': 250, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0082, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9319324735595785
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0010500000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9259751131797079
# {'batch_size': 100, 'discriminator_decay': 9e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8848145233436958
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.005050000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9561140343629692
# {'batch_size': 250, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.945788760433114
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00025, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00295, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9502741082318042
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00015000000000000001, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9353939773040238
# {'batch_size': 250, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.004, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.00055, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.813653298163703
# {'batch_size': 50, 'discriminator_decay': 2e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00335, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 8e-06, 'generator_dim': (256, 256), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.7814154563463696
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.0004, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0022, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9531756096803706
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0064, 'embedding_dim': 128, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 0.00075, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8868257845311204
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0002, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 2e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0061, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9439272744824762
# {'batch_size': 50, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (128, 128), 'discriminator_lr': 0.00185, 'embedding_dim': 32, 'epochs': 400, 'generator_decay': 9.999999999999999e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.9746217144527577
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00285, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.8886678040181027
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (128, 128, 128), 'discriminator_lr': 0.00055, 'embedding_dim': 256, 'epochs': 400, 'generator_decay': 7e-06, 'generator_dim': (256, 256), 'generator_lr': 0.00365, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.7939166445755474
# {'batch_size': 250, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 5e-05, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 4e-06, 'generator_dim': (256, 256, 256), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Pair-score: 0.7910307204915261
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00975, 'embedding_dim': 64, 'epochs': 400, 'generator_decay': 1e-06, 'generator_dim': (256, 256, 256, 256), 'generator_lr': 0.0012000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
#  61%|██████    | 61/100 [3:55:59<1:47:24, 165.24s/trial, best loss: -0.9926523828780941]

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_pair_score'])
