# %%
# !pip install sdv deap
# Out:
# Requirement already satisfied: sdv in /usr/local/lib/python3.11/dist-packages (1.22.1)
# Requirement already satisfied: deap in /usr/local/lib/python3.11/dist-packages (1.4.3)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.36)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.36)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.12.3)
# Requirement already satisfied: ctgan>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.17.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.21.0)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.15.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (1.6.1)
# Requirement already satisfied: Faker>=17 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (37.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)

# %%
# !unrar x data.rar
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from data.rar
#
# Creating    data                                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
import time
import pandas as pd
import numpy as np
import torch
import random
import warnings
from datetime import timedelta
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import hp
from deap import base, creator, tools, algorithms
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm

# %%
dir_datasets = 'data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_2 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_regression.csv')
real_data_4 = pd.read_csv(dir_datasets+'two_moons.csv')
real_data_5 = pd.read_csv(dir_datasets+'california_housing.csv')
real_data_6 = pd.read_csv(dir_datasets+'titanic.csv')

# Словарь датасетов для удобства
datasets = {
               'insurance': {
                        "data": real_data_1,
                        "task": "regression",
                        "target": "expenses",
                        "num_columns":
                        ["age", "bmi", "children"],
                        "cat_columns":
                        ["sex", "smoker", "region"]
                    },
               'my_regression': {
                        "data": real_data_3,
                        "task": "regression",
                        "target": "target",
                        "num_columns":
                        ["feature_0", "feature_1", "feature_2", "feature_3"],
                        "cat_columns":
                        []
                    },
              'two_moons': {
                              "data": real_data_4,
                              "task": "classification",
                              "target": "label",
                              "num_columns":
                              ["x1", "x2"],
                              "cat_columns":
                              []
                          },

}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете insurance:
#  Количество строк: 1338
#  Количество колонок: 7
#  Колонки: ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']
#  Задача: regression
#  Целевая переменная: expenses
#  Числовые признаки: ['age', 'bmi', 'children']
#  Категориальные признаки: ['sex', 'smoker', 'region']
#
#  Информация о датасете my_regression:
#  Количество строк: 900
#  Количество колонок: 5
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'target']
#  Задача: regression
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3']
#  Категориальные признаки: []
#
#  Информация о датасете two_moons:
#  Количество строк: 900
#  Количество колонок: 3
#  Колонки: ['x1', 'x2', 'label']
#  Задача: classification
#  Целевая переменная: label
#  Числовые признаки: ['x1', 'x2']
#  Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    'discriminator_lr': (4e-4, 2.1e-3, 5e-5),
    'generator_lr': (5e-5, 5e-3, 5e-5),
    'batch_size': [100, 500, 1000],
    'embedding_dim': [32, 128],
    'generator_dim': [[128, 128, 128], [128, 128, 128, 128]],
    'discriminator_dim': [[256, 256], [256, 256, 256]],
    'generator_decay': (1e-6, 6.4e-6, 1e-7),
    'discriminator_decay': (1e-6, 8e-6, 1e-6),
    'log_frequency': [False, True],
    'transformation_num_type': ['CDF', 'PLE_CDF'],
    'transformation_cat_type': ['OHE']

}

# %%
import sys
import os
import builtins
import contextlib

@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        old_print = builtins.print
        builtins.print = lambda *args, **kwargs: None
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr
            builtins.print = old_print

# %%
import numpy as np
import random
from deap import base, creator, tools, algorithms
from hyperopt import hp
from sklearn.model_selection import KFold
import warnings
from contextlib import contextmanager
import sys
import os

@contextmanager
def suppress_all_output():
    """Контекстный менеджер для подавления всего вывода"""
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

class UniversalGeneticOptimizer:
    def __init__(self,
                 param_space,
                 population_size=20,
                 n_generations=10,
                 mutation_prob=0.2,
                 crossover_prob=0.8,
                 tournament_size=3,
                 random_seed=42,
                 verbose=True):
        """
        Универсальный генетический алгоритм для оптимизации гиперпараметров

        Args:
            param_space: словарь с определением пространства поиска
            population_size: размер популяции
            n_generations: количество поколений
            mutation_prob: вероятность мутации
            crossover_prob: вероятность скрещивания
            tournament_size: размер турнира для отбора
            random_seed: seed для воспроизводимости
            verbose: вывод прогресса
        """
        self.param_space = param_space
        self.population_size = population_size
        self.n_generations = n_generations
        self.mutation_prob = mutation_prob
        self.crossover_prob = crossover_prob
        self.tournament_size = tournament_size
        self.verbose = verbose

        # Устанавливаем seed
        random.seed(random_seed)
        np.random.seed(random_seed)

        # Анализируем пространство параметров
        self.param_info = self._analyze_param_space()

        # Настройка DEAP
        self._setup_deap()

        # История оптимизации
        self.history = {
            'generations': [],
            'best_fitness': [],
            'avg_fitness': [],
            'best_params': []
        }

    def _analyze_param_space(self):
        """Анализ пространства параметров для определения их типов"""
        param_info = {}

        for param_name, param_def in self.param_space.items():
            if isinstance(param_def, tuple) and len(param_def) == 2:
                # Непрерывный параметр (min, max)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': None
                }
            elif isinstance(param_def, tuple) and len(param_def) == 3:
                # Непрерывный параметр с квантованием (min, max, step)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': param_def[2]
                }
            elif isinstance(param_def, list):
                # Дискретный параметр
                param_info[param_name] = {
                    'type': 'discrete',
                    'values': param_def
                }
            else:
                raise ValueError(f"Неподдерживаемый тип параметра: {param_name}")

        return param_info

    def _setup_deap(self):
        """Настройка DEAP для минимизации"""
        # Создаем класс для фитнеса (минимизация)
        if not hasattr(creator, "FitnessMin"):
            creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
        if not hasattr(creator, "Individual"):
            creator.create("Individual", list, fitness=creator.FitnessMin)

        self.toolbox = base.Toolbox()

        # Регистрируем функции создания индивидов
        self.toolbox.register("individual", self._create_individual)
        self.toolbox.register("population", tools.initRepeat, list, self.toolbox.individual)

        # Регистрируем операторы
        self.toolbox.register("mate", self._crossover)
        self.toolbox.register("mutate", self._mutate)
        self.toolbox.register("select", tools.selTournament, tournsize=self.tournament_size)
        self.toolbox.register("evaluate", self._evaluate_individual)

    def _create_individual(self):
        """Создание случайного индивида"""
        individual = []

        for param_name in self.param_space.keys():
            info = self.param_info[param_name]

            if info['type'] == 'continuous':
                # Непрерывный параметр
                value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                if info['quantization'] is not None:
                    # Применяем квантование
                    value = round(value / info['quantization']) * info['quantization']
                    value = np.clip(value, info['min'], info['max'])
                individual.append(value)

            elif info['type'] == 'discrete':
                # Дискретный параметр - сохраняем индекс
                individual.append(np.random.randint(len(info['values'])))

        return creator.Individual(individual)

    def _decode_individual(self, individual):
        """Декодирование индивида в параметры"""
        params = {}

        for i, param_name in enumerate(self.param_space.keys()):
            info = self.param_info[param_name]

            if info['type'] == 'continuous':
                params[param_name] = individual[i]
            elif info['type'] == 'discrete':
                params[param_name] = info['values'][int(individual[i])]

        return params

    def _crossover(self, ind1, ind2):
        """One-point crossover"""
        # Выбираем случайную точку разреза
        if len(ind1) > 1:
            crossover_point = random.randint(1, len(ind1) - 1)
        else:
            crossover_point = 1

        # Обмениваемся частями после точки разреза
        for i in range(crossover_point, len(ind1)):
            ind1[i], ind2[i] = ind2[i], ind1[i]

        return ind1, ind2

    def _mutate(self, individual):
        """Операция мутации - случайное значение из пространства поиска"""
        for i, param_name in enumerate(self.param_space.keys()):
            if random.random() < self.mutation_prob:
                info = self.param_info[param_name]

                if info['type'] == 'continuous':
                    # Генерируем новое случайное значение
                    new_value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                    if info['quantization'] is not None:
                        new_value = round(new_value / info['quantization']) * info['quantization']
                        new_value = np.clip(new_value, info['min'], info['max'])
                    individual[i] = new_value

                elif info['type'] == 'discrete':
                    # Выбираем случайный индекс
                    individual[i] = np.random.randint(len(info['values']))

        return individual,

    def _evaluate_individual(self, individual):
        """Оценка индивида"""

        params = self._decode_individual(individual)
        pair_score = self.objective_function(params)

        return pair_score,

    def set_objective_function(self, objective_func):
        """Установка целевой функции"""
        self.objective_function = objective_func

    def optimize(self):
        """Запуск оптимизации"""
        if self.verbose:
            print(f"Пространство параметров:")
            for param_name, info in self.param_info.items():
                if info['type'] == 'continuous':
                    quant_info = f", квантование: {info['quantization']}" if info['quantization'] else ""
                    print(f"  {param_name}: непрерывный ({info['min']}, {info['max']}){quant_info}")
                else:
                    print(f"  {param_name}: дискретный {info['values']}")
            print(f"Размер популяции: {self.population_size}")
            print(f"Количество поколений: {self.n_generations}")
            print(f"Вероятность мутации: {self.mutation_prob}")
            print(f"Вероятность скрещивания: {self.crossover_prob}")
            print("="*60)

        # Создание начальной популяции
        population = self.toolbox.population(n=self.population_size)

        # Оценка начальной популяции
        fitnesses = list(map(self.toolbox.evaluate, population))
        for ind, fit in zip(population, fitnesses):
            ind.fitness.values = fit

        if self.verbose:
            self._print_population_info(population, 0, "Начальная популяция")

        # Эволюция
        for generation in range(1, self.n_generations + 1):
            if self.verbose:
                print(f"\n{'='*20} ПОКОЛЕНИЕ {generation} {'='*20}")

            # Отбор родителей
            parents = self.toolbox.select(population, len(population))


            # Создание потомков
            offspring = list(map(self.toolbox.clone, parents))

            # Скрещивание (one-point crossover)
            for child1, child2 in zip(offspring[::2], offspring[1::2]):
                if random.random() < self.crossover_prob:
                    self.toolbox.mate(child1, child2)
                    del child1.fitness.values
                    del child2.fitness.values

            # Мутация
            for mutant in offspring:
                if random.random() < self.mutation_prob:
                    self.toolbox.mutate(mutant)
                    del mutant.fitness.values

            # Оценка потомков
            invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
            fitnesses = map(self.toolbox.evaluate, invalid_ind)
            for ind, fit in zip(invalid_ind, fitnesses):
                ind.fitness.values = fit

            # ЭЛИТАРНАЯ СТРАТЕГИЯ: объединение родителей и потомков
            combined_population = population + offspring
            population = tools.selBest(combined_population, self.population_size)


            # Сохранение статистики
            self._save_generation_stats(population, generation)


        # Лучший индивид
        best_individual = tools.selBest(population, 1)[0]
        best_params = self._decode_individual(best_individual)
        best_fitness = best_individual.fitness.values[0]


        return {
            'best_params': best_params,
            'best_pair': best_fitness,
            'pair_diff_from_optimal': best_fitness,
            'history': self.history
        }

    def _format_params(self, params):
        """Форматирование параметров для вывода"""
        formatted = {}
        for key, value in params.items():
            if isinstance(value, float):
                formatted[key] = f"{value}"
            else:
                formatted[key] = value
        return formatted

    def _print_population_info(self, population, generation, title):
        """Вывод информации о популяции"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)

        print(f"\n{title}:")
        print(f"  Лучший PAIR: {-best_fitness}")
        print(f"  Средний PAIR: {-avg_fitness}")


    def _save_generation_stats(self, population, generation):
        """Сохранение статистики поколения"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)

        best_individual = min(population, key=lambda x: x.fitness.values[0])
        best_params = self._decode_individual(best_individual)

        self.history['generations'].append(generation)
        self.history['best_fitness'].append(best_fitness)
        self.history['avg_fitness'].append(avg_fitness)
        self.history['best_params'].append(best_params)

# %%
def evaluate_pair(real_data, synthetic_data, cat_columns):
    # One-hot энкодинг для категориальных признаков
    real_data_encoded = pd.get_dummies(real_data, columns=cat_columns, drop_first=True)

    if hasattr(synthetic_data, "dataframe"):
        synthetic = synthetic_data.dataframe()
    else:
        synthetic = synthetic_data

    synthetic_encoded = pd.get_dummies(synthetic, columns=cat_columns, drop_first=True)

    # После get_dummies
    real_data_encoded = real_data_encoded.astype(float)
    synthetic_encoded = synthetic_encoded.astype(float)

    # Корреляции
    corr_real = real_data_encoded.corr()
    corr_synth = synthetic_encoded.corr()

    # Абсолютное отклонение корреляций
    pairwise_diff = np.abs(corr_real - corr_synth)

    # Усреднённое отклонение
    mean_diff = pairwise_diff.mean().mean()

    # Проверяем на NaN
    if np.isnan(mean_diff):
        print("Warning: mean_diff is NaN, returning 0")
        return 0.0

    return 1 - mean_diff

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_pair_scores(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    columns_dataset = dataset_info['num_columns'] + dataset_info['cat_columns'] + [dataset_info['target']]
    data = process_data(dataset_info['data'][columns_dataset], dataset_info['num_columns'], dataset_info['cat_columns'],
                        'None', 'None')

    kf = KFold(n_splits=n_splits, shuffle=False)
    pair_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        cat_columns = dataset_info['cat_columns'].copy()
        if dataset_info["task"] == 'classification':
            cat_columns.append(dataset_info['target'])
        for col in dataset_info['cat_columns']:
            metadata.update_column(col, sdtype='categorical')

        # Создание и обучение CTGAN с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        # Вычисляем Pair-score
        score = evaluate_pair(
            test_data,
            synthetic_data,
            cat_columns
        )
        pair_scores.append(score)

    return -np.mean(pair_scores) #Возращаем *(-1) для минимизации

# %%
def optimize_dataset_genetic(dataset_name, dataset_info, param_space,
                           population_size=20, n_generations=10,
                           mutation_prob=0.2, crossover_prob=1.0,
                           tournament_size=3, random_seed=None, verbose=True):
    """
    Универсальная оптимизация датасета с использованием генетического алгоритма

    Args:
        dataset_name: название датасета
        dataset: информация о датасете
        param_space: пространство поиска параметров
        population_size: размер популяции
        n_generations: количество поколений
        mutation_prob: вероятность мутации
        crossover_prob: вероятность скрещивания
        tournament_size: размер турнира
        random_seed: seed для воспроизводимости
        verbose: вывод прогресса
    """
    print(f"Генетическая оптимизация для датасета: {dataset_name}")

    # Создание оптимизатора
    optimizer = UniversalGeneticOptimizer(
        param_space=param_space,
        population_size=population_size,
        n_generations=n_generations,
        mutation_prob=mutation_prob,
        crossover_prob=crossover_prob,
        tournament_size=tournament_size,
        random_seed=random_seed,
        verbose=verbose
    )

    # Определение целевой функции
    def objective(params):
        if verbose:
            print(f"Оценка параметров: {optimizer._format_params(params)}")

        pair_score = generate_and_evaluate_pair_scores(params, dataset_info)

        if verbose:
            print(f"PAIR score: {-pair_score}")

        return pair_score

    optimizer.set_objective_function(objective)

    # Запуск оптимизации
    start_time = time.time()
    results = optimizer.optimize()
    end_time = time.time()  # время окончания

    elapsed_time = end_time - start_time
    formatted_time = str(timedelta(seconds=int(elapsed_time)))

    print(f"{'='*60}")
    print("РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:")
    print(f"Лучший PAIR для {dataset_name}: {-results['best_pair']}")
    print(f"Лучшие параметры: {results['best_params']}")
    print(f"[INFO] Время работы алгоритма: {formatted_time}")
    print(f"{'='*60}")

    return results

# %%
results = {}
N_GENERATIONS = 4 # без учета начальной популяции
POPULATION_SIZE = 10
MUTATION_PROB = 0.4
TOURNAMENT_SIZE = 3


for dataset_name in datasets:
    data = datasets[dataset_name]
    results[dataset_name] = optimize_dataset_genetic(
        dataset_name=dataset_name,
        dataset_info=datasets[dataset_name],
        param_space=ctgan_space,  # или ctgan_space, или любое другое
        population_size=POPULATION_SIZE,
        n_generations=N_GENERATIONS,
        mutation_prob=MUTATION_PROB,
        tournament_size=TOURNAMENT_SIZE,
        random_seed=RANDOM_SEED,
        verbose=True,
    )
# Out:
# Универсальная генетическая оптимизация для датасета: insurance
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8657210738874138
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8916221913488881
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8911336632544833
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8755920712402007
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8678009710830676
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9157432527443623
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.903427337648926
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8606156600049095
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.915573239019054
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9194083784265246
#
# Начальная популяция:
#   Лучший PAIR: 0.9194083784265246
#   Средний PAIR: 0.8906637838657829
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8958500576389783
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8946382776304193
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9145241218340887
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9158468288884447
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8830159386219445
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9214145644652922
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9107708197080985
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9188844900475214
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9026008970459422
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9139000186252275
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0005', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8996933408591582
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9122789390515899
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9087893361495004
# Оценка параметров: {'discriminator_lr': '0.0012000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9192587807714844
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0029000000000000002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.906447800893547
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9242398191853454
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9244767470910827
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9232509854311126
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9170016462669629
# Оценка параметров: {'discriminator_lr': '0.0012000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9153144399514502
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9157708862236541
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.90879797559547
# Оценка параметров: {'discriminator_lr': '0.0009000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9227388028261347
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9183206313920885
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9175199532768651
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.917127359686817
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '5.7e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9215933860211618
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9205342676013822
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9202823315702656
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '5.0999999999999995e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9115188696454579
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9132844891351999
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9186849224384761
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9195378118524973
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9101130259277275
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9229635009393982
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9108474750266303
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9110194879388757
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9255184478937171
# Оценка параметров: {'discriminator_lr': '0.0009000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9162339137219527
# Оценка параметров: {'discriminator_lr': '0.0018000000000000002', 'generator_lr': '0.00075', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '5.7e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9070117917569176
#
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR: 0.9255184478937171
# Лучшие параметры: {'discriminator_lr': np.float64(0.0011), 'generator_lr': np.float64(0.0002), 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1e-06), 'discriminator_decay': np.float64(2e-06), 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR для insurance: 0.9255184478937171
# Лучшие параметры: {'discriminator_lr': np.float64(0.0011), 'generator_lr': np.float64(0.0002), 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1e-06), 'discriminator_decay': np.float64(2e-06), 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 1:30:29
# --------------------------------------------------
# Универсальная генетическая оптимизация для датасета: my_regression
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7995342192403282
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8190522835695421
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7396007616487671
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7821952819892051
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7229538790437205
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8405529378387656
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8277763206160059
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.812743539729161
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8533587459550596
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9136558784355948
#
# Начальная популяция:
#   Лучший PAIR: 0.9136558784355948
#   Средний PAIR: 0.8111423848066149
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.797086322029059
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7864255670687399
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8708528905877376
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8926812617622414
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.0008', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8544520962658219
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8515023956439256
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8391240341943059
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8778356286669924
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7790118518858172
# Оценка параметров: {'discriminator_lr': '0.0010500000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8634061464815259
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.0010500000000000002', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8912094500112856
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8951167387641155
# Оценка параметров: {'discriminator_lr': '0.0010500000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8842495846384629
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8696353660120507
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00025', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8765719731099204
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8812294907513851
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8718489099158936
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8625431968704002
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8626532422562588
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8852081888815104
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8811059294176142
# Оценка параметров: {'discriminator_lr': '0.0014500000000000001', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7763631973772509
# Оценка параметров: {'discriminator_lr': '0.00095', 'generator_lr': '0.00015000000000000001', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.822876956856684
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9009931491691209
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8788736328150423
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8820960070094044
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '5.0999999999999995e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9031292230494515
# Оценка параметров: {'discriminator_lr': '0.0010500000000000002', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8673253802299311
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8624117854612615
# Оценка параметров: {'discriminator_lr': '0.0013000000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '6.2e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8764072004799243
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '5.0999999999999995e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8693896685191443
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.5e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8060971263635553
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8997276531494715
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8166211839354638
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8909467842565215
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8877454177580993
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.893250812194221
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8712575522351685
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8800565475072729
# Оценка параметров: {'discriminator_lr': '0.00185', 'generator_lr': '0.0005', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.749177281962463
#
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR: 0.9136558784355948
# Лучшие параметры: {'discriminator_lr': np.float64(0.0011), 'generator_lr': np.float64(0.0002), 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1e-06), 'discriminator_decay': np.float64(2e-06), 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR для my_regression: 0.9136558784355948
# Лучшие параметры: {'discriminator_lr': np.float64(0.0011), 'generator_lr': np.float64(0.0002), 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1e-06), 'discriminator_decay': np.float64(2e-06), 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 0:57:12
# --------------------------------------------------
# Универсальная генетическая оптимизация для датасета: two_moons
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8331693955642715
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.873037121877421
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.933088296427078
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9024747486724967
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8045116561698938
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.6407530053420959
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.893501893572244
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7109338528793069
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9532812326905056
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9239988288010504
#
# Начальная популяция:
#   Лучший PAIR: 0.9532812326905056
#   Средний PAIR: 0.8468750031996365
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# ...
# PAIR score: 0.8366841204091772
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9363637133389018
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.5999999999999997e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9128789707310564
# Оценка параметров: {'discriminator_lr': '0.0018000000000000002', 'generator_lr': '0.00445', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.6947172390668971
# Оценка параметров: {'discriminator_lr': '0.00095', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9312857674211811
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.957755672301774
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9353508820770525
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8971535927750169
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9403256046148513
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.0015500000000000002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8923266860072526
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9649467973433662
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9478037387740202
# Оценка параметров: {'discriminator_lr': '0.0016', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.4e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9273849331807659
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00045000000000000004', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9465301738495809
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9199273498023394
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9472937128522515
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9583710684172182
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9335199858197983
# Оценка параметров: {'discriminator_lr': '0.0009000000000000001', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9429154079716716
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9532982831788211
# Оценка параметров: {'discriminator_lr': '0.0005', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.6459759179065966
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7722271052181835
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9563880255173635
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9571758209826786
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '6.3e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7277776350738424
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.6e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9420400692154378
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9518988744644754
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9469109625120194
# Оценка параметров: {'discriminator_lr': '0.0012000000000000001', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '5.7e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.937944431135224
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9453603443396975
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.6204812081544853
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9475902492199967
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.2999999999999995e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9341857872607894
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9555135712656861
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9524084384074508
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9629865415563773
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9761737723601446
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '8e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.946201656825065
# Оценка параметров: {'discriminator_lr': '0.00175', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9450917237726216
#
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR: 0.9761737723601446
# Лучшие параметры: {'discriminator_lr': np.float64(0.00055), 'generator_lr': np.float64(5e-05), 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': np.float64(2.7e-06), 'discriminator_decay': np.float64(3e-06), 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR для two_moons: 0.9761737723601446
# Лучшие параметры: {'discriminator_lr': np.float64(0.00055), 'generator_lr': np.float64(5e-05), 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': np.float64(2.7e-06), 'discriminator_decay': np.float64(3e-06), 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 0:58:02
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(f"{dataset_name}: {-results[dataset_name]['best_pair']}")
# Out:
# insurance: 0.9255184478937171
# my_regression: 0.9136558784355948
# two_moons: 0.9761737723601446
