# %%
# !pip install sdv deap
# Out:
# Collecting sdv
#   Downloading sdv-1.22.1-py3-none-any.whl.metadata (14 kB)
# Collecting deap
#   Downloading deap-1.4.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting boto3<2.0.0,>=1.28 (from sdv)
#   Downloading boto3-1.38.36-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<2.0.0,>=1.31 (from sdv)
#   Downloading botocore-1.38.36-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Collecting copulas>=0.12.1 (from sdv)
#   Downloading copulas-0.12.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting ctgan>=0.11.0 (from sdv)
#   Downloading ctgan-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Downloading deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.17.0 (from sdv)
#   Downloading rdt-1.17.0-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.21.0 (from sdv)
#   Downloading sdmetrics-0.21.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.15.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (1.6.1)
# Collecting Faker>=17 (from rdt>=1.17.0->sdv)
#   Downloading faker-37.4.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# Downloading sdv-1.22.1-py3-none-any.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 7.2 MB/s eta 0:00:00
# Downloading deap-1.4.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 11.9 MB/s eta 0:00:00
# Downloading boto3-1.38.36-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 11.5 MB/s eta 0:00:00
# Downloading botocore-1.38.36-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 61.8 MB/s eta 0:00:00
# Downloading copulas-0.12.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.9 MB/s eta 0:00:00
# Downloading ctgan-0.11.0-py3-none-any.whl (24 kB)
# Downloading deepecho-0.7.0-py3-none-any.whl (27 kB)
# Downloading rdt-1.17.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 6.2 MB/s eta 0:00:00
# Downloading sdmetrics-0.21.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 kB 17.0 MB/s eta 0:00:00
# Downloading faker-37.4.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 50.6 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jmespath, Faker, deap, nvidia-cusparse-cu12, nvidia-cudnn-cu12, botocore, s3transfer, rdt, nvidia-cusolver-cu12, copulas, sdmetrics, boto3, deepecho, ctgan, sdv
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed Faker-37.4.0 boto3-1.38.36 botocore-1.38.36 copulas-0.12.3 ctgan-0.11.0 deap-1.4.3 deepecho-0.7.0 jmespath-1.0.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rdt-1.17.0 s3transfer-0.13.0 sdmetrics-0.21.0 sdv-1.22.1

# %%
# !unrar x data.rar
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from data.rar
#
# Creating    data                                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
import time
import pandas as pd
import numpy as np
import torch
import random
import warnings
from datetime import timedelta
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import hp
from deap import base, creator, tools, algorithms
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm

# %%
dir_datasets = 'data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_2 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_regression.csv')
real_data_4 = pd.read_csv(dir_datasets+'two_moons.csv')
real_data_5 = pd.read_csv(dir_datasets+'california_housing.csv')
real_data_6 = pd.read_csv(dir_datasets+'titanic.csv')

# Словарь датасетов для удобства
datasets = {
               'my_classification': {
                        "data": real_data_2,
                        "task": "classification",
                        "target": "target",
                        "num_columns":
                        ["feature_0", "feature_1", "feature_2", "feature_3", "feature_4"],
                        "cat_columns":
                        []
                    },
               'california_housing': {
                        "data": real_data_5,
                        "task": "regression",
                        "target": "MedHouseVal",
                        "num_columns":
                        ["MedInc",	"HouseAge",	"AveRooms",	"AveBedrms",	"Population",	"AveOccup",	"Latitude",	"Longitude"],
                        "cat_columns":
                        []
                    },
            'titanic': {
                            "data": real_data_6,
                            "task": "classification",
                            "target": "Survived",
                            "num_columns": ["Age", "Fare", "SibSp", "Parch"],
                            "cat_columns": ["Pclass", "Sex", "Embarked"]
                        },
}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете my_classification:
#  Количество строк: 900
#  Количество колонок: 6
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'target']
#  Задача: classification
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4']
#  Категориальные признаки: []
#
#  Информация о датасете california_housing:
#  Количество строк: 1200
#  Количество колонок: 9
#  Колонки: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude', 'MedHouseVal']
#  Задача: regression
#  Целевая переменная: MedHouseVal
#  Числовые признаки: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
#  Категориальные признаки: []
#
#  Информация о датасете titanic:
#  Количество строк: 712
#  Количество колонок: 12
#  Колонки: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#  Задача: classification
#  Целевая переменная: Survived
#  Числовые признаки: ['Age', 'Fare', 'SibSp', 'Parch']
#  Категориальные признаки: ['Pclass', 'Sex', 'Embarked']

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    'discriminator_lr': (4e-4, 2.1e-3, 5e-5),
    'generator_lr': (5e-5, 5e-3, 5e-5),
    'batch_size': [100, 500, 1000],
    'embedding_dim': [32, 128],
    'generator_dim': [[128, 128, 128], [128, 128, 128, 128]],
    'discriminator_dim': [[256, 256], [256, 256, 256]],
    'generator_decay': (1e-6, 6.4e-6, 1e-7),
    'discriminator_decay': (1e-6, 8e-6, 1e-6),
    'log_frequency': [False, True],
    'transformation_num_type': ['CDF', 'PLE_CDF'],
    'transformation_cat_type': ['OHE']

}

# %%
import sys
import os
import builtins
import contextlib

@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        old_print = builtins.print
        builtins.print = lambda *args, **kwargs: None
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr
            builtins.print = old_print

# %%
import numpy as np
import random
from deap import base, creator, tools, algorithms
from hyperopt import hp
from sklearn.model_selection import KFold
import warnings
from contextlib import contextmanager
import sys
import os

@contextmanager
def suppress_all_output():
    """Контекстный менеджер для подавления всего вывода"""
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

class UniversalGeneticOptimizer:
    def __init__(self,
                 param_space,
                 population_size=20,
                 n_generations=10,
                 mutation_prob=0.2,
                 crossover_prob=0.8,
                 tournament_size=3,
                 random_seed=42,
                 verbose=True):
        """
        Универсальный генетический алгоритм для оптимизации гиперпараметров

        Args:
            param_space: словарь с определением пространства поиска
            population_size: размер популяции
            n_generations: количество поколений
            mutation_prob: вероятность мутации
            crossover_prob: вероятность скрещивания
            tournament_size: размер турнира для отбора
            random_seed: seed для воспроизводимости
            verbose: вывод прогресса
        """
        self.param_space = param_space
        self.population_size = population_size
        self.n_generations = n_generations
        self.mutation_prob = mutation_prob
        self.crossover_prob = crossover_prob
        self.tournament_size = tournament_size
        self.verbose = verbose

        # Устанавливаем seed
        random.seed(random_seed)
        np.random.seed(random_seed)

        # Анализируем пространство параметров
        self.param_info = self._analyze_param_space()

        # Настройка DEAP
        self._setup_deap()

        # История оптимизации
        self.history = {
            'generations': [],
            'best_fitness': [],
            'avg_fitness': [],
            'best_params': []
        }

    def _analyze_param_space(self):
        """Анализ пространства параметров для определения их типов"""
        param_info = {}

        for param_name, param_def in self.param_space.items():
            if isinstance(param_def, tuple) and len(param_def) == 2:
                # Непрерывный параметр (min, max)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': None
                }
            elif isinstance(param_def, tuple) and len(param_def) == 3:
                # Непрерывный параметр с квантованием (min, max, step)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': param_def[2]
                }
            elif isinstance(param_def, list):
                # Дискретный параметр
                param_info[param_name] = {
                    'type': 'discrete',
                    'values': param_def
                }
            else:
                raise ValueError(f"Неподдерживаемый тип параметра: {param_name}")

        return param_info

    def _setup_deap(self):
        """Настройка DEAP для минимизации"""
        # Создаем класс для фитнеса (минимизация)
        if not hasattr(creator, "FitnessMin"):
            creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
        if not hasattr(creator, "Individual"):
            creator.create("Individual", list, fitness=creator.FitnessMin)

        self.toolbox = base.Toolbox()

        # Регистрируем функции создания индивидов
        self.toolbox.register("individual", self._create_individual)
        self.toolbox.register("population", tools.initRepeat, list, self.toolbox.individual)

        # Регистрируем операторы
        self.toolbox.register("mate", self._crossover)
        self.toolbox.register("mutate", self._mutate)
        self.toolbox.register("select", tools.selTournament, tournsize=self.tournament_size)
        self.toolbox.register("evaluate", self._evaluate_individual)

    def _create_individual(self):
        """Создание случайного индивида"""
        individual = []

        for param_name in self.param_space.keys():
            info = self.param_info[param_name]

            if info['type'] == 'continuous':
                # Непрерывный параметр
                value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                if info['quantization'] is not None:
                    # Применяем квантование
                    value = round(value / info['quantization']) * info['quantization']
                    value = np.clip(value, info['min'], info['max'])
                individual.append(value)

            elif info['type'] == 'discrete':
                # Дискретный параметр - сохраняем индекс
                individual.append(np.random.randint(len(info['values'])))

        return creator.Individual(individual)

    def _decode_individual(self, individual):
        """Декодирование индивида в параметры"""
        params = {}

        for i, param_name in enumerate(self.param_space.keys()):
            info = self.param_info[param_name]

            if info['type'] == 'continuous':
                params[param_name] = individual[i]
            elif info['type'] == 'discrete':
                params[param_name] = info['values'][int(individual[i])]

        return params

    def _crossover(self, ind1, ind2):
        """One-point crossover"""
        # Выбираем случайную точку разреза
        if len(ind1) > 1:
            crossover_point = random.randint(1, len(ind1) - 1)
        else:
            crossover_point = 1

        # Обмениваемся частями после точки разреза
        for i in range(crossover_point, len(ind1)):
            ind1[i], ind2[i] = ind2[i], ind1[i]

        return ind1, ind2

    def _mutate(self, individual):
        """Операция мутации - случайное значение из пространства поиска"""
        for i, param_name in enumerate(self.param_space.keys()):
            if random.random() < self.mutation_prob:
                info = self.param_info[param_name]

                if info['type'] == 'continuous':
                    # Генерируем новое случайное значение
                    new_value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                    if info['quantization'] is not None:
                        new_value = round(new_value / info['quantization']) * info['quantization']
                        new_value = np.clip(new_value, info['min'], info['max'])
                    individual[i] = new_value

                elif info['type'] == 'discrete':
                    # Выбираем случайный индекс
                    individual[i] = np.random.randint(len(info['values']))

        return individual,

    def _evaluate_individual(self, individual):
        """Оценка индивида"""

        params = self._decode_individual(individual)
        pair_score = self.objective_function(params)

        return pair_score,

    def set_objective_function(self, objective_func):
        """Установка целевой функции"""
        self.objective_function = objective_func

    def optimize(self):
        """Запуск оптимизации"""
        if self.verbose:
            print(f"Пространство параметров:")
            for param_name, info in self.param_info.items():
                if info['type'] == 'continuous':
                    quant_info = f", квантование: {info['quantization']}" if info['quantization'] else ""
                    print(f"  {param_name}: непрерывный ({info['min']}, {info['max']}){quant_info}")
                else:
                    print(f"  {param_name}: дискретный {info['values']}")
            print(f"Размер популяции: {self.population_size}")
            print(f"Количество поколений: {self.n_generations}")
            print(f"Вероятность мутации: {self.mutation_prob}")
            print(f"Вероятность скрещивания: {self.crossover_prob}")
            print("="*60)

        # Создание начальной популяции
        population = self.toolbox.population(n=self.population_size)

        # Оценка начальной популяции
        fitnesses = list(map(self.toolbox.evaluate, population))
        for ind, fit in zip(population, fitnesses):
            ind.fitness.values = fit

        if self.verbose:
            self._print_population_info(population, 0, "Начальная популяция")

        # Эволюция
        for generation in range(1, self.n_generations + 1):
            if self.verbose:
                print(f"\n{'='*20} ПОКОЛЕНИЕ {generation} {'='*20}")

            # Отбор родителей
            parents = self.toolbox.select(population, len(population))


            # Создание потомков
            offspring = list(map(self.toolbox.clone, parents))

            # Скрещивание (one-point crossover)
            for child1, child2 in zip(offspring[::2], offspring[1::2]):
                if random.random() < self.crossover_prob:
                    self.toolbox.mate(child1, child2)
                    del child1.fitness.values
                    del child2.fitness.values

            # Мутация
            for mutant in offspring:
                if random.random() < self.mutation_prob:
                    self.toolbox.mutate(mutant)
                    del mutant.fitness.values

            # Оценка потомков
            invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
            fitnesses = map(self.toolbox.evaluate, invalid_ind)
            for ind, fit in zip(invalid_ind, fitnesses):
                ind.fitness.values = fit

            # ЭЛИТАРНАЯ СТРАТЕГИЯ: объединение родителей и потомков
            combined_population = population + offspring
            population = tools.selBest(combined_population, self.population_size)


            # Сохранение статистики
            self._save_generation_stats(population, generation)


        # Лучший индивид
        best_individual = tools.selBest(population, 1)[0]
        best_params = self._decode_individual(best_individual)
        best_fitness = best_individual.fitness.values[0]


        return {
            'best_params': best_params,
            'best_pair': best_fitness,
            'pair_diff_from_optimal': best_fitness,
            'history': self.history
        }

    def _format_params(self, params):
        """Форматирование параметров для вывода"""
        formatted = {}
        for key, value in params.items():
            if isinstance(value, float):
                formatted[key] = f"{value}"
            else:
                formatted[key] = value
        return formatted

    def _print_population_info(self, population, generation, title):
        """Вывод информации о популяции"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)

        print(f"\n{title}:")
        print(f"  Лучший PAIR: {-best_fitness}")
        print(f"  Средний PAIR: {-avg_fitness}")


    def _save_generation_stats(self, population, generation):
        """Сохранение статистики поколения"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)

        best_individual = min(population, key=lambda x: x.fitness.values[0])
        best_params = self._decode_individual(best_individual)

        self.history['generations'].append(generation)
        self.history['best_fitness'].append(best_fitness)
        self.history['avg_fitness'].append(avg_fitness)
        self.history['best_params'].append(best_params)

# %%
def evaluate_pair(real_data, synthetic_data, cat_columns):
    # One-hot энкодинг для категориальных признаков
    real_data_encoded = pd.get_dummies(real_data, columns=cat_columns, drop_first=True)

    if hasattr(synthetic_data, "dataframe"):
        synthetic = synthetic_data.dataframe()
    else:
        synthetic = synthetic_data

    synthetic_encoded = pd.get_dummies(synthetic, columns=cat_columns, drop_first=True)

    # После get_dummies
    real_data_encoded = real_data_encoded.astype(float)
    synthetic_encoded = synthetic_encoded.astype(float)

    # Корреляции
    corr_real = real_data_encoded.corr()
    corr_synth = synthetic_encoded.corr()

    # Абсолютное отклонение корреляций
    pairwise_diff = np.abs(corr_real - corr_synth)

    # Усреднённое отклонение
    mean_diff = pairwise_diff.mean().mean()

    # Проверяем на NaN
    if np.isnan(mean_diff):
        print("Warning: mean_diff is NaN, returning 0")
        return 0.0

    return 1 - mean_diff

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_pair_scores(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    columns_dataset = dataset_info['num_columns'] + dataset_info['cat_columns'] + [dataset_info['target']]
    data = process_data(dataset_info['data'][columns_dataset], dataset_info['num_columns'], dataset_info['cat_columns'],
                        'None', 'None')

    kf = KFold(n_splits=n_splits, shuffle=False)
    pair_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        cat_columns = dataset_info['cat_columns'].copy()
        if dataset_info["task"] == 'classification':
            cat_columns.append(dataset_info['target'])
        for col in dataset_info['cat_columns']:
            metadata.update_column(col, sdtype='categorical')

        # Создание и обучение CTGAN с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        # Вычисляем Pair-score
        score = evaluate_pair(
            test_data,
            synthetic_data,
            cat_columns
        )
        pair_scores.append(score)

    return -np.mean(pair_scores) #Возращаем *(-1) для минимизации

# %%
def optimize_dataset_genetic(dataset_name, dataset_info, param_space,
                           population_size=20, n_generations=10,
                           mutation_prob=0.2, crossover_prob=1.0,
                           tournament_size=3, random_seed=None, verbose=True):
    """
    Универсальная оптимизация датасета с использованием генетического алгоритма

    Args:
        dataset_name: название датасета
        dataset: информация о датасете
        param_space: пространство поиска параметров
        population_size: размер популяции
        n_generations: количество поколений
        mutation_prob: вероятность мутации
        crossover_prob: вероятность скрещивания
        tournament_size: размер турнира
        random_seed: seed для воспроизводимости
        verbose: вывод прогресса
    """
    print(f"Генетическая оптимизация для датасета: {dataset_name}")

    # Создание оптимизатора
    optimizer = UniversalGeneticOptimizer(
        param_space=param_space,
        population_size=population_size,
        n_generations=n_generations,
        mutation_prob=mutation_prob,
        crossover_prob=crossover_prob,
        tournament_size=tournament_size,
        random_seed=random_seed,
        verbose=verbose
    )

    # Определение целевой функции
    def objective(params):
        if verbose:
            print(f"Оценка параметров: {optimizer._format_params(params)}")

        pair_score = generate_and_evaluate_pair_scores(params, dataset_info)

        if verbose:
            print(f"PAIR score: {-pair_score}")

        return pair_score

    optimizer.set_objective_function(objective)

    # Запуск оптимизации
    start_time = time.time()
    results = optimizer.optimize()
    end_time = time.time()  # время окончания

    elapsed_time = end_time - start_time
    formatted_time = str(timedelta(seconds=int(elapsed_time)))

    print(f"{'='*60}")
    print("РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:")
    print(f"Лучший PAIR для {dataset_name}: {-results['best_pair']}")
    print(f"Лучшие параметры: {results['best_params']}")
    print(f"[INFO] Время работы алгоритма: {formatted_time}")
    print(f"{'='*60}")

    return results

# %%
results = {}
N_GENERATIONS = 4 # без учета начальной популяции
POPULATION_SIZE = 10
MUTATION_PROB = 0.4
TOURNAMENT_SIZE = 3


for dataset_name in datasets:
    data = datasets[dataset_name]
    results[dataset_name] = optimize_dataset_genetic(
        dataset_name=dataset_name,
        dataset_info=datasets[dataset_name],
        param_space=ctgan_space,  # или ctgan_space, или любое другое
        population_size=POPULATION_SIZE,
        n_generations=N_GENERATIONS,
        mutation_prob=MUTATION_PROB,
        tournament_size=TOURNAMENT_SIZE,
        random_seed=RANDOM_SEED,
        verbose=True,
    )
# Out:
# Генетическая оптимизация для датасета: my_classification
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8041056488545575
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8076119817447367
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7782205369711557
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8729529857372632
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7618807003301078
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8087491494442145
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8768472678690976
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7964062428251631
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9046849265045486
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9139512518864782
#
# Начальная популяция:
#   Лучший PAIR: 0.9139512518864782
#   Средний PAIR: 0.8325410692167322
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8084183620932656
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8382989802746724
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8867757493204645
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9099521137169816
# Оценка параметров: {'discriminator_lr': '0.0019', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8083754539344494
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8692459404483645
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8042390336151474
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9010223948733431
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8386021230287791
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8867597957674987
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00025', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8777477022494783
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.91046493511561
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9201463303779985
# Оценка параметров: {'discriminator_lr': '0.002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8773572374011472
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0009000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9074350544597305
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8965615121501843
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9180382088298916
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8948703140335512
# Оценка параметров: {'discriminator_lr': '0.00115', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8806487490536115
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9004063097881758
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9031899664990926
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8857573853150571
# Оценка параметров: {'discriminator_lr': '0.0010500000000000002', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.84279591007987
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8673827330858471
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9060694159191242
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8619994190999544
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.8e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8901192357320453
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8965035092866036
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.904549684943779
# Оценка параметров: {'discriminator_lr': '0.00125', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.5e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9055963484258122
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8820661260128208
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.2e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8683575550771812
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9218370918759881
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8701737109520925
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.90932338267507
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9010193163668391
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8980866093493144
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9196771467608915
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.9164560469129533
# Оценка параметров: {'discriminator_lr': '0.0009000000000000001', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.7911608032934246
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR для my_classification: 0.9218370918759881
# Лучшие параметры: {'discriminator_lr': np.float64(0.00055), 'generator_lr': np.float64(5e-05), 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1e-06), 'discriminator_decay': np.float64(2e-06), 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 1:07:24
# ============================================================
# Генетическая оптимизация для датасета: california_housing
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8240475747811931
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8137230088959414
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8201116052802412
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8369519244058181
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8276986058407395
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8369810661566556
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8356515956035446
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8197214267249482
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8559874484874351
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8664135696963623
#
# Начальная популяция:
#   Лучший PAIR: 0.8664135696963623
#   Средний PAIR: 0.8337287825872879
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.808889286494961
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8379719632191579
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8435623039999438
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8557961817296372
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8433042535725653
# Оценка параметров: {'discriminator_lr': '0.0018000000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8577507161315546
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8345810292287332
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8507949520420839
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8403645797133562
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8682824612019976
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8609971185302769
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8591202746971977
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8671605629727369
# Оценка параметров: {'discriminator_lr': '0.0019', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.4e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8507326483917336
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8683995927069166
# Оценка параметров: {'discriminator_lr': '0.0018000000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8510401451264986
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.861812331365989
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8444780627165652
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8603844065840991
# Оценка параметров: {'discriminator_lr': '0.0005', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8585549902435236
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8566633193029695
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8384406705186823
# Оценка параметров: {'discriminator_lr': '0.0015500000000000002', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8431464347869295
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8452174328154277
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8669975466150294
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8567452118045106
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.4e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8589278254010898
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8633273088682101
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8626529894167585
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.5e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.853425918655589
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8621652999819894
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.4999999999999998e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8188655477927753
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8623329424191702
# Оценка параметров: {'discriminator_lr': '0.001', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8314278446666963
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8656481554076411
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8619484020033523
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8567828083836023
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8670557882879297
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.00015000000000000001', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8638648793088924
# Оценка параметров: {'discriminator_lr': '0.0005', 'generator_lr': '0.0004', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8382069924338765
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR для california_housing: 0.8683995927069166
# Лучшие параметры: {'discriminator_lr': np.float64(0.0006000000000000001), 'generator_lr': np.float64(0.00015000000000000001), 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1e-06), 'discriminator_decay': np.float64(4.9999999999999996e-06), 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 1:23:42
# ============================================================
# Генетическая оптимизация для датасета: titanic
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8437325336801519
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8594093003406922
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8496371496189031
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8489065877413634
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8546663236889637
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8688713709739598
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8640178217313507
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8382318110384332
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8644228199621948
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8837779488143159
#
# Начальная популяция:
#   Лучший PAIR: 0.8837779488143159
#   Средний PAIR: 0.857567366759033
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8575323324922414
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8477834967475218
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.868001974304974
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.7e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8646197186656126
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0008', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8403434102458002
# Оценка параметров: {'discriminator_lr': '0.0005', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8606638084346598
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8569749093014242
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8610844774519181
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8573572410587066
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8621707612197321
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8722583921457433
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8747392811575073
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8640962500965493
# Оценка параметров: {'discriminator_lr': '0.0012000000000000001', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '6.3e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8577633112882509
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8788854593542078
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8716848982611194
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.7e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8566952162023935
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8659056069039132
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8736548150956002
# Оценка параметров: {'discriminator_lr': '0.0007', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8728516309578794
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8701596665553213
# Оценка параметров: {'discriminator_lr': '0.0014500000000000001', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8691994054415607
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8574205564984417
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8684358278809431
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.876404840697189
# Оценка параметров: {'discriminator_lr': '0.0007', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.6999999999999998e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8621176105133234
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.4e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8675741427739503
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8746834813084381
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8714764341559457
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8848572641572856
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8688334104534272
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.9e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8589878882803093
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.871456282700215
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.001', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.9e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8777571838909782
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '6e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8779395467565726
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8622260295307441
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.001', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.869557615869483
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8812555052632932
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.874575285951305
# Оценка параметров: {'discriminator_lr': '0.0005', 'generator_lr': '0.0008', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# PAIR score: 0.8675280748447189
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший PAIR для titanic: 0.8848572641572856
# Лучшие параметры: {'discriminator_lr': np.float64(0.0004), 'generator_lr': np.float64(0.0002), 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1.8e-06), 'discriminator_decay': np.float64(4.9999999999999996e-06), 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 0:52:17
# ============================================================

# %%
for dataset_name in datasets:
    print(f"{dataset_name}: {-results[dataset_name]['best_pair']}")
# Out:
# my_classification: 0.9218370918759881
# california_housing: 0.8683995927069166
# titanic: 0.8848572641572856
