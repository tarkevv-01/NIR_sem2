# %%
# !pip install sdv deap
# Out:
# Collecting sdv
#   Downloading sdv-1.22.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: deap in /usr/local/lib/python3.11/dist-packages (1.4.3)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.26.4)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Collecting copulas>=0.12.1 (from sdv)
#   Downloading copulas-0.12.3-py3-none-any.whl.metadata (9.5 kB)
# Collecting ctgan>=0.11.0 (from sdv)
#   Downloading ctgan-0.11.0-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.7.0 (from sdv)
#   Downloading deepecho-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.17.0 (from sdv)
#   Downloading rdt-1.17.0-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.21.0 (from sdv)
#   Downloading sdmetrics-0.21.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.15.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (1.2.2)
# Collecting Faker>=17 (from rdt>=1.17.0->sdv)
#   Downloading faker-37.4.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->ctgan>=0.11.0->sdv)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.0->sdv) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# Downloading sdv-1.22.1-py3-none-any.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Downloading copulas-0.12.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.2 MB/s eta 0:00:00
# Downloading ctgan-0.11.0-py3-none-any.whl (24 kB)
# Downloading deepecho-0.7.0-py3-none-any.whl (27 kB)
# Downloading rdt-1.17.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 4.1 MB/s eta 0:00:00
# Downloading sdmetrics-0.21.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.5/193.5 kB 10.0 MB/s eta 0:00:00
# Downloading faker-37.4.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.9 MB/s eta 0:00:0000:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, Faker, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, rdt, copulas, sdmetrics, deepecho, ctgan, sdv
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed Faker-37.4.0 copulas-0.12.3 ctgan-0.11.0 deepecho-0.7.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rdt-1.17.0 sdmetrics-0.21.0 sdv-1.22.1

# %%
# !unrar x data.rar

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, rand, hp, Trials, STATUS_OK
from hyperopt import space_eval
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
from sklearn.metrics import f1_score, r2_score
from xgboost import XGBClassifier, XGBRegressor
import time
from datetime import timedelta

# %%
dir_datasets = '/kaggle/input/nir02-main/data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_2 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_regression.csv')
real_data_4 = pd.read_csv(dir_datasets+'two_moons.csv')
real_data_5 = pd.read_csv(dir_datasets+'california_housing.csv')
real_data_6 = pd.read_csv(dir_datasets+'titanic.csv')

# Словарь датасетов для удобства
datasets = {
        'insurance': {
                        "data": real_data_1,
                        "task": "regression",
                        "target": "expenses",
                        "num_columns":
                        ["age", "bmi", "children"],
                        "cat_columns":
                        ["sex", "smoker", "region"]
                    },
        'my_classification': {
                        "data": real_data_2,
                        "task": "classification",
                        "target": "target",
                        "num_columns":
                        ["feature_0", "feature_1", "feature_2", "feature_3", "feature_4"],
                        "cat_columns":
                        []
                    },
        'my_regression': {
                        "data": real_data_3,
                        "task": "regression",
                        "target": "target",
                        "num_columns":
                        ["feature_0", "feature_1", "feature_2", "feature_3"],
                        "cat_columns":
                        []
                    },

        'two_moons': {
                        "data": real_data_4,
                        "task": "classification",
                        "target": "label",
                        "num_columns":
                        ["x1", "x2"],
                        "cat_columns": 
                        []
                    },
        'california_housing': {
                        "data": real_data_5,
                        "task": "regression",
                        "target": "MedHouseVal",
                        "num_columns":
                        ["MedInc",	"HouseAge",	"AveRooms",	"AveBedrms",	"Population",	"AveOccup",	"Latitude",	"Longitude"],
                        "cat_columns": 
                        []
                    },
        'titanic': {
                        "data": real_data_6,
                        "task": "classification",
                        "target": "Survived",
                        "num_columns": ["Age", "Fare", "SibSp", "Parch"],
                        "cat_columns": ["Pclass", "Sex", "Embarked"]
                    },

}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете insurance:
#  Количество строк: 1338
#  Количество колонок: 7
#  Колонки: ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']
#  Задача: regression
#  Целевая переменная: expenses
#  Числовые признаки: ['age', 'bmi', 'children']
#  Категориальные признаки: ['sex', 'smoker', 'region']
#
#  Информация о датасете my_classification:
#  Количество строк: 900
#  Количество колонок: 6
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'target']
#  Задача: classification
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4']
#  Категориальные признаки: []
#
#  Информация о датасете my_regression:
#  Количество строк: 900
#  Количество колонок: 5
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'target']
#  Задача: regression
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3']
#  Категориальные признаки: []
#
#  Информация о датасете two_moons:
#  Количество строк: 900
#  Количество колонок: 3
#  Колонки: ['x1', 'x2', 'label']
#  Задача: classification
#  Целевая переменная: label
#  Числовые признаки: ['x1', 'x2']
#  Категориальные признаки: []
#
#  Информация о датасете california_housing:
#  Количество строк: 1200
#  Количество колонок: 9
#  Колонки: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude', 'MedHouseVal']
#  Задача: regression
#  Целевая переменная: MedHouseVal
#  Числовые признаки: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
#  Категориальные признаки: []
#
#  Информация о датасете titanic:
#  Количество строк: 712
#  Количество колонок: 12
#  Колонки: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#  Задача: classification
#  Целевая переменная: Survived
#  Числовые признаки: ['Age', 'Fare', 'SibSp', 'Parch']
#  Категориальные признаки: ['Pclass', 'Sex', 'Embarked']

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    'discriminator_lr': (4e-4, 2.1e-3, 5e-5),
    'generator_lr': (5e-5, 5e-3, 5e-5),
    'batch_size': [100, 500, 1000],
    'embedding_dim': [32, 128],
    'generator_dim': [[128, 128, 128], [128, 128, 128, 128]],
    'discriminator_dim': [[256, 256], [256, 256, 256]],
    'generator_decay': (1e-6, 6.4e-6, 1e-7),
    'discriminator_decay': (1e-6, 8e-6, 1e-6),
    'log_frequency': [False, True],
    'transformation_num_type': ['CDF', 'PLE_CDF'],
    'transformation_cat_type': ['OHE']
}

# %%
import numpy as np
import random
from deap import base, creator, tools, algorithms
from hyperopt import hp
from sklearn.model_selection import KFold
import warnings
from contextlib import contextmanager
import sys
import os

@contextmanager
def suppress_all_output():
    """Контекстный менеджер для подавления всего вывода"""
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

class UniversalGeneticOptimizer:
    def __init__(self,
                 param_space,
                 population_size=20,
                 n_generations=10,
                 mutation_prob=0.2,
                 crossover_prob=0.8,
                 tournament_size=3,
                 random_seed=42,
                 verbose=True):
        """
        Универсальный генетический алгоритм для оптимизации гиперпараметров

        Args:
            param_space: словарь с определением пространства поиска
            population_size: размер популяции
            n_generations: количество поколений
            mutation_prob: вероятность мутации
            crossover_prob: вероятность скрещивания
            tournament_size: размер турнира для отбора
            random_seed: seed для воспроизводимости
            verbose: вывод прогресса
        """
        self.param_space = param_space
        self.population_size = population_size
        self.n_generations = n_generations
        self.mutation_prob = mutation_prob
        self.crossover_prob = crossover_prob
        self.tournament_size = tournament_size
        self.verbose = verbose

        # Устанавливаем seed
        random.seed(random_seed)
        np.random.seed(random_seed)

        # Анализируем пространство параметров
        self.param_info = self._analyze_param_space()

        # Настройка DEAP
        self._setup_deap()

        # История оптимизации
        self.history = {
            'generations': [],
            'best_fitness': [],
            'avg_fitness': [],
            'best_params': []
        }

    def _analyze_param_space(self):
        """Анализ пространства параметров для определения их типов"""
        param_info = {}

        for param_name, param_def in self.param_space.items():
            if isinstance(param_def, tuple) and len(param_def) == 2:
                # Непрерывный параметр (min, max)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': None
                }
            elif isinstance(param_def, tuple) and len(param_def) == 3:
                # Непрерывный параметр с квантованием (min, max, step)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': param_def[2]
                }
            elif isinstance(param_def, list):
                # Дискретный параметр
                param_info[param_name] = {
                    'type': 'discrete',
                    'values': param_def
                }
            else:
                raise ValueError(f"Неподдерживаемый тип параметра: {param_name}")

        return param_info

    def _setup_deap(self):
        """Настройка DEAP для минимизации"""
        # Создаем класс для фитнеса (минимизация)
        if not hasattr(creator, "FitnessMin"):
            creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
        if not hasattr(creator, "Individual"):
            creator.create("Individual", list, fitness=creator.FitnessMin)

        self.toolbox = base.Toolbox()

        # Регистрируем функции создания индивидов
        self.toolbox.register("individual", self._create_individual)
        self.toolbox.register("population", tools.initRepeat, list, self.toolbox.individual)

        # Регистрируем операторы
        self.toolbox.register("mate", self._crossover)
        self.toolbox.register("mutate", self._mutate)
        self.toolbox.register("select", tools.selTournament, tournsize=self.tournament_size)
        self.toolbox.register("evaluate", self._evaluate_individual)

    def _create_individual(self):
        """Создание случайного индивида"""
        individual = []

        for param_name in self.param_space.keys():
            info = self.param_info[param_name]

            if info['type'] == 'continuous':
                # Непрерывный параметр
                value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                if info['quantization'] is not None:
                    # Применяем квантование
                    value = round(value / info['quantization']) * info['quantization']
                    value = np.clip(value, info['min'], info['max'])
                individual.append(value)

            elif info['type'] == 'discrete':
                # Дискретный параметр - сохраняем индекс
                individual.append(np.random.randint(len(info['values'])))

        return creator.Individual(individual)

    def _decode_individual(self, individual):
        """Декодирование индивида в параметры"""
        params = {}

        for i, param_name in enumerate(self.param_space.keys()):
            info = self.param_info[param_name]

            if info['type'] == 'continuous':
                params[param_name] = individual[i]
            elif info['type'] == 'discrete':
                params[param_name] = info['values'][int(individual[i])]

        return params

    def _crossover(self, ind1, ind2):
        """One-point crossover"""
        # Выбираем случайную точку разреза
        if len(ind1) > 1:
            crossover_point = random.randint(1, len(ind1) - 1)
        else:
            crossover_point = 1

        # Обмениваемся частями после точки разреза
        for i in range(crossover_point, len(ind1)):
            ind1[i], ind2[i] = ind2[i], ind1[i]

        return ind1, ind2

    def _mutate(self, individual):
        """Операция мутации - случайное значение из пространства поиска"""
        for i, param_name in enumerate(self.param_space.keys()):
            if random.random() < self.mutation_prob:
                info = self.param_info[param_name]

                if info['type'] == 'continuous':
                    # Генерируем новое случайное значение
                    new_value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                    if info['quantization'] is not None:
                        new_value = round(new_value / info['quantization']) * info['quantization']
                        new_value = np.clip(new_value, info['min'], info['max'])
                    individual[i] = new_value

                elif info['type'] == 'discrete':
                    # Выбираем случайный индекс
                    individual[i] = np.random.randint(len(info['values']))

        return individual,

    def _evaluate_individual(self, individual):
        """Оценка индивида"""

        params = self._decode_individual(individual)
        score = self.objective_function(params)

        return score,

    def set_objective_function(self, objective_func):
        """Установка целевой функции"""
        self.objective_function = objective_func

    def optimize(self):
        """Запуск оптимизации"""
        if self.verbose:
            print(f"Пространство параметров:")
            for param_name, info in self.param_info.items():
                if info['type'] == 'continuous':
                    quant_info = f", квантование: {info['quantization']}" if info['quantization'] else ""
                    print(f"  {param_name}: непрерывный ({info['min']}, {info['max']}){quant_info}")
                else:
                    print(f"  {param_name}: дискретный {info['values']}")
            print(f"Размер популяции: {self.population_size}")
            print(f"Количество поколений: {self.n_generations}")
            print(f"Вероятность мутации: {self.mutation_prob}")
            print(f"Вероятность скрещивания: {self.crossover_prob}")
            print("="*60)

        # Создание начальной популяции
        population = self.toolbox.population(n=self.population_size)

        # Оценка начальной популяции
        fitnesses = list(map(self.toolbox.evaluate, population))
        for ind, fit in zip(population, fitnesses):
            ind.fitness.values = fit

        if self.verbose:
            self._print_population_info(population, 0, "Начальная популяция")

        # Эволюция
        for generation in range(1, self.n_generations + 1):
            if self.verbose:
                print(f"\n{'='*20} ПОКОЛЕНИЕ {generation} {'='*20}")

            # Отбор родителей
            parents = self.toolbox.select(population, len(population))


            # Создание потомков
            offspring = list(map(self.toolbox.clone, parents))

            # Скрещивание (one-point crossover)
            for child1, child2 in zip(offspring[::2], offspring[1::2]):
                if random.random() < self.crossover_prob:
                    self.toolbox.mate(child1, child2)
                    del child1.fitness.values
                    del child2.fitness.values

            # Мутация
            for mutant in offspring:
                if random.random() < self.mutation_prob:
                    self.toolbox.mutate(mutant)
                    del mutant.fitness.values

            # Оценка потомков
            invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
            fitnesses = map(self.toolbox.evaluate, invalid_ind)
            for ind, fit in zip(invalid_ind, fitnesses):
                ind.fitness.values = fit

            # ЭЛИТАРНАЯ СТРАТЕГИЯ: объединение родителей и потомков
            combined_population = population + offspring
            population = tools.selBest(combined_population, self.population_size)

            if self.verbose:
                sorted_combined = sorted(combined_population, key=lambda x: x.fitness.values[0])
                params = self._decode_individual(sorted_combined[0])

                print('Лучший индивид')
                print(f"ML-EFFICACY={-sorted_combined[0].fitness.values[0]}, Params={self._format_params(params)}")

            # Сохранение статистики
            self._save_generation_stats(population, generation)


        # Лучший индивид
        best_individual = tools.selBest(population, 1)[0]
        best_params = self._decode_individual(best_individual)
        best_fitness = best_individual.fitness.values[0]


        return {
            'best_params': best_params,
            'best_ml_eff': best_fitness,
            'ml_eff_diff_from_optimal': best_fitness,
            'history': self.history
        }

    def _format_params(self, params):
        """Форматирование параметров для вывода"""
        formatted = {}
        for key, value in params.items():
            if isinstance(value, float):
                formatted[key] = f"{value}"
            else:
                formatted[key] = value
        return formatted

    def _print_population_info(self, population, generation, title):
        """Вывод информации о популяции"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)

        print(f"\n{title}:")
        print(f"  Лучший ML-EFFICACY: {-best_fitness}")
        print(f"  Средний ML-EFFICACY: {-avg_fitness}")


    def _save_generation_stats(self, population, generation):
        """Сохранение статистики поколения"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)

        best_individual = min(population, key=lambda x: x.fitness.values[0])
        best_params = self._decode_individual(best_individual)

        self.history['generations'].append(generation)
        self.history['best_fitness'].append(best_fitness)
        self.history['avg_fitness'].append(avg_fitness)
        self.history['best_params'].append(best_params)

# %%
def evaluate_ml_efficacy(real_train, synthetic_train, real_test, target_column, num_columns, cat_columns, task_type='classification'):
    """
    Вычисляет ML-Efficacy метрику

    Args:
        real_train: реальные тренировочные данные
        synthetic_train: синтетические тренировочные данные
        real_test: реальные тестовые данные
        target_column: название целевой колонки
        task_type: 'classification' или 'regression'

    Returns:
        ml_efficacy_score: отношение качества модели на синтетических данных к качеству на реальных
    """

    # Подготовка данных
    real_train_copy = real_train.copy()

    # Обработка синтетических данных (если это объект с методом dataframe)
    if hasattr(synthetic_train, "dataframe"):
        synthetic_train = synthetic_train.dataframe()
    synthetic_train_copy = synthetic_train.copy()

    real_test_copy = real_test.copy()

    # Определение категориальных колонок (исключая целевую)
    feature_columns = num_columns
    categorical_columns = cat_columns

    # Label Encoding для категориальных признаков
    label_encoders = {}
    for col in categorical_columns:
        le = LabelEncoder()
        # Обучаем на реальных данных
        combined_values = pd.concat([real_train_copy[col], real_test_copy[col]]).astype(str)
        le.fit(combined_values)
        label_encoders[col] = le

        # Применяем к реальным данным
        real_train_copy[col] = le.transform(real_train_copy[col].astype(str))
        real_test_copy[col] = le.transform(real_test_copy[col].astype(str))

        # Применяем к синтетическим данным, обрабатываем неизвестные значения
        synthetic_values = synthetic_train_copy[col].astype(str)
        known_values = set(le.classes_)
        synthetic_values = synthetic_values.apply(lambda x: x if x in known_values else le.classes_[0])
        synthetic_train_copy[col] = le.transform(synthetic_values)

    # Разделение на признаки и целевую переменную
    X_real_train = real_train_copy.drop(columns=[target_column])
    y_real_train = real_train_copy[target_column]

    X_synthetic_train = synthetic_train_copy.drop(columns=[target_column])
    y_synthetic_train = synthetic_train_copy[target_column]

    X_real_test = real_test_copy.drop(columns=[target_column])
    y_real_test = real_test_copy[target_column]

    # Выбор модели в зависимости от типа задачи
    if task_type == 'classification':
        model_real = XGBClassifier(random_state=42, eval_metric='logloss')
        model_synthetic = XGBClassifier(random_state=42, eval_metric='logloss')
        score_func = f1_score
        score_kwargs = {'average': 'weighted'} if len(np.unique(y_real_train)) > 2 else {'average': 'binary'}
    else:  # regression
        model_real = XGBRegressor(random_state=42)
        model_synthetic = XGBRegressor(random_state=42)
        score_func = r2_score
        score_kwargs = {}

    try:
        # Обучение модели на реальных данных
        model_real.fit(X_real_train, y_real_train)
        y_pred_real = model_real.predict(X_real_test)
        score_real = score_func(y_real_test, y_pred_real, **score_kwargs)

        # Обучение модели на синтетических данных
        model_synthetic.fit(X_synthetic_train, y_synthetic_train)
        y_pred_synthetic = model_synthetic.predict(X_real_test)
        score_synthetic = score_func(y_real_test, y_pred_synthetic, **score_kwargs)

        # Вычисление ML-Efficacy
        if score_real > 0:
            ml_efficacy = score_synthetic / score_real
        else:
            ml_efficacy = 0.0

        return ml_efficacy

    except Exception as e:
        print(f"Ошибка при вычислении ML-Efficacy: {e}")
        return 0.0

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_ml_efficacy(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    # Извлекаем информацию о задаче и целевой переменной из dataset_info
    task_type = dataset_info['task']
    target_column = dataset_info['target']

    columns_dataset = dataset_info['num_columns'] + dataset_info['cat_columns'] + [dataset_info['target']]
    data = process_data(dataset_info['data'][columns_dataset], dataset_info['num_columns'], dataset_info['cat_columns'],
                        'None', 'None')

    kf = KFold(n_splits=n_splits, shuffle=False)
    ml_efficacy_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение CTGAN с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        num_columns = dataset_info['num_columns'].copy()
        cat_columns = dataset_info['cat_columns'].copy()
        if dataset_info["task"] == 'classification':
            cat_columns.append(dataset_info['target'])

        # Вычисляем ML-Efficacy
        score = evaluate_ml_efficacy(
            real_train=train_data,
            synthetic_train=synthetic_data,
            real_test=test_data,
            target_column=target_column,
            num_columns = num_columns,
            cat_columns = cat_columns,
            task_type=task_type
        )
        ml_efficacy_scores.append(score)

    return -np.mean(ml_efficacy_scores) #Возращаем *(-1) для минимизации

# %%
def optimize_dataset_genetic(dataset_name, dataset_info, param_space,
                           population_size=20, n_generations=10,
                           mutation_prob=0.2, crossover_prob=1.0,
                           tournament_size=3, random_seed=None, verbose=True):
    """
    Универсальная оптимизация датасета с использованием генетического алгоритма

    Args:
        dataset_name: название датасета
        dataset: информация о датасете
        param_space: пространство поиска параметров
        population_size: размер популяции
        n_generations: количество поколений
        mutation_prob: вероятность мутации
        crossover_prob: вероятность скрещивания
        tournament_size: размер турнира
        random_seed: seed для воспроизводимости
        verbose: вывод прогресса
    """
    print(f"Универсальная генетическая оптимизация для датасета: {dataset_name}")

    # Создание оптимизатора
    optimizer = UniversalGeneticOptimizer(
        param_space=param_space,
        population_size=population_size,
        n_generations=n_generations,
        mutation_prob=mutation_prob,
        crossover_prob=crossover_prob,
        tournament_size=tournament_size,
        random_seed=random_seed,
        verbose=verbose
    )

    # Определение целевой функции
    def objective(params):
        if verbose:
            print(f"Оценка параметров: {optimizer._format_params(params)}")

        ml_eff_score = generate_and_evaluate_ml_efficacy(params, dataset_info)

        if verbose:
            print(f"ML-EFFICACY score: {-ml_eff_score}")

        return ml_eff_score

    optimizer.set_objective_function(objective)

    # Запуск оптимизации
    start_time = time.time()
    results = optimizer.optimize()
    end_time = time.time()  # время окончания

    elapsed_time = end_time - start_time
    formatted_time = str(timedelta(seconds=int(elapsed_time)))

    print(f"\n{'='*60}")
    print("РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:")
    print(f"Лучший ML-EFFICACY для {dataset_name}: {-results['best_ml_eff']}")
    print(f"Лучшие параметры: {results['best_params']}")
    print(f"[INFO] Время работы алгоритма: {formatted_time}")
    print('-' * 50)

    return results

# %%
results = {}
N_GENERATIONS = 4 # без учета начальной популяции
POPULATION_SIZE = 10
MUTATION_PROB = 0.4
TOURNAMENT_SIZE = 3


for dataset_name in datasets:
    data = datasets[dataset_name]
    results[dataset_name] = optimize_dataset_genetic(
        dataset_name=dataset_name,
        dataset_info=datasets[dataset_name],
        param_space=ctgan_space , 
        population_size=POPULATION_SIZE,
        n_generations=N_GENERATIONS,
        mutation_prob=MUTATION_PROB,
        tournament_size=TOURNAMENT_SIZE,
        random_seed=RANDOM_SEED,
        verbose=True,
    )
# Out:
# Универсальная генетическая оптимизация для датасета: insurance
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -2.6619080576968606
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -1.9358881706543218
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -1.0472483643552701
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -1.0933395405257358
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -1.1598030054241426
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.6170121942612043
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.8557728105020406
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -3.903224660232482
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.5235092663898863
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.0854921177550516
#
# Начальная популяция:
#   Лучший ML-EFFICACY: -0.0854921177550516
#   Средний ML-EFFICACY: -1.3883198187796997
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -1.5090972086793173
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -1.2101184486649659
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.6582093376739324
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.07727177928597934
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.8379180711589993
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.17857602524240557
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.5519116893932904
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.6113203594729936
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.633855699163726
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.005394702248189692
# Лучший индивид
# ML-EFFICACY=0.17857602524240557, Params={'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.0005', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.15966522503007483
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.13229632073877232
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.5712368558042563
# Оценка параметров: {'discriminator_lr': '0.0012000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.0057836518967537874
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0029000000000000002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.024631273955924262
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.2512730982897196
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.29043596038974795
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.1639152911786372
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.3377353276046062
# Оценка параметров: {'discriminator_lr': '0.0012000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.13737874723094487
# Лучший индивид
# ML-EFFICACY=0.3377353276046062, Params={'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.0174563756098088
# Оценка параметров: {'discriminator_lr': '0.00115', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.7428823261341336
# Оценка параметров: {'discriminator_lr': '0.0019', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.6442450272129217
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.2993600372509742
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.24730801328407984
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.0005', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.4e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.6673315589057021
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.18451966542899564
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.05566968912454232
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.2044786612392675
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '5.199999999999999e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.16318498013125815
# Лучший индивид
# ML-EFFICACY=0.3377353276046062, Params={'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '8e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.20049983244920122
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.3715814033894702
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.12864920586044956
# Оценка параметров: {'discriminator_lr': '0.0019', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.9e-06', 'discriminator_decay': '4e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.48312756962514886
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.15007100988173042
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.23892762710277615
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.20077351955274755
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.23813843485040667
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.15928507599833952
# Оценка параметров: {'discriminator_lr': '0.0013000000000000002', 'generator_lr': '0.0001', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.5355902571309009
# Лучший индивид
# ML-EFFICACY=0.3715814033894702, Params={'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
#
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший ML-EFFICACY для insurance: 0.3715814033894702
# Лучшие параметры: {'discriminator_lr': 0.00075, 'generator_lr': 0.0002, 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': 1.2e-06, 'discriminator_decay': 1e-06, 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 1:21:27
# --------------------------------------------------
# Универсальная генетическая оптимизация для датасета: my_classification
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8164069221802578
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6188655470093224
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5960584972788018
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7746578312825019
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8318635051804742
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5964089241037668
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5694953030700549
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5860042266148334
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8732788694854219
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8940865340121885
#
# Начальная популяция:
#   Лучший ML-EFFICACY: 0.8940865340121885
#   Средний ML-EFFICACY: 0.7157126160217624
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7094707876287019
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7770481574472062
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8677051002888915
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8807740177957636
# Оценка параметров: {'discriminator_lr': '0.0019', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6391599045844384
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8291142594276151
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.4923002619902857
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8710282004747464
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5836432646120517
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8461052356144467
# Лучший индивид
# ML-EFFICACY=0.8940865340121885, Params={'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8612120019244317
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.9113273170847896
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.86418995111991
# Оценка параметров: {'discriminator_lr': '0.0015500000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.9e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.795993451125918
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00125', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8791820511683491
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8692612472707083
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8360118643799997
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8803017776490994
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8773159751148426
# Оценка параметров: {'discriminator_lr': '0.0015500000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.9031028225212974
# Лучший индивид
# ML-EFFICACY=0.9113273170847896, Params={'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.9184626015373264
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8857659787102582
# Оценка параметров: {'discriminator_lr': '0.0019', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6934400114433553
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.893361964903893
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.9110251484416545
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '6.1e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8498391402838833
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.5999999999999997e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.9103942258620318
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8746806700271241
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8698652020035276
# Оценка параметров: {'discriminator_lr': '0.0018000000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8905151281685003
# Лучший индивид
# ML-EFFICACY=0.9184626015373264, Params={'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8708434153011383
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7498186617884022
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8600934322472066
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.5e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8674646195773539
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8989139848347727
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8942109368048566
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8731471907812369
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8843570265622794
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.5999999999999997e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8826723651751488
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0009000000000000001', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6844094988400755
# Лучший индивид
# ML-EFFICACY=0.9184626015373264, Params={'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший ML-EFFICACY для my_classification: 0.9184626015373264
# Лучшие параметры: {'discriminator_lr': 0.0011, 'generator_lr': 0.0002, 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': 1e-06, 'discriminator_decay': 2e-06, 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 1:00:39
# --------------------------------------------------
# Универсальная генетическая оптимизация для датасета: my_regression
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.4402002164922896
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.4812017424866348
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -1.6423027001073163
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: -0.22665037030572974
# ...
# ML-EFFICACY score: 0.6634090558440038
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7309256439915272
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.48522835570718525
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.3698064509845458
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7570120477777346
# Лучший индивид
# ML-EFFICACY=0.8464541492857842, Params={'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0018000000000000002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7728102483627147
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.603030336564476
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8487345586128668
# Оценка параметров: {'discriminator_lr': '0.00115', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.5999999999999997e-06', 'discriminator_decay': '7e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.4220100333155719
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00215', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.806167824119752
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7263294449367526
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5973506508201425
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7654408933384674
# Оценка параметров: {'discriminator_lr': '0.00125', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '6e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5884086409867151
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.9089945436363728
# Лучший индивид
# ML-EFFICACY=0.9089945436363728, Params={'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.4542136776033637
# Оценка параметров: {'discriminator_lr': '0.0014500000000000001', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.42250161100969214
# Оценка параметров: {'discriminator_lr': '0.0009000000000000001', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6938198321602558
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5096808756266181
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7601156677621703
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00215', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8137546385049159
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.9e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6526950529944213
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.41611467777505523
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.823776970454575
# Оценка параметров: {'discriminator_lr': '0.0016', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.5e-06', 'discriminator_decay': '4e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6680031053823253
# Лучший индивид
# ML-EFFICACY=0.9089945436363728, Params={'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.7945681725883819
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5325737773307492
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00215', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.33925841485813474
# Оценка параметров: {'discriminator_lr': '0.00115', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.619577626222234
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.6690972714805884
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.4129802864542043
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.8227472613327529
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.5617932106206825
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.562566213307104
# Оценка параметров: {'discriminator_lr': '0.001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# ML-EFFICACY score: 0.806968983528407
# Лучший индивид
# ML-EFFICACY=0.9089945436363728, Params={'discriminator_lr': '0.00055', 'generator_lr': '0.00445', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ============================================================
# РЕЗУЛЬТАТЫ ОПТИМИЗАЦИИ:
# Лучший ML-EFFICACY для titanic: 0.9089945436363728
# Лучшие параметры: {'discriminator_lr': 0.00055, 'generator_lr': 0.00445, 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': 1e-06, 'discriminator_decay': 2e-06, 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 0:38:20
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(f"{dataset_name}: {-results[dataset_name]['best_ml_eff']}")
# Out:
# insurance: 0.3715814033894702
# my_classification: 0.9184626015373264
# my_regression: 0.49012781479332884
# two_moons: 0.9321233911216181
# california_housing: 0.25540188165865974
# titanic: 0.9089945436363728
