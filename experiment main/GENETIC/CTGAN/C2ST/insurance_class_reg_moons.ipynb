# %%
# !pip install sdv deap
# Out:
# Requirement already satisfied: sdv in /usr/local/lib/python3.11/dist-packages (1.22.1)
# Requirement already satisfied: deap in /usr/local/lib/python3.11/dist-packages (1.4.3)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.26.4)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.12.3)
# Requirement already satisfied: ctgan>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.17.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.21.0)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.15.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (1.2.2)
# Requirement already satisfied: Faker>=17 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (37.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.0->sdv) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)

# %%
# !unrar x data.rar

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from hyperopt import space_eval
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from deap import base, creator, tools, algorithms
import time
from datetime import timedelta

# %%
dir_datasets = '/kaggle/input/nir02-main/data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_2 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_regression.csv')
real_data_4 = pd.read_csv(dir_datasets+'two_moons.csv')
real_data_5 = pd.read_csv(dir_datasets+'california_housing.csv')
real_data_6 = pd.read_csv(dir_datasets+'titanic.csv')

# Словарь датасетов для удобства
datasets = {
        'insurance': {
                        "data": real_data_1,
                        "task": "regression",
                        "target": "expenses",
                        "num_columns":
                        ["age", "bmi", "children"],
                        "cat_columns":
                        ["sex", "smoker", "region"]
                    },
        'my_classification': {
                        "data": real_data_2,
                        "task": "classification",
                        "target": "target",
                        "num_columns":
                        ["feature_0", "feature_1", "feature_2", "feature_3", "feature_4"],
                        "cat_columns":
                        []
                    },
        'my_regression': {
                        "data": real_data_3,
                        "task": "regression",
                        "target": "target",
                        "num_columns":
                        ["feature_0", "feature_1", "feature_2", "feature_3"],
                        "cat_columns":
                        []
                    },

        'two_moons': {
                        "data": real_data_4,
                        "task": "classification",
                        "target": "label",
                        "num_columns":
                        ["x1", "x2"],
                        "cat_columns": 
                        []
                    },
        
    }
for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете insurance:
#  Количество строк: 1338
#  Количество колонок: 7
#  Колонки: ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']
#  Задача: regression
#  Целевая переменная: expenses
#  Числовые признаки: ['age', 'bmi', 'children']
#  Категориальные признаки: ['sex', 'smoker', 'region']
#
#  Информация о датасете my_classification:
#  Количество строк: 900
#  Количество колонок: 6
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'target']
#  Задача: classification
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4']
#  Категориальные признаки: []
#
#  Информация о датасете my_regression:
#  Количество строк: 900
#  Количество колонок: 5
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'target']
#  Задача: regression
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3']
#  Категориальные признаки: []
#
#  Информация о датасете two_moons:
#  Количество строк: 900
#  Количество колонок: 3
#  Колонки: ['x1', 'x2', 'label']
#  Задача: classification
#  Целевая переменная: label
#  Числовые признаки: ['x1', 'x2']
#  Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    'discriminator_lr': (4e-4, 2.1e-3, 5e-5),
    'generator_lr': (5e-5, 5e-3, 5e-5),
    'batch_size': [100, 500, 1000],
    'embedding_dim': [32, 128],
    'generator_dim': [[128, 128, 128], [128, 128, 128, 128]],
    'discriminator_dim': [[256, 256], [256, 256, 256]],
    'generator_decay': (1e-6, 6.4e-6, 1e-7),
    'discriminator_decay': (1e-6, 8e-6, 1e-6),
    'log_frequency': [False, True],
    'transformation_num_type': ['CDF', 'PLE_CDF'],
    'transformation_cat_type': ['OHE']
    
}

# %%
import numpy as np
import random
from deap import base, creator, tools, algorithms
from hyperopt import hp
from sklearn.model_selection import KFold
import warnings
from contextlib import contextmanager
import sys
import os

@contextmanager
def suppress_all_output():
    """Контекстный менеджер для подавления всего вывода"""
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

class UniversalGeneticOptimizer:
    def __init__(self, 
                 param_space,
                 population_size=20,
                 n_generations=10,
                 mutation_prob=0.2,
                 crossover_prob=0.8,
                 tournament_size=3,
                 random_seed=42,
                 verbose=True):
        """
        Универсальный генетический алгоритм для оптимизации гиперпараметров
        
        Args:
            param_space: словарь с определением пространства поиска
            population_size: размер популяции
            n_generations: количество поколений
            mutation_prob: вероятность мутации
            crossover_prob: вероятность скрещивания
            tournament_size: размер турнира для отбора
            random_seed: seed для воспроизводимости
            verbose: вывод прогресса
        """
        self.param_space = param_space
        self.population_size = population_size
        self.n_generations = n_generations
        self.mutation_prob = mutation_prob
        self.crossover_prob = crossover_prob
        self.tournament_size = tournament_size
        self.verbose = verbose
        
        # Устанавливаем seed
        random.seed(random_seed)
        np.random.seed(random_seed)
        
        # Анализируем пространство параметров
        self.param_info = self._analyze_param_space()
        
        # Настройка DEAP
        self._setup_deap()
        
        # История оптимизации
        self.history = {
            'generations': [],
            'best_fitness': [],
            'avg_fitness': [],
            'best_params': []
        }
    
    def _analyze_param_space(self):
        """Анализ пространства параметров для определения их типов"""
        param_info = {}
        
        for param_name, param_def in self.param_space.items():
            if isinstance(param_def, tuple) and len(param_def) == 2:
                # Непрерывный параметр (min, max)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': None
                }
            elif isinstance(param_def, tuple) and len(param_def) == 3:
                # Непрерывный параметр с квантованием (min, max, step)
                param_info[param_name] = {
                    'type': 'continuous',
                    'min': param_def[0],
                    'max': param_def[1],
                    'quantization': param_def[2]
                }
            elif isinstance(param_def, list):
                # Дискретный параметр
                param_info[param_name] = {
                    'type': 'discrete',
                    'values': param_def
                }
            else:
                raise ValueError(f"Неподдерживаемый тип параметра: {param_name}")
        
        return param_info
    
    def _setup_deap(self):
        """Настройка DEAP для минимизации"""
        # Создаем класс для фитнеса (минимизация)
        if not hasattr(creator, "FitnessMin"):
            creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
        if not hasattr(creator, "Individual"):
            creator.create("Individual", list, fitness=creator.FitnessMin)
        
        self.toolbox = base.Toolbox()
        
        # Регистрируем функции создания индивидов
        self.toolbox.register("individual", self._create_individual)
        self.toolbox.register("population", tools.initRepeat, list, self.toolbox.individual)
        
        # Регистрируем операторы
        self.toolbox.register("mate", self._crossover)
        self.toolbox.register("mutate", self._mutate)
        self.toolbox.register("select", tools.selTournament, tournsize=self.tournament_size)
        self.toolbox.register("evaluate", self._evaluate_individual)
    
    def _create_individual(self):
        """Создание случайного индивида"""
        individual = []
        
        for param_name in self.param_space.keys():
            info = self.param_info[param_name]
            
            if info['type'] == 'continuous':
                # Непрерывный параметр
                value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                if info['quantization'] is not None:
                    # Применяем квантование
                    value = round(value / info['quantization']) * info['quantization']
                    value = np.clip(value, info['min'], info['max'])
                individual.append(value)
            
            elif info['type'] == 'discrete':
                # Дискретный параметр - сохраняем индекс
                individual.append(np.random.randint(len(info['values'])))
        
        return creator.Individual(individual)
    
    def _decode_individual(self, individual):
        """Декодирование индивида в параметры"""
        params = {}
        
        for i, param_name in enumerate(self.param_space.keys()):
            info = self.param_info[param_name]
            
            if info['type'] == 'continuous':
                params[param_name] = individual[i]
            elif info['type'] == 'discrete':
                params[param_name] = info['values'][int(individual[i])]
        
        return params
    
    def _crossover(self, ind1, ind2):
        """One-point crossover"""
        # Выбираем случайную точку разреза
        if len(ind1) > 1:
            crossover_point = random.randint(1, len(ind1) - 1)
        else:
            crossover_point = 1
        
        # Обмениваемся частями после точки разреза
        for i in range(crossover_point, len(ind1)):
            ind1[i], ind2[i] = ind2[i], ind1[i]
        
        return ind1, ind2
    
    def _mutate(self, individual):
        """Операция мутации - случайное значение из пространства поиска"""
        for i, param_name in enumerate(self.param_space.keys()):
            if random.random() < self.mutation_prob:
                info = self.param_info[param_name]
                
                if info['type'] == 'continuous':
                    # Генерируем новое случайное значение
                    new_value = np.exp(np.random.uniform(np.log(info['min']), np.log(info['max'])))
                    if info['quantization'] is not None:
                        new_value = round(new_value / info['quantization']) * info['quantization']
                        new_value = np.clip(new_value, info['min'], info['max'])
                    individual[i] = new_value
                
                elif info['type'] == 'discrete':
                    # Выбираем случайный индекс
                    individual[i] = np.random.randint(len(info['values']))
        
        return individual,
    
    def _evaluate_individual(self, individual):
        """Оценка индивида"""
    
        params = self._decode_individual(individual)
        c2st_score = self.objective_function(params)
    
    
        return c2st_score,
    
    def set_objective_function(self, objective_func):
        """Установка целевой функции"""
        self.objective_function = objective_func
    
    def optimize(self):
        """Запуск оптимизации"""
        if self.verbose:
            print(f"Пространство параметров:")
            for param_name, info in self.param_info.items():
                if info['type'] == 'continuous':
                    quant_info = f", квантование: {info['quantization']}" if info['quantization'] else ""
                    print(f"  {param_name}: непрерывный ({info['min']}, {info['max']}){quant_info}")
                else:
                    print(f"  {param_name}: дискретный {info['values']}")
            print(f"Размер популяции: {self.population_size}")
            print(f"Количество поколений: {self.n_generations}")
            print(f"Вероятность мутации: {self.mutation_prob}")
            print(f"Вероятность скрещивания: {self.crossover_prob}")
            print("="*60)
        
        # Создание начальной популяции
        population = self.toolbox.population(n=self.population_size)
        
        # Оценка начальной популяции
        fitnesses = list(map(self.toolbox.evaluate, population))
        for ind, fit in zip(population, fitnesses):
            ind.fitness.values = fit
        
        if self.verbose:
            self._print_population_info(population, 0, "Начальная популяция")
        
        # Эволюция
        for generation in range(1, self.n_generations + 1):
            if self.verbose:
                print(f"\n{'='*20} ПОКОЛЕНИЕ {generation} {'='*20}")
                      
            # Отбор родителей
            parents = self.toolbox.select(population, len(population))
            
            
            # Создание потомков
            offspring = list(map(self.toolbox.clone, parents))
            
            # Скрещивание (one-point crossover)
            for child1, child2 in zip(offspring[::2], offspring[1::2]):
                if random.random() < self.crossover_prob:
                    self.toolbox.mate(child1, child2)
                    del child1.fitness.values
                    del child2.fitness.values
            
            # Мутация
            for mutant in offspring:
                if random.random() < self.mutation_prob:
                    self.toolbox.mutate(mutant)
                    del mutant.fitness.values
            
            # Оценка потомков
            invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
            fitnesses = map(self.toolbox.evaluate, invalid_ind)
            for ind, fit in zip(invalid_ind, fitnesses):
                ind.fitness.values = fit
            
            # ЭЛИТАРНАЯ СТРАТЕГИЯ: объединение родителей и потомков
            combined_population = population + offspring
            population = tools.selBest(combined_population, self.population_size)

            if self.verbose:
                sorted_combined = sorted(combined_population, key=lambda x: x.fitness.values[0])
                params = self._decode_individual(sorted_combined[0])

                print('Лучший индивид')
                print(f"C2ST={sorted_combined[0].fitness.values[0]}, Params={self._format_params(params)}")
                
            # Сохранение статистики
            self._save_generation_stats(population, generation)
            
        
        # Лучший индивид
        best_individual = tools.selBest(population, 1)[0]
        best_params = self._decode_individual(best_individual)
        best_fitness = best_individual.fitness.values[0]
        
        
        return {
            'best_params': best_params,
            'best_c2st': best_fitness,
            'c2st_diff_from_optimal': best_fitness,
            'history': self.history
        }
    
    def _format_params(self, params):
        """Форматирование параметров для вывода"""
        formatted = {}
        for key, value in params.items():
            if isinstance(value, float):
                formatted[key] = f"{value}"
            else:
                formatted[key] = value
        return formatted
    
    def _print_population_info(self, population, generation, title):
        """Вывод информации о популяции"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)
        
        print(f"\n{title}:")
        print(f"  Лучший C2ST: {best_fitness}")
        print(f"  Средний C2ST: {avg_fitness}")
        
    
    def _save_generation_stats(self, population, generation):
        """Сохранение статистики поколения"""
        fitnesses = [ind.fitness.values[0] for ind in population]
        best_fitness = min(fitnesses)
        avg_fitness = np.mean(fitnesses)
        
        best_individual = min(population, key=lambda x: x.fitness.values[0])
        best_params = self._decode_individual(best_individual)
        
        self.history['generations'].append(generation)
        self.history['best_fitness'].append(best_fitness)
        self.history['avg_fitness'].append(avg_fitness)
        self.history['best_params'].append(best_params)

# %%
def evaluate_c2st(real, synthetic):
    real_copy = real.copy()
    if hasattr(synthetic, "dataframe"):
        synthetic = synthetic.dataframe()

    synthetic_copy = synthetic.copy()

    # Добавление меток
    real_copy['label'] = 1
    synthetic_copy['label'] = 0

    # Объединение данных
    df = pd.concat([real_copy, synthetic_copy], ignore_index=True)

    # Определение категориальных колонок
    categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()
    categorical_columns = [col for col in categorical_columns if col != 'label']

    # Label Encoding для категориальных признаков
    for col in categorical_columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))

    # Разделение на признаки и метки
    X = df.drop(columns='label')
    y = df['label']

    # Разделение на обучающую и тестовую выборки
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y, random_state=RANDOM_SEED
    )
    # Обучение XGBoost
    clf = XGBClassifier(
        random_state=RANDOM_SEED
    )
    clf.fit(X_train, y_train)

    # Предсказания
    y_pred_proba = clf.predict_proba(X_test)[:, 1]

    return roc_auc_score(y_test, y_pred_proba)

# %%
# Пример использования с различными пространствами поиска
def generate_and_evaluate(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    columns_dataset = dataset_info['num_columns'] + dataset_info['cat_columns'] + [dataset_info['target']]
    data = process_data(dataset_info['data'][columns_dataset], dataset_info['num_columns'], dataset_info['cat_columns'],
                        'None', 'None')

    kf = KFold(n_splits=n_splits, shuffle=False)
    c2st_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        cat_columns = dataset_info['cat_columns'].copy()
        if dataset_info["task"] == 'classification':
            cat_columns.append(dataset_info['target'])
        for col in dataset_info['cat_columns']:
            metadata.update_column(col, sdtype='categorical')

        # Создание и обучение CTGAN с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency']
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        score = evaluate_c2st(test_data, synthetic_data)
        c2st_scores.append(score)

    return np.mean(c2st_scores)

# %%
def optimize_dataset_genetic(dataset_name, dataset_info, param_space,
                           population_size=20, n_generations=10, 
                           mutation_prob=0.2, crossover_prob=1.0,
                           tournament_size=3, random_seed=None, verbose=True):
    """
    Универсальная оптимизация датасета с использованием генетического алгоритма
    
    Args:
        dataset_name: название датасета
        dataset: информация о датасете
        param_space: пространство поиска параметров
        population_size: размер популяции
        n_generations: количество поколений
        mutation_prob: вероятность мутации
        crossover_prob: вероятность скрещивания
        tournament_size: размер турнира
        random_seed: seed для воспроизводимости
        verbose: вывод прогресса
    """
    print(f"Универсальная генетическая оптимизация для датасета: {dataset_name}")
    
    # Создание оптимизатора
    optimizer = UniversalGeneticOptimizer(
        param_space=param_space,
        population_size=population_size,
        n_generations=n_generations,
        mutation_prob=mutation_prob,
        crossover_prob=crossover_prob,
        tournament_size=tournament_size,
        random_seed=random_seed,
        verbose=verbose
    )
    
    # Определение целевой функции
    def objective(params):
        if verbose:
            print(f"Оценка параметров: {optimizer._format_params(params)}")
        
        c2st_score = generate_and_evaluate(params, dataset_info)
        
        if verbose:
            print(f"C2ST score: {c2st_score}")
        
        return c2st_score
    
    optimizer.set_objective_function(objective)
    
    # Запуск оптимизации
    start_time = time.time()
    results = optimizer.optimize()
    end_time = time.time()  # время окончания
    
    elapsed_time = end_time - start_time
    formatted_time = str(timedelta(seconds=int(elapsed_time)))

    print("РЕЗУЛЬТАТ ОПТИМИЗАЦИИ:")
    print(f"Лучший C2ST для {dataset_name}: {results['best_c2st']}")
    print(f"Лучшие параметры: {results['best_params']}")
    print(f"[INFO] Время работы алгоритма: {formatted_time}")
    print('-' * 50)
    
    return results

# %%
results = {}
N_GENERATIONS = 4 # без учета начальной популяции
POPULATION_SIZE = 10
MUTATION_PROB = 0.4
TOURNAMENT_SIZE = 3


for dataset_name in datasets:
    data = datasets[dataset_name]
    results[dataset_name] = optimize_dataset_genetic(
        dataset_name=dataset_name,
        dataset_info=datasets[dataset_name],
        param_space=ctgan_space,  
        population_size=POPULATION_SIZE,
        n_generations=N_GENERATIONS,
        mutation_prob=MUTATION_PROB,
        tournament_size=TOURNAMENT_SIZE,
        random_seed=RANDOM_SEED,
        verbose=True,
    )
# Out:
# Универсальная генетическая оптимизация для датасета: insurance
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9603475161505903
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9553723917724809
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9658053018489641
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9650441820747012
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9576186233014035
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.876104551867528
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9167409222543995
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9808420583648919
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8866302814286776
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8461238583203388
#
# Начальная популяция:
#   Лучший C2ST: 0.8461238583203388
#   Средний C2ST: 0.9310629687383976
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9732865523130615
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9841835598128759
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8759746045889955
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8744338011435361
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.945199376253063
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8702383604366228
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8995693175911487
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8794089255216456
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8957637187198336
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8560555431796243
# Лучший индивид
# C2ST=0.8461238583203388, Params={'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8671010618549045
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8708509690354199
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9001076706022128
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8694029850746268
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00025', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8737655008539393
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8543847924556323
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8844397415905547
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8660986114205094
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8758817851043291
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8595919655454073
# Лучший индивид
# C2ST=0.8461238583203388, Params={'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8576520383158832
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9178547560703944
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9081458379743075
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8673795203089033
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.862274448652261
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '4.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9025952327912675
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.4999999999999998e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8625157793123933
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8525469666592412
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8839013885794906
# Оценка параметров: {'discriminator_lr': '0.0010500000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8665812727407737
# Лучший индивид
# C2ST=0.8461238583203388, Params={'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8533823420212371
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.4e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9078302517264425
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8541620256924333
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8939630207173089
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8512846216677805
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8795760005940446
# Оценка параметров: {'discriminator_lr': '0.0015', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.875640454444197
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.868437662434098
# Оценка параметров: {'discriminator_lr': '0.00165', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8924779089626496
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0039000000000000003', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8361364817702532
# Лучший индивид
# C2ST=0.8361364817702532, Params={'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0039000000000000003', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# РЕЗУЛЬТАТ ОПТИМИЗАЦИИ:
# Лучший C2ST для insurance: 0.8361364817702532
# Лучшие параметры: {'discriminator_lr': 0.0006000000000000001, 'generator_lr': 0.0039000000000000003, 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': 1e-06, 'discriminator_decay': 2e-06, 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 1:24:10
# --------------------------------------------------
# Универсальная генетическая оптимизация для датасета: my_classification
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9167078189300412
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9739094650205762
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.977283950617284
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8577777777777778
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9392181069958848
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8010699588477367
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9322222222222223
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.0024000000000000002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9549794238683127
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7690534979423869
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7230452674897121
#
# Начальная популяция:
#   Лучший C2ST: 0.7230452674897121
#   Средний C2ST: 0.8845267489711937
#
# ==================== ПОКОЛЕНИЕ 1 ====================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8891358024691357
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8886831275720164
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.732551440329218
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7218930041152264
# Оценка параметров: {'discriminator_lr': '0.0019', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9791358024691358
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.6746502057613167
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8175720164609054
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7796707818930041
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9327572016460906
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.6926337448559671
# Лучший индивид
# C2ST=0.6746502057613167, Params={'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00030000000000000003', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7327983539094651
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7165432098765431
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7851028806584361
# Оценка параметров: {'discriminator_lr': '0.0015500000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.9e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7772427983539094
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00125', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7961728395061728
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7284362139917695
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7116872427983539
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7604526748971194
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7465432098765433
# Оценка параметров: {'discriminator_lr': '0.0015500000000000002', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.8e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7814403292181069
# Лучший индивид
# C2ST=0.6746502057613167, Params={'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7753497942386831
# Оценка параметров: {'discriminator_lr': '0.0005', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8864609053497943
# Оценка параметров: {'discriminator_lr': '0.0012000000000000001', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8721399176954733
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.6734979423868314
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8132098765432098
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '4.7e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7487654320987654
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.4999999999999998e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.757283950617284
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7179012345679013
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7555967078189302
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8153497942386831
# Лучший индивид
# C2ST=0.6734979423868314, Params={'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7418930041152264
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.5999999999999997e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.862633744855967
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7956378600823046
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.0002', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.4e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8390534979423868
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '6e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7369958847736626
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7017283950617283
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7137860082304527
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7240740740740742
# Оценка параметров: {'discriminator_lr': '0.0008', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7195473251028807
# Оценка параметров: {'discriminator_lr': '0.0004', 'generator_lr': '0.00015000000000000001', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8465432098765433
# Лучший индивид
# C2ST=0.6734979423868314, Params={'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# РЕЗУЛЬТАТ ОПТИМИЗАЦИИ:
# Лучший C2ST для my_classification: 0.6734979423868314
# Лучшие параметры: {'discriminator_lr': 0.00045000000000000004, 'generator_lr': 0.0002, 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': 1e-06, 'discriminator_decay': 2e-06, 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 1:01:47
# --------------------------------------------------
# Универсальная генетическая оптимизация для датасета: my_regression
# Пространство параметров:
#   discriminator_lr: непрерывный (0.0004, 0.0021), квантование: 5e-05
#   generator_lr: непрерывный (5e-05, 0.005), квантование: 5e-05
#   batch_size: дискретный [100, 500, 1000]
#   embedding_dim: дискретный [32, 128]
#   generator_dim: дискретный [[128, 128, 128], [128, 128, 128, 128]]
#   discriminator_dim: дискретный [[256, 256], [256, 256, 256]]
#   generator_decay: непрерывный (1e-06, 6.4e-06), квантование: 1e-07
#   discriminator_decay: непрерывный (1e-06, 8e-06), квантование: 1e-06
#   log_frequency: дискретный [False, True]
#   transformation_num_type: дискретный ['CDF', 'PLE_CDF']
#   transformation_cat_type: дискретный ['OHE']
# Размер популяции: 10
# Количество поколений: 4
# Вероятность мутации: 0.4
# Вероятность скрещивания: 1.0
# ============================================================
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '0.004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2999999999999998e-06', 'discriminator_decay': '1e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8995061728395063
# Оценка параметров: {'discriminator_lr': '0.0017000000000000001', 'generator_lr': '0.0008', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9237448559670781
# Оценка параметров: {'discriminator_lr': '0.00205', 'generator_lr': '0.0008500000000000001', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9581481481481481
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '0.00445', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8520164609053498
# Оценка параметров: {'discriminator_lr': '0.0008500000000000001', 'generator_lr': '0.0026000000000000003', 'batch_size': 1000, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '7e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.9026748971193416
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.6e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8630452674897119
# ...
# C2ST score: 0.7840534979423869
# Оценка параметров: {'discriminator_lr': '0.0018000000000000002', 'generator_lr': '0.0008', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '3.8e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8890329218106996
# Оценка параметров: {'discriminator_lr': '0.00095', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7736625514403292
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7741358024691358
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7897325102880659
# Оценка параметров: {'discriminator_lr': '0.0011', 'generator_lr': '0.00030000000000000003', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.2e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8586625514403292
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7814814814814816
# Лучший индивид
# C2ST=0.7736625514403292, Params={'discriminator_lr': '0.00095', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 2 ====================
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0015500000000000002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '4e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7944238683127572
# Оценка параметров: {'discriminator_lr': '0.00095', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.78320987654321
# Оценка параметров: {'discriminator_lr': '0.0006000000000000001', 'generator_lr': '0.0002', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8120781893004114
# Оценка параметров: {'discriminator_lr': '0.0016', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.4e-06', 'discriminator_decay': '4.9999999999999996e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7873251028806584
# Оценка параметров: {'discriminator_lr': '0.00095', 'generator_lr': '0.00045000000000000004', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7799794238683129
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8101234567901234
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7549382716049383
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7972222222222222
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7758024691358024
# Оценка параметров: {'discriminator_lr': '0.0009000000000000001', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8039917695473252
# Лучший индивид
# C2ST=0.7549382716049383, Params={'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 3 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7516666666666666
# Оценка параметров: {'discriminator_lr': '0.0005', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8212345679012345
# Оценка параметров: {'discriminator_lr': '0.0014500000000000001', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.777716049382716
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8081481481481482
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8168930041152264
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.4e-06', 'discriminator_decay': '2e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8130864197530864
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '1.2e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7881069958847737
# Оценка параметров: {'discriminator_lr': '0.00045000000000000004', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7999382716049382
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7684567901234568
# Оценка параметров: {'discriminator_lr': '0.00075', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '1.6e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7864197530864198
# Лучший индивид
# C2ST=0.7516666666666666, Params={'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
#
# ==================== ПОКОЛЕНИЕ 4 ====================
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '2e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8148148148148149
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '6.1e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8245061728395062
# Оценка параметров: {'discriminator_lr': '0.0014500000000000001', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8025514403292181
# Оценка параметров: {'discriminator_lr': '0.0006500000000000001', 'generator_lr': '5e-05', 'batch_size': 500, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '5.6e-06', 'discriminator_decay': '1e-06', 'log_frequency': True, 'transformation_num_type': 'CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.855
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '6e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7756584362139917
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7939506172839507
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7577572016460906
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.8014609053497943
# Оценка параметров: {'discriminator_lr': '0.00095', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.7803909465020576
# Оценка параметров: {'discriminator_lr': '0.00055', 'generator_lr': '0.00045000000000000004', 'batch_size': 1000, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': False, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# C2ST score: 0.832716049382716
# Лучший индивид
# C2ST=0.7516666666666666, Params={'discriminator_lr': '0.00055', 'generator_lr': '5e-05', 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': '2.7e-06', 'discriminator_decay': '3e-06', 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# РЕЗУЛЬТАТ ОПТИМИЗАЦИИ:
# Лучший C2ST для two_moons: 0.7516666666666666
# Лучшие параметры: {'discriminator_lr': 0.00055, 'generator_lr': 5e-05, 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': 2.7e-06, 'discriminator_decay': 3e-06, 'log_frequency': True, 'transformation_num_type': 'PLE_CDF', 'transformation_cat_type': 'OHE'}
# [INFO] Время работы алгоритма: 0:51:51
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(f"{dataset_name}: {results[dataset_name]['best_c2st']}")
# Out:
# insurance: 0.8361364817702532
# my_classification: 0.6734979423868314
# my_regression: 0.7097530864197531
# two_moons: 0.7516666666666666
