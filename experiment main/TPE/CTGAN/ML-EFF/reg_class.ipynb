# %%
#!pip install sdv

# %%
#!unrar x data.rar

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
from sklearn.metrics import f1_score, r2_score
from xgboost import XGBClassifier, XGBRegressor

# %%
dir_datasets = 'data/original/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'abalone.csv')
#real_data_1['Rings'] = (real_data_1['Rings'] > 10).astype(int)
real_data_2 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_4 = pd.read_csv(dir_datasets+'my_regression.csv')

# Словарь датасетов для удобства
datasets = {
    # 'abolone': {
    #             "data": real_data_1,
    #             "task": "classification",
    #             "target": "Rings",
    #             "num_columns":
    #             ["Length", "Diameter", "Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight"]
    #             },
    # 'insurance': {
    #                 "data": real_data_2,
    #                 "task": "regression",
    #                 "target": "expenses",
    #                 "num_columns":
    #                 ["age", "bmi", "children"],
    #                 "cat_columns":
    #                 ["sex", "smoker", "region"]
    #             },
    'my_classification': {
                    "data": real_data_3,
                    "task": "classification",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3", "feature_4"],
                    "cat_columns":
                    []
                },
    'my_regression': {
                    "data": real_data_4,
                    "task": "regression",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3"],
                    "cat_columns":
                    []
                },
}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете my_classification:
#  Количество строк: 900
#  Количество колонок: 6
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'target']
#  Задача: classification
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4']
#  Категориальные признаки: []
#
#  Информация о датасете my_regression:
#  Количество строк: 900
#  Количество колонок: 5
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'target']
#  Задача: regression
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3']
#  Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    # Learning rates
    'discriminator_lr': hp.qloguniform('discriminator_lr',
                                                 np.log(4e-4), np.log(2.1e-3), 5e-5),
    'generator_lr': hp.qloguniform('generator_lr',
                                             np.log(5e-5), np.log(5e-3), 5e-5),

    # Batch size
    'batch_size': hp.choice('batch_size', [100, 500, 1000]),

    # Embedding dimensions
    'embedding_dim': hp.choice('embedding_dim', [32, 128]),

    # Network architecture
    'generator_dim': hp.choice('generator_dim', [[128, 128, 128], [128, 128, 128, 128]]),
    'discriminator_dim': hp.choice('discriminator_dim', [[256, 256], [256, 256, 256]]),

    # Decay parameters
    'generator_decay': hp.qloguniform('generator_decay',
                                     np.log(1e-6), np.log(6.4e-6), 1e-7),
    'discriminator_decay': hp.qloguniform('discriminator_decay',
                                         np.log(1e-6), np.log(8e-6), 1e-6),

    # Frequency
    'log_frequency': hp.choice('log_frequency', [False, True]),

    'transformation_num_type': hp.choice('transformation_num_type', ['CDF', 'PLE_CDF']),
    'transformation_cat_type': hp.choice('transformation_cat_type', ['OHE'])

}

# %%
def evaluate_ml_efficacy(real_train, synthetic_train, real_test, target_column, num_columns, cat_columns, task_type='classification'):
    """
    Вычисляет ML-Efficacy метрику

    Args:
        real_train: реальные тренировочные данные
        synthetic_train: синтетические тренировочные данные
        real_test: реальные тестовые данные
        target_column: название целевой колонки
        task_type: 'classification' или 'regression'

    Returns:
        ml_efficacy_score: отношение качества модели на синтетических данных к качеству на реальных
    """

    # Подготовка данных
    real_train_copy = real_train.copy()

    # Обработка синтетических данных (если это объект с методом dataframe)
    if hasattr(synthetic_train, "dataframe"):
        synthetic_train = synthetic_train.dataframe()
    synthetic_train_copy = synthetic_train.copy()

    real_test_copy = real_test.copy()

    # Определение категориальных колонок (исключая целевую)
    feature_columns = num_columns
    categorical_columns = cat_columns

    # Label Encoding для категориальных признаков
    label_encoders = {}
    for col in categorical_columns:
        le = LabelEncoder()
        # Обучаем на реальных данных
        combined_values = pd.concat([real_train_copy[col], real_test_copy[col]]).astype(str)
        le.fit(combined_values)
        label_encoders[col] = le

        # Применяем к реальным данным
        real_train_copy[col] = le.transform(real_train_copy[col].astype(str))
        real_test_copy[col] = le.transform(real_test_copy[col].astype(str))

        # Применяем к синтетическим данным, обрабатываем неизвестные значения
        synthetic_values = synthetic_train_copy[col].astype(str)
        known_values = set(le.classes_)
        synthetic_values = synthetic_values.apply(lambda x: x if x in known_values else le.classes_[0])
        synthetic_train_copy[col] = le.transform(synthetic_values)

    # Разделение на признаки и целевую переменную
    X_real_train = real_train_copy.drop(columns=[target_column])
    y_real_train = real_train_copy[target_column]

    X_synthetic_train = synthetic_train_copy.drop(columns=[target_column])
    y_synthetic_train = synthetic_train_copy[target_column]

    X_real_test = real_test_copy.drop(columns=[target_column])
    y_real_test = real_test_copy[target_column]

    # Выбор модели в зависимости от типа задачи
    if task_type == 'classification':
        model_real = XGBClassifier(random_state=42, eval_metric='logloss')
        model_synthetic = XGBClassifier(random_state=42, eval_metric='logloss')
        score_func = f1_score
        score_kwargs = {'average': 'weighted'} if len(np.unique(y_real_train)) > 2 else {'average': 'binary'}
    else:  # regression
        model_real = XGBRegressor(random_state=42)
        model_synthetic = XGBRegressor(random_state=42)
        score_func = r2_score
        score_kwargs = {}

    try:
        # Обучение модели на реальных данных
        model_real.fit(X_real_train, y_real_train)
        y_pred_real = model_real.predict(X_real_test)
        score_real = score_func(y_real_test, y_pred_real, **score_kwargs)

        # Обучение модели на синтетических данных
        model_synthetic.fit(X_synthetic_train, y_synthetic_train)
        y_pred_synthetic = model_synthetic.predict(X_real_test)
        score_synthetic = score_func(y_real_test, y_pred_synthetic, **score_kwargs)

        # Вычисление ML-Efficacy
        if score_real > 0:
            ml_efficacy = score_synthetic / score_real
        else:
            ml_efficacy = 0.0

        return ml_efficacy

    except Exception as e:
        print(f"Ошибка при вычислении ML-Efficacy: {e}")
        return 0.0

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_ml_efficacy(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    task_type = dataset_info['task']
    target_column = dataset_info['target']
    data = process_data(dataset_info['data'], dataset_info['num_columns'], dataset_info["cat_columns"], params['transformation_num_type'], params['transformation_cat_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    ml_efficacy_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение TVAE с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        # Вычисляем ML-Efficacy
        score = evaluate_ml_efficacy(
            real_train=train_data,
            synthetic_train=synthetic_data,
            real_test=test_data,
            target_column=target_column,
            num_columns = dataset_info["num_columns"],
            cat_columns = dataset_info["cat_columns"],
            task_type=task_type
        )
        ml_efficacy_scores.append(score)

    return np.mean(ml_efficacy_scores)

# %%
def optimize_dataset(dataset_name, dataset_info, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        ml_efficacy_score = generate_and_evaluate_ml_efficacy(params, dataset_info)

        print(f"ML-Efficacy: {ml_efficacy_score}")
        print(params)
        print("="*50)

        # Для ML-Efficacy мы хотим максимизировать метрику, поэтому возвращаем отрицательное значение
        return {
            'loss': -ml_efficacy_score,  # отрицательное для максимизации
            'status': STATUS_OK,
            'ml_efficacy_score': ml_efficacy_score
        }

    # Запускаем оптимизацию с помощью TPE алгоритма
    rng = np.random.default_rng(42)  # Используем фиксированный seed
    best = fmin(
        fn=objective,
        space=ctgan_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Получаем лучшие параметры в читаемом виде
    best_params = {
        'discriminator_lr': best['discriminator_lr'],
        'generator_lr': best['generator_lr'],
        'batch_size': [100, 500, 1000][best['batch_size']],
        'embedding_dim': [32, 128][best['embedding_dim']],
        'generator_dim': [[128, 128, 128], [128, 128, 128, 128]][best['generator_dim']],
        'discriminator_dim': [[256, 256], [256, 256, 256]][best['discriminator_dim']],
        'generator_decay': best['generator_decay'],
        'discriminator_decay': best['discriminator_decay'],
        'log_frequency': [False, True][best['log_frequency']],
        'epochs': float('inf')
    }


    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_ml_efficacy = best_trial['result'].get('ml_efficacy_score', None)

    results = {
        'best_params': best_params,
        'best_ml_efficacy': best_ml_efficacy,
        'ml_efficacy_diff_from_optimal': -best_trial['result']['loss']  # убираем минус для читаемости
    }

    print(f"Лучший ML-Efficacy для {dataset_name}: {best_ml_efficacy}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 50

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: my_classification
# ==================================================
# ML-Efficacy: 0.8667662328179108
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.9002571540822867
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6177775678920011
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.755650166552967
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7246432024823858
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6983741851115726
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7523154922875648
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00495, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.5408575016963348
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0023, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.5118062830935315
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7260106034596757
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.782152662224497
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 32, 'generator_decay': 5.899999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7039188885444275
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'generator_decay': 1.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.579048166343593
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0014500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8670564866548415
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8555324934173442
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0032500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8934289873609069
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00475, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6238459417181459
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7919621232760005
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6339646474451784
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6644526057952446
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.9075197359902768
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.893937169549211
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8068343175053289
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8749088275825855
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 128, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8906245690738679
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00075, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8449210600488409
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 1.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8312235869241847
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8880388484491407
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8597638842530317
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 128, 'generator_decay': 2.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7651379353898403
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0006500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8534403755177854
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0011, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0009000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8740081436939328
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 128, 'generator_decay': 1.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7675410812441331
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8420268289690344
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7884103088350017
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0011, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6704756343367171
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6930499432039751
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6864006563071233
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'generator_decay': 1.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.745413962747172
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'generator_decay': 4.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8940330502692735
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 128, 'generator_decay': 2.5999999999999997e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8136996935113757
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 4.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0038, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.723899179433861
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7242434778642334
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.827409365969935
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 32, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7390897981428228
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019, 'embedding_dim': 128, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.761015075261061
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 128, 'generator_decay': 2.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.8131964419814968
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 32, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00075, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6817404979210077
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0013000000000000002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.6788329956388125
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 32, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00285, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.7823296613554653
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# 100%|██████████| 50/50 [1:07:45<00:00, 81.31s/trial, best loss: -0.9075197359902768]
# Лучший ML-Efficacy для my_classification: 0.9075197359902768
# Лучшие параметры: {'discriminator_lr': np.float64(0.0008500000000000001), 'generator_lr': np.float64(0.00025), 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1e-06), 'discriminator_decay': np.float64(7e-06), 'log_frequency': True, 'epochs': inf}
# --------------------------------------------------
# Оптимизация для датасета: my_regression
# ==================================================
# ML-Efficacy: 0.3086086750178307
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.18679095676802518
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.5692550910309837
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.4655136113662544
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.8281241190866896
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.046869963744642
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.3929402295636606
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00495, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.46662306549448934
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0023, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.6630839024477526
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.8089334279127045
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.3682400701245876
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 32, 'generator_decay': 5.899999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.38238130202836795
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'generator_decay': 1.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.5095982130743446
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0014500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.3527649739245175
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.35427334385074855
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0032500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.316638943728224
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00475, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.2628739822190158
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.046540945728339854
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.6373908619529651
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.8731211521690039
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.3455011064168125
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 32, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.4554129717944182
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'generator_decay': 4.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.2754109301462578
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 32, 'generator_decay': 4.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.31507975861342674
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 32, 'generator_decay': 6.3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.16954382690079295
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 32, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0036000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.4220809456814847
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'generator_decay': 4.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.3713739277493675
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.18886290792893712
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 32, 'generator_decay': 2.8e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.22600270418297377
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 4.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0006500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.20312282708091664
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 32, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.05577619206743714
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 32, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.16070710760318027
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 5.3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.009704386441463772
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 32, 'generator_decay': 2.4999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -1.30946027670757
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.471473129874576
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 32, 'generator_decay': 4.2999999999999995e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.039689528156810316
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 5.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.9647567181036804
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.31214657350559866
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 4.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.016417183191158997
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0011, 'embedding_dim': 32, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7982036691254285
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 128, 'generator_decay': 3.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.0978683942444691
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 4.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.740673010872895
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 32, 'generator_decay': 3.9e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.04727953840237942
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 32, 'generator_decay': 5.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7687914266503318
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 128, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.3627229961516915
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 32, 'generator_decay': 2.5999999999999997e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.7436635358003573
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015, 'embedding_dim': 32, 'generator_decay': 5.7e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.13625172087324455
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.31945372375969316
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: 0.11063055139540663
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0019, 'embedding_dim': 32, 'generator_decay': 6.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# ML-Efficacy: -0.70082195396422
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 32, 'generator_decay': 4.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# 100%|██████████| 50/50 [53:06<00:00, 63.74s/trial, best loss: -0.471473129874576]
# Лучший ML-Efficacy для my_regression: 0.471473129874576
# Лучшие параметры: {'discriminator_lr': np.float64(0.0009000000000000001), 'generator_lr': np.float64(0.00015000000000000001), 'batch_size': 100, 'embedding_dim': 32, 'generator_dim': [128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(4.2999999999999995e-06), 'discriminator_decay': np.float64(4.9999999999999996e-06), 'log_frequency': True, 'epochs': inf}
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_ml_efficacy'])
# Out:
# my_classification 0.9075197359902768
# my_regression 0.471473129874576
