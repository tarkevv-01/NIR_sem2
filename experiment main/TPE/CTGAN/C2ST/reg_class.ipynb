# %%
# !pip install sdv

# %%
#!unrar x  data.rar

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
dir_datasets = 'data/original/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'abalone.csv')
#real_data_1['Rings'] = (real_data_1['Rings'] > 10).astype(int)
real_data_2 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_4 = pd.read_csv(dir_datasets+'my_regression.csv')

# Словарь датасетов для удобства
datasets = {
    # 'abolone': {
    #             "data": real_data_1,
    #             "task": "classification",
    #             "target": "Rings",
    #             "num_columns":
    #             ["Length", "Diameter", "Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight"]
    #             },
    # 'insurance': {
    #                 "data": real_data_2,
    #                 "task": "regression",
    #                 "target": "expenses",
    #                 "num_columns":
    #                 ["age", "bmi", "children"],
    #                 "cat_columns":
    #                 ["sex", "smoker", "region"]
    #             },
    'my_classification': {
                    "data": real_data_3,
                    "task": "classification",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3", "feature_4"],
                    "cat_columns":
                    []
                },
    'my_regression': {
                    "data": real_data_4,
                    "task": "regression",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3"],
                    "cat_columns":
                    []
                },
}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете my_classification:
#  Количество строк: 900
#  Количество колонок: 6
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'target']
#  Задача: classification
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4']
#  Категориальные признаки: []
#
#  Информация о датасете my_regression:
#  Количество строк: 900
#  Количество колонок: 5
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'target']
#  Задача: regression
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3']
#  Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    # Learning rates
    'discriminator_lr': hp.qloguniform('discriminator_lr',
                                                 np.log(4e-4), np.log(2.1e-3), 5e-5),
    'generator_lr': hp.qloguniform('generator_lr',
                                             np.log(5e-5), np.log(5e-3), 5e-5),

    # Batch size
    'batch_size': hp.choice('batch_size', [100, 500, 1000]),

    # Embedding dimensions
    'embedding_dim': hp.choice('embedding_dim', [32, 128]),

    # Network architecture
    'generator_dim': hp.choice('generator_dim', [[128, 128, 128], [128, 128, 128, 128]]),
    'discriminator_dim': hp.choice('discriminator_dim', [[256, 256], [256, 256, 256]]),

    # Decay parameters
    'generator_decay': hp.qloguniform('generator_decay',
                                     np.log(1e-6), np.log(6.4e-6), 1e-7),
    'discriminator_decay': hp.qloguniform('discriminator_decay',
                                         np.log(1e-6), np.log(8e-6), 1e-6),

    # Frequency
    'log_frequency': hp.choice('log_frequency', [False, True]),
    'transformation_num_type': hp.choice('transformation_num_type', ['CDF', 'PLE_CDF']),
    'transformation_cat_type': hp.choice('transformation_cat_type', ['OHE'])

}

# %%
def evaluate_c2st(real, synthetic):
    real_copy = real.copy()
    synthetic_copy = synthetic.copy()

    # Добавление меток
    real_copy['label'] = 1
    synthetic_copy['label'] = 0

    # Объединение данных
    df = pd.concat([real_copy, synthetic_copy], ignore_index=True)

    # Определение категориальных колонок
    categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()
    categorical_columns = [col for col in categorical_columns if col != 'label']

    # Label Encoding для категориальных признаков
    for col in categorical_columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))

    # Разделение на признаки и метки
    X = df.drop(columns='label')
    y = df['label']

    # Разделение на обучающую и тестовую выборки
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y, random_state=RANDOM_SEED
    )
    # Обучение XGBoost
    clf = XGBClassifier(
        random_state=RANDOM_SEED
    )
    clf.fit(X_train, y_train)

    # Предсказания
    y_pred_proba = clf.predict_proba(X_test)[:, 1]

    return roc_auc_score(y_test, y_pred_proba)

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    data = process_data(dataset_info['data'], dataset_info['num_columns'], dataset_info["cat_columns"], params['transformation_num_type'], params['transformation_cat_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    c2st_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение TVAE с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        score = evaluate_c2st(test_data, synthetic_data)
        c2st_scores.append(score)

    return np.mean(c2st_scores)

# %%
def optimize_dataset(dataset_name, dataset_info, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        c2st_score = generate_and_evaluate(params, dataset_info)

        print(c2st_score)
        print(params)
        print("="*50)
        # Возвращаем словарь в формате, который ожидает hyperopt
        return {
            'loss': c2st_score,
            'status': STATUS_OK,
            'c2st_score': c2st_score
        }


    # Запускаем оптимизацию с помощью TPE алгоритма
    rng = np.random.default_rng(RANDOM_SEED)
    best = fmin(
        fn=objective,
        space=ctgan_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Получаем лучшие параметры в читаемом виде
    best_params = {
        'discriminator_lr': best['discriminator_lr'],
        'generator_lr': best['generator_lr'],
        'batch_size': [100, 500, 1000][best['batch_size']],
        'embedding_dim': [32, 128][best['embedding_dim']],
        'generator_dim': [[128, 128, 128], [128, 128, 128, 128]][best['generator_dim']],
        'discriminator_dim': [[256, 256], [256, 256, 256]][best['discriminator_dim']],
        'generator_decay': best['generator_decay'],
        'discriminator_decay': best['discriminator_decay'],
        'log_frequency': [False, True][best['log_frequency']],
        'epochs': float('inf')
    }

    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_c2st = best_trial['result'].get('c2st_score', None)

    results = {
        'best_params': best_params,
        'best_c2st': best_c2st,
        'c2st_diff_from_optimal': best_trial['result']['loss']
    }

    print(f"Лучший C2ST для {dataset_name}: {best_c2st}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 50

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data_info = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data_info, max_evals)
# Out:
# Оптимизация для датасета: my_classification
# ==================================================
# 0.7292592592592593
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.6704115226337449
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8063786008230452
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8720987654320987
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8037037037037037
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.874238683127572
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9362139917695473
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00495, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9161316872427984
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0023, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9430864197530863
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9509876543209876
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7662139917695473
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 32, 'generator_decay': 5.899999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9402880658436215
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'generator_decay': 1.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9370781893004114
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0014500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8315226337448559
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7659670781893003
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0032500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.6889300411522634
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00475, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9453086419753086
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8271193415637859
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9244444444444445
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9166255144032922
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7078189300411523
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.6834156378600823
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00485, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7859259259259259
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0011, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.691358024691358
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.6990123456790123
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 128, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00365, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.745679012345679
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7490534979423868
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7605761316872428
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7188477366255143
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 128, 'generator_decay': 2.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00115, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7590123456790124
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0006500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.6567901234567901
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 1.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00315, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.670082304526749
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0032, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.6881481481481483
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0037, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9664197530864197
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00295, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7000411522633746
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 128, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00185, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.6690123456790124
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015, 'embedding_dim': 128, 'generator_decay': 1.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00405, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9578189300411525
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 128, 'generator_decay': 2.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00485, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7447325102880659
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00185, 'embedding_dim': 128, 'generator_decay': 1.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0015500000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7039506172839506
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015, 'embedding_dim': 128, 'generator_decay': 1.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.004200000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9600823045267489
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 128, 'generator_decay': 2.4999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00255, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7593827160493826
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9420576131687243
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00185, 'embedding_dim': 128, 'generator_decay': 2.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0012000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7151440329218106
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 3.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9587654320987654
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00095, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7425102880658437
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8913991769547325
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 32, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00205, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9468724279835391
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 3.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0028, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.6969135802469136
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0016, 'embedding_dim': 32, 'generator_decay': 4.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0037500000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.70440329218107
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'generator_decay': 2.4999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9332510288065844
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 32, 'generator_decay': 1.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# 100%|██████████| 50/50 [1:05:18<00:00, 78.36s/trial, best loss: 0.6567901234567901]
# Лучший C2ST для my_classification: 0.6567901234567901
# Лучшие параметры: {'discriminator_lr': np.float64(0.00115), 'generator_lr': np.float64(0.00315), 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256], 'generator_decay': np.float64(1.4e-06), 'discriminator_decay': np.float64(1e-06), 'log_frequency': True, 'epochs': inf}
# --------------------------------------------------
# Оптимизация для датасета: my_regression
# ==================================================
# 0.7518518518518519
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7297942386831275
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8504938271604937
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8627160493827161
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.838230452674897
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9012962962962963
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9310699588477367
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00495, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8858436213991769
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0023, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9223868312757202
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.9169547325102881
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8363374485596707
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 32, 'generator_decay': 5.899999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8655967078189301
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'generator_decay': 1.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.902633744855967
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0014500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7970781893004114
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.790082304526749
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0032500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8037860082304528
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00475, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.921522633744856
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8023456790123457
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9258847736625514
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9280246913580247
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7762962962962963
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8061316872427983
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 2.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8216872427983538
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.801440329218107
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 3.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.8434979423868313
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0011, 'embedding_dim': 128, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7586008230452674
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 2.5999999999999997e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7685185185185185
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 128, 'generator_decay': 1.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8104115226337448
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0010500000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7743621399176955
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# 0.7405761316872428
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00175, 'embedding_dim': 128, 'generator_decay': 4.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8107818930041152
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 128, 'generator_decay': 4.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00405, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7574897119341563
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00175, 'embedding_dim': 128, 'generator_decay': 4.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.909753086419753
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'generator_decay': 5.199999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8057613168724279
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00385, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7768724279835392
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9181893004115227
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00185, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0017000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8641152263374486
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 128, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9397942386831276
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0016, 'embedding_dim': 128, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7744855967078189
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'generator_decay': 2.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.812469135802469
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 128, 'generator_decay': 3.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8759670781893004
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0006500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9342798353909466
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'generator_decay': 5.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00205, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.8322633744855966
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00055, 'embedding_dim': 128, 'generator_decay': 4.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9085596707818929
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 2.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.753045267489712
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015, 'embedding_dim': 128, 'generator_decay': 5.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00295, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9400411522633746
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 2.4999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7502880658436214
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 32, 'generator_decay': 4.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0037500000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9489711934156378
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 128, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00495, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.9431275720164609
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00205, 'embedding_dim': 32, 'generator_decay': 3.9e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0015, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# 0.7874897119341564
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0027, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# 100%|██████████| 50/50 [53:12<00:00, 63.85s/trial, best loss: 0.7297942386831275]
# Лучший C2ST для my_regression: 0.7297942386831275
# Лучшие параметры: {'discriminator_lr': np.float64(0.001), 'generator_lr': np.float64(0.0008), 'batch_size': 100, 'embedding_dim': 128, 'generator_dim': [128, 128, 128, 128], 'discriminator_dim': [256, 256, 256], 'generator_decay': np.float64(1.1e-06), 'discriminator_decay': np.float64(6e-06), 'log_frequency': False, 'epochs': inf}
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_c2st'])
# Out:
# my_classification 0.6567901234567901
# my_regression 0.7297942386831275
