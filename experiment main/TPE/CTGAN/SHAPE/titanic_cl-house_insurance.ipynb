# %%
# !pip install sdv
# !pip install sdmetrics
# Out:
# Requirement already satisfied: sdv in /usr/local/lib/python3.11/dist-packages (1.22.1)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.38.11)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.26.4)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (2.2.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.12.3)
# Requirement already satisfied: ctgan>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (1.17.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (0.21.0)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.11/dist-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.4.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from copulas>=0.12.1->sdv) (1.15.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ctgan>=0.11.0->sdv) (2.6.0+cu124)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdv) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (1.2.2)
# Requirement already satisfied: Faker>=17 in /usr/local/lib/python3.11/dist-packages (from rdt>=1.17.0->sdv) (37.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ctgan>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdv) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.0->sdv) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24.0->sdv) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ctgan>=0.11.0->sdv) (3.0.2)
# Requirement already satisfied: sdmetrics in /usr/local/lib/python3.11/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (1.26.4)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (1.2.2)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (1.15.2)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (0.12.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (4.67.1)
# Requirement already satisfied: plotly>=5.19.0 in /usr/local/lib/python3.11/dist-packages (from sdmetrics) (5.24.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdmetrics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdmetrics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdmetrics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdmetrics) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdmetrics) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.0->sdmetrics) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdmetrics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdmetrics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.0->sdmetrics) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.19.0->sdmetrics) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.19.0->sdmetrics) (25.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->sdmetrics) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.3->sdmetrics) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->sdmetrics) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdmetrics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.0->sdmetrics) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.0->sdmetrics) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24.0->sdmetrics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24.0->sdmetrics) (2024.2.0)

# %%
# !unrar x data.rar

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from hyperopt import space_eval
from sdv.single_table import CTGANSynthesizer as CTGAN
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
from sklearn.metrics import f1_score, r2_score
from xgboost import XGBClassifier, XGBRegressor
from sdmetrics.reports.single_table import QualityReport
import pandas as pd

# %%
dir_datasets = '/kaggle/input/nir02-main/data/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_2 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_regression.csv')
real_data_4 = pd.read_csv(dir_datasets+'two_moons.csv')
real_data_5 = pd.read_csv(dir_datasets+'california_housing.csv')
real_data_6 = pd.read_csv(dir_datasets+'titanic.csv')

# Словарь датасетов для удобства
datasets = {
        'titanic': {
                        "data": real_data_6,
                        "task": "classification",
                        "target": "Survived",
                        "num_columns": ["Age", "Fare", "SibSp", "Parch"],
                        "cat_columns": ["Pclass", "Sex", "Embarked"]
                    },
        'california_housing': {
                        "data": real_data_5,
                        "task": "regression",
                        "target": "MedHouseVal",
                        "num_columns":
                        ["MedInc",	"HouseAge",	"AveRooms",	"AveBedrms",	"Population",	"AveOccup",	"Latitude",	"Longitude"],
                        "cat_columns":
                        []
                    },
        'insurance': {
                        "data": real_data_1,
                        "task": "regression",
                        "target": "expenses",
                        "num_columns":
                        ["age", "bmi", "children"],
                        "cat_columns":
                        ["sex", "smoker", "region"]
                    }

}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете titanic:
#  Количество строк: 712
#  Количество колонок: 12
#  Колонки: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#  Задача: classification
#  Целевая переменная: Survived
#  Числовые признаки: ['Age', 'Fare', 'SibSp', 'Parch']
#  Категориальные признаки: ['Pclass', 'Sex', 'Embarked']
#
#  Информация о датасете california_housing:
#  Количество строк: 1200
#  Количество колонок: 9
#  Колонки: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude', 'MedHouseVal']
#  Задача: regression
#  Целевая переменная: MedHouseVal
#  Числовые признаки: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
#  Категориальные признаки: []
#
#  Информация о датасете insurance:
#  Количество строк: 1338
#  Количество колонок: 7
#  Колонки: ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']
#  Задача: regression
#  Целевая переменная: expenses
#  Числовые признаки: ['age', 'bmi', 'children']
#  Категориальные признаки: ['sex', 'smoker', 'region']

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
ctgan_space = {
    # Learning rates
    'discriminator_lr': hp.qloguniform('discriminator_lr',
                                                 np.log(4e-4), np.log(2.1e-3), 5e-5),
    'generator_lr': hp.qloguniform('generator_lr',
                                             np.log(5e-5), np.log(5e-3), 5e-5),

    # Batch size
    'batch_size': hp.choice('batch_size', [100, 500, 1000]),

    # Embedding dimensions
    'embedding_dim': hp.choice('embedding_dim', [32, 128]),

    # Network architecture
    'generator_dim': hp.choice('generator_dim', [[128, 128, 128], [128, 128, 128, 128]]),
    'discriminator_dim': hp.choice('discriminator_dim', [[256, 256], [256, 256, 256]]),

    # Decay parameters
    'generator_decay': hp.qloguniform('generator_decay',
                                     np.log(1e-6), np.log(6.4e-6), 1e-7),
    'discriminator_decay': hp.qloguniform('discriminator_decay',
                                         np.log(1e-6), np.log(8e-6), 1e-6),

    # Frequency
    'log_frequency': hp.choice('log_frequency', [False, True]),
    'transformation_num_type': hp.choice('transformation_num_type', ['CDF', 'PLE_CDF']),
    'transformation_cat_type': hp.choice('transformation_cat_type', ['OHE'])

}

# %%
def evaluate_shape(real_data, synthetic_data, cat_columns):
    """
    Прямое использование метрик SDMetrics без QualityReport.
    Для случаев, когда QualityReport не работает.
    """
    # Обработка входных данных
    if hasattr(synthetic_data, "dataframe"):
        synthetic = synthetic_data.dataframe()
    else:
        synthetic = synthetic_data.copy()

    real_data = pd.get_dummies(real_data, columns=cat_columns, drop_first=True)
    synthetic = pd.get_dummies(synthetic, columns=cat_columns, drop_first=True)

    # После get_dummies
    real_data = real_data.astype(float)
    synthetic = synthetic.astype(float)

    # Пытаемся использовать прямые метрики
    shape_scores = []

    from sdmetrics.single_column import KSComplement

    with warnings.catch_warnings():
        warnings.simplefilter('ignore', RuntimeWarning)
        for column in real_data.select_dtypes(include=['number']).columns:
            if column in synthetic.columns:
                ks_score = KSComplement.compute(
                    real_data=real_data[column],
                    synthetic_data=synthetic[column]
                )
                shape_scores.append(ks_score)

    return sum(shape_scores) / len(shape_scores) if shape_scores else 0.0

# %%
import sys
import os
import builtins
import contextlib

@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        old_print = builtins.print
        builtins.print = lambda *args, **kwargs: None
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr
            builtins.print = old_print

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_shape_scores(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    columns_dataset = dataset_info['num_columns'] + dataset_info['cat_columns'] + [dataset_info['target']]
    data = process_data(dataset_info['data'][columns_dataset], dataset_info['num_columns'], dataset_info['cat_columns'],
                        'None', 'None')

    kf = KFold(n_splits=n_splits, shuffle=False)
    shape_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение CTGAN с заданными параметрами
        ctgan = CTGAN(
            metadata=metadata,
            discriminator_lr=params['discriminator_lr'],
            generator_lr=params['generator_lr'],
            batch_size=params['batch_size'],
            embedding_dim=params['embedding_dim'],
            generator_dim=params['generator_dim'],
            generator_decay=params['generator_decay'],
            discriminator_decay=params['discriminator_decay'],
            log_frequency=params['log_frequency'],
        )

        ctgan.fit(train_data)

        synthetic_data = ctgan.sample(len(test_data))

        cat_columns = dataset_info['cat_columns'].copy()
        if dataset_info["task"] == 'classification':
            cat_columns.append(dataset_info['target'])

        score = evaluate_shape(
            test_data,
            synthetic_data,
            cat_columns)

        shape_scores.append(score)

    return np.mean(shape_scores)

# %%
def optimize_dataset(dataset_name, dataset_info, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        shape_score = generate_and_evaluate_shape_scores(params, dataset_info)

        print(f"Shape-score: {shape_score}")
        print(params)
        print("="*50)

        # Для Shape-score мы хотим максимизировать метрику, поэтому возвращаем отрицательное значение
        return {
            'loss': -shape_score,  # отрицательное для максимизации
            'status': STATUS_OK,
            'shape_score': shape_score
        }

    # Запускаем оптимизацию с помощью Rand алгоритма
    rng = np.random.default_rng(RANDOM_SEED)  # Используем фиксированный seed
    best = fmin(
        fn=objective,
        space=ctgan_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Автоматическое декодирование параметров
    best_params = space_eval(ctgan_space, best)

    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_shape_score = best_trial['result'].get('shape_score', None)

    results = {
        'best_params': best_params,
        'best_shape_score': best_shape_score,
        'shape_score_diff_from_optimal': -best_trial['result']['loss']  # убираем минус для читаемости
    }

    print(f"Лучший Shape-score для {dataset_name}: {best_shape_score}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 50

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: titanic
# ==================================================
# Shape-score: 0.8786222505879989
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8734655887671524
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.922196811213937
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8737214717110472
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9082928530061812
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8988860523112199
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8530440024110911
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00495, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7998764906806605
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0023, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8006004089399473
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8417567871030268
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9327081043387819
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 32, 'generator_decay': 5.899999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8077279012870973
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'generator_decay': 1.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8302290536467751
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0014500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8759470032738834
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8579140516966279
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0032500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.846756255244714
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00475, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8024914607193088
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.91954874776915
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8357586072403645
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8124041177652496
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9266644210426787
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8853555768298881
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00205, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8755368814192344
# {'batch_size': 1000, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 4.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9222050845654718
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 2.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9152028743987047
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.940740937725301
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8646290583744047
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0019, 'embedding_dim': 32, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9214912125187628
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 32, 'generator_decay': 5.899999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8878021250694372
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015, 'embedding_dim': 32, 'generator_decay': 4.2999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.923740382228841
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.002, 'embedding_dim': 32, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.928107529931804
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 32, 'generator_decay': 2.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8877690316632982
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 5.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9273777021357065
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'generator_decay': 4.2999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9057635712512854
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 32, 'generator_decay': 2.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8226542093630703
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 32, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9098263778085073
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 32, 'generator_decay': 3.9e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9252715432164428
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 32, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9010838090510466
# {'batch_size': 1000, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0019, 'embedding_dim': 32, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8318329019371461
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 32, 'generator_decay': 2.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8945348603576452
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 32, 'generator_decay': 5.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8856664184661206
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00185, 'embedding_dim': 32, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9305983996974317
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 32, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8992955832121877
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 32, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9313122717441408
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8388888888888889
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0016, 'embedding_dim': 32, 'generator_decay': 4.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8846003380255056
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00075, 'embedding_dim': 32, 'generator_decay': 2.7e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8265935066009527
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 6.3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9110933825006797
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 128, 'generator_decay': 2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9070264392676902
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 32, 'generator_decay': 1.6999999999999998e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.899158481958184
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 32, 'generator_decay': 3.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0038, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# 100%|██████████| 50/50 [34:29<00:00, 41.39s/trial, best loss: -0.940740937725301]
# Лучший Shape-score для titanic: 0.940740937725301
# Лучшие параметры: {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# --------------------------------------------------
# Оптимизация для датасета: california_housing
# ==================================================
# Shape-score: 0.7380555555555555
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7228703703703704
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7286111111111112
# {'batch_size': 1000, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 1.2999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.6924999999999999
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00045000000000000004, 'embedding_dim': 128, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7066666666666667
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.6925925925925925
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 3.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.6642592592592592
# {'batch_size': 1000, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 32, 'generator_decay': 4.9999999999999996e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00495, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.535
# {'batch_size': 1000, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 128, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0023, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.5899999999999999
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00175, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.6124999999999999
# {'batch_size': 1000, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 32, 'generator_decay': 3.6999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7264814814814815
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0019500000000000001, 'embedding_dim': 32, 'generator_decay': 5.899999999999999e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.6343518518518518
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 32, 'generator_decay': 1.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.581111111111111
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0014500000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7034259259259259
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00045000000000000004, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.735
# {'batch_size': 100, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0032500000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7124074074074075
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 1.9e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00475, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.546574074074074
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006500000000000001, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0021000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.6896296296296297
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0005, 'embedding_dim': 32, 'generator_decay': 6.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.4966666666666666
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0007, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0025, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.5831481481481481
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0006000000000000001, 'embedding_dim': 128, 'generator_decay': 1.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00135, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7350925925925926
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7282407407407407
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 2.8999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7278703703703705
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0012000000000000001, 'embedding_dim': 128, 'generator_decay': 2.7e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0008500000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7347222222222222
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 128, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7324074074074073
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00025, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7248148148148147
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0011, 'embedding_dim': 128, 'generator_decay': 4.5e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7269444444444444
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 128, 'generator_decay': 3.2e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7103703703703704
# {'batch_size': 100, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 2.3e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0010500000000000002, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7257407407407408
# {'batch_size': 100, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'generator_decay': 2.4999999999999998e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7039814814814814
# {'batch_size': 100, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.7101851851851851
# {'batch_size': 100, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 128, 'generator_decay': 1.1e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# ...
# ==================================================
# ==================================================
# Shape-score: 0.9577312738747716
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9426175053977744
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00185, 'embedding_dim': 32, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8949510048164758
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 6.3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9265072247135028
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0018000000000000002, 'embedding_dim': 32, 'generator_decay': 5.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8969440292310248
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015, 'embedding_dim': 128, 'generator_decay': 3e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9375519016774622
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0008500000000000001, 'embedding_dim': 32, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9216077063610696
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00135, 'embedding_dim': 128, 'generator_decay': 4.2999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9108121574489288
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.002, 'embedding_dim': 128, 'generator_decay': 5.5e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9393788407241321
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 6.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9266733100813819
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.827769473509384
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0010500000000000002, 'embedding_dim': 128, 'generator_decay': 3.2999999999999997e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0008, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8736920777279522
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 32, 'generator_decay': 3.9e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00030000000000000003, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9450257432320212
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0009000000000000001, 'embedding_dim': 128, 'generator_decay': 5.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9012622487958811
# {'batch_size': 500, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0019, 'embedding_dim': 32, 'generator_decay': 4.8e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00015000000000000001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9071582793555888
# {'batch_size': 100, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00165, 'embedding_dim': 32, 'generator_decay': 4.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0006000000000000001, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9195316392625811
# {'batch_size': 500, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014500000000000001, 'embedding_dim': 128, 'generator_decay': 3.3999999999999996e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.898189669490118
# {'batch_size': 500, 'discriminator_decay': 2e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.001, 'embedding_dim': 32, 'generator_decay': 2.4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9392127553562531
# {'batch_size': 500, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0015500000000000002, 'embedding_dim': 128, 'generator_decay': 3.1e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.925925925925926
# {'batch_size': 100, 'discriminator_decay': 6e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0008, 'embedding_dim': 32, 'generator_decay': 2.7e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9451087859159607
# {'batch_size': 500, 'discriminator_decay': 8e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0021000000000000003, 'embedding_dim': 32, 'generator_decay': 3.6e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8409732602557716
# {'batch_size': 1000, 'discriminator_decay': 3e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00115, 'embedding_dim': 128, 'generator_decay': 5.0999999999999995e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.00055, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.8565022421524664
# {'batch_size': 500, 'discriminator_decay': 4.9999999999999996e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0004, 'embedding_dim': 32, 'generator_decay': 5.7999999999999995e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.00035, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9049161268892211
# {'batch_size': 100, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0017000000000000001, 'embedding_dim': 128, 'generator_decay': 4.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0011, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9070752366716492
# {'batch_size': 500, 'discriminator_decay': 1e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.0014, 'embedding_dim': 32, 'generator_decay': 4e-06, 'generator_dim': (128, 128, 128), 'generator_lr': 0.0002, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.9081547915628634
# {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256, 256), 'discriminator_lr': 0.00125, 'embedding_dim': 32, 'generator_decay': 2.2e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0001, 'log_frequency': True, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# ==================================================
# ==================================================
# Shape-score: 0.812240491612689
# {'batch_size': 1000, 'discriminator_decay': 4e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.00095, 'embedding_dim': 128, 'generator_decay': 3.6e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 0.0038, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'PLE_CDF'}
# ==================================================
# 100%|██████████| 50/50 [46:55<00:00, 56.31s/trial, best loss: -0.9577312738747716]
# Лучший Shape-score для insurance: 0.9577312738747716
# Лучшие параметры: {'batch_size': 500, 'discriminator_decay': 7e-06, 'discriminator_dim': (256, 256), 'discriminator_lr': 0.0013000000000000002, 'embedding_dim': 128, 'generator_decay': 4.4e-06, 'generator_dim': (128, 128, 128, 128), 'generator_lr': 5e-05, 'log_frequency': False, 'transformation_cat_type': 'OHE', 'transformation_num_type': 'CDF'}
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_shape_score'])
# Out:
# titanic 0.940740937725301
# california_housing 0.7412962962962965
# insurance 0.9577312738747716
