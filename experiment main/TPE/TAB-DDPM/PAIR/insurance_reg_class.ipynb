# %%
# !pip install synthcity
# !pip install opacus==1.4.0

# %%
# !unrar x data.rar

# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from synthcity.plugins import Plugins
from synthcity.plugins.generic.plugin_ddpm import TabDDPMPlugin as DDPM
#from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
from sklearn.metrics import f1_score, r2_score
from xgboost import XGBClassifier, XGBRegressor

# %%
dir_datasets = 'data/original/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'abalone.csv')
#real_data_1['Rings'] = (real_data_1['Rings'] > 10).astype(int)
real_data_2 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_4 = pd.read_csv(dir_datasets+'my_regression.csv')

# Словарь датасетов для удобства
datasets = {
    # 'abolone': {
    #             "data": real_data_1,
    #             "task": "classification",
    #             "target": "Rings",
    #             "num_columns":
    #             ["Length", "Diameter", "Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight"]
    #             },
    'insurance': {
                    "data": real_data_2,
                    "task": "regression",
                    "target": "expenses",
                    "num_columns":
                    ["age", "bmi", "children"],
                    "cat_columns":
                    ["sex", "smoker", "region"]
                },
    'my_classification': {
                    "data": real_data_3,
                    "task": "classification",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3", "feature_4"],
                    "cat_columns":
                    []
                },
    'my_regression': {
                    "data": real_data_4,
                    "task": "regression",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3"],
                    "cat_columns":
                    []
                },
}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print(f" Категориальные признаки: {data['cat_columns']}")
    print()
# Out:
#  Информация о датасете insurance:
#  Количество строк: 1338
#  Количество колонок: 7
#  Колонки: ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']
#  Задача: regression
#  Целевая переменная: expenses
#  Числовые признаки: ['age', 'bmi', 'children']
#  Категориальные признаки: ['sex', 'smoker', 'region']
#
#  Информация о датасете my_classification:
#  Количество строк: 900
#  Количество колонок: 6
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'target']
#  Задача: classification
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4']
#  Категориальные признаки: []
#
#  Информация о датасете my_regression:
#  Количество строк: 900
#  Количество колонок: 5
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'target']
#  Задача: regression
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3']
#  Категориальные признаки: []

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, cat_columns, transformation_num_type='None', transformation_cat_type='None'):

    df_processed = dataset.copy()

    # Обработка числовых признаков
    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))

    # Обработка категориальных признаков
    if transformation_cat_type == 'OHE':
        # One Hot Encoding для категориальных признаков
        for col in cat_columns:
            # Создаем dummy переменные с префиксом имени колонки
            dummy_df = pd.get_dummies(df_processed[col], prefix=col, dtype=int)

            # Удаляем исходную категориальную колонку
            df_processed = df_processed.drop(columns=[col])

            # Добавляем новые dummy колонки
            df_processed = pd.concat([df_processed, dummy_df], axis=1)

    return df_processed

# %%
# Определение пространства поиска гиперпараметров для DDPM
ddpm_space = {
    'batch_size': hp.choice('batch_size', [4096]),
    'lr': hp.qloguniform('lr', np.log(3.5e-4), np.log(9.2e-4), 1e-5),
    'num_timesteps': hp.choice('num_timesteps', [1000]),
    'n_layers_hidden': hp.choice('n_layers_hidden', [2, 4, 6]),
    'n_units_hidden': hp.choice('n_units_hidden', [256, 512, 1024]),
    'transformation_num_type': hp.choice('transformation_num_type', ['None'])
}

# %%
def evaluate_pair(real_data, synthetic_data, cat_columns):
    # One-hot энкодинг для категориальных признаков
    real_data_encoded = pd.get_dummies(real_data, columns=cat_columns, drop_first=True)

    if hasattr(synthetic_data, "dataframe"):
        synthetic = synthetic_data.dataframe()
    else:
        synthetic = synthetic_data

    synthetic_encoded = pd.get_dummies(synthetic, columns=cat_columns, drop_first=True)

    # После get_dummies
    real_data_encoded = real_data_encoded.astype(float)
    synthetic_encoded = synthetic_encoded.astype(float)

    # Корреляции
    corr_real = real_data_encoded.corr()
    corr_synth = synthetic_encoded.corr()

    # Абсолютное отклонение корреляций
    pairwise_diff = np.abs(corr_real - corr_synth)

    # Усреднённое отклонение
    mean_diff = pairwise_diff.mean().mean()

    # Проверяем на NaN
    if np.isnan(mean_diff):
        print("Warning: mean_diff is NaN, returning 0")
        return 0.0

    return 1 - mean_diff  # ближе к 1 — лучше

# %%
import sys
import os
import builtins
import contextlib

@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        old_print = builtins.print
        builtins.print = lambda *args, **kwargs: None
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr
            builtins.print = old_print

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate_pair_scores(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    data = process_data(dataset_info['data'], dataset_info['num_columns'], params['transformation_num_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    pair_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        # Создание и обучение DDPM с заданными параметрами
        ddpm = DDPM(
            lr=params['lr'],
            num_timesteps=params['num_timesteps'],
            model_params = dict(n_layers_hidden=params['n_layers_hidden'],
                                n_units_hidden=params['n_units_hidden'],
                                dropout=0.0),
            batch_size=params['batch_size']
        )

        # Обучение модели на реальных данных
        with suppress_all_output():
            ddpm.fit(train_data)

        # Генерация синтетических данных
        synthetic_data = ddpm.generate(len(train_data))

        # Вычисляем Pair-score
        score = evaluate_pair(
            test_data,
            synthetic_data,
            dataset_info["cat_columns"]
        )
        pair_scores.append(score)

    return np.mean(pair_scores)

# %%
def optimize_dataset(dataset_name, dataset_info, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        pair_score = generate_and_evaluate_pair_scores(params, dataset_info)

        print(f"Pair-score: {pair_score}")
        print(params)
        print("="*50)

        # Для ML-Efficacy мы хотим максимизировать метрику, поэтому возвращаем отрицательное значение
        return {
            'loss': -pair_score,  # отрицательное для максимизации
            'status': STATUS_OK,
            'pair_score': pair_score
        }

    # Запускаем оптимизацию с помощью TPE алгоритма
    rng = np.random.default_rng(42)  # Используем фиксированный seed
    best = fmin(
        fn=objective,
        space=ddpm_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Получаем лучшие параметры в читаемом виде
    best_params = {
        'batch_size': 4096,
        'num_timesteps': 1000,
        'lr': best['lr'],
        'dropout': 0.0,
        'transformation_num_type': ['None'][best['transformation_num_type']],
        'n_layers_hidden': [2, 4, 6][best['n_layers_hidden']],
        'n_units_hidden': [256, 512, 1024][best['n_units_hidden']],
    }

    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_pair_score = best_trial['result'].get('pair_score', None)

    results = {
        'best_params': best_params,
        'best_pair_score': best_pair_score,
        'pair_score_diff_from_optimal': -best_trial['result']['loss']  # убираем минус для читаемости
    }

    print(f"Лучший Pair-score для {dataset_name}: {best_pair_score}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 50

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: insurance
# ==================================================
# Pair-score: 0.9171196037659474
# {'batch_size': 4096, 'lr': 0.00064, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7952790666835448
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7706966429524913
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8843502200230943
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.890489286476244
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8741097513856136
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8359303496076954
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8307468683932783
# {'batch_size': 4096, 'lr': 0.0007800000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9136903703109853
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8185276138744215
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.785592534540129
# {'batch_size': 4096, 'lr': 0.00036, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.846284413338604
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8554580529254397
# {'batch_size': 4096, 'lr': 0.00071, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.804007544834465
# {'batch_size': 4096, 'lr': 0.00055, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8387875839933628
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9370093091159947
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8800249768702795
# {'batch_size': 4096, 'lr': 0.0007700000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7882014814811402
# {'batch_size': 4096, 'lr': 0.00039000000000000005, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8068959298454543
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9381991175455119
# {'batch_size': 4096, 'lr': 0.0007000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8925580774196997
# {'batch_size': 4096, 'lr': 0.00048000000000000007, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9399561886875775
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9402441096821107
# {'batch_size': 4096, 'lr': 0.00068, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9210042472097649
# {'batch_size': 4096, 'lr': 0.0005, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9357209604737813
# {'batch_size': 4096, 'lr': 0.0008500000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9263527887330772
# {'batch_size': 4096, 'lr': 0.0006600000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9369171974490683
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9401313708570692
# {'batch_size': 4096, 'lr': 0.0008600000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9381181820965042
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9402441096821107
# {'batch_size': 4096, 'lr': 0.00068, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9411470889618799
# {'batch_size': 4096, 'lr': 0.00067, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9213474077737773
# {'batch_size': 4096, 'lr': 0.0006000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9205970346981593
# {'batch_size': 4096, 'lr': 0.0005300000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8824095187645288
# {'batch_size': 4096, 'lr': 0.00048000000000000007, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.936167862233451
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8801182562796672
# {'batch_size': 4096, 'lr': 0.00044, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9309140478814809
# {'batch_size': 4096, 'lr': 0.0007300000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9213474077737773
# {'batch_size': 4096, 'lr': 0.0006000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9290099615253817
# {'batch_size': 4096, 'lr': 0.0006600000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9227958478517829
# {'batch_size': 4096, 'lr': 0.00054, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8916458177150169
# {'batch_size': 4096, 'lr': 0.00076, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8238207416573721
# {'batch_size': 4096, 'lr': 0.00058, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.936167862233451
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8991962791678363
# {'batch_size': 4096, 'lr': 0.00051, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9032801793207437
# {'batch_size': 4096, 'lr': 0.00045000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8241637127332734
# {'batch_size': 4096, 'lr': 0.00068, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9325791640230285
# {'batch_size': 4096, 'lr': 0.00072, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9017953861438771
# {'batch_size': 4096, 'lr': 0.0008100000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8281921401024069
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9344557509529273
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# 100%|██████████| 50/50 [2:05:47<00:00, 150.96s/trial, best loss: -0.9411470889618799]
# Лучший Pair-score для insurance: 0.9411470889618799
# Лучшие параметры: {'batch_size': 4096, 'num_timesteps': 1000, 'lr': 0.00067, 'dropout': 0.0, 'transformation_num_type': 'None', 'n_layers_hidden': 4, 'n_units_hidden': 256}
# --------------------------------------------------
# Оптимизация для датасета: my_classification
# ==================================================
# Pair-score: 0.8924955863390097
# {'batch_size': 4096, 'lr': 0.00064, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8524401775041198
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8948601570594219
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9048457656499519
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8873854654084181
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.842714745302986
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7656479768742447
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8583167499063142
# {'batch_size': 4096, 'lr': 0.0007800000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9099475989314484
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8196846647526409
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8961186880010859
# {'batch_size': 4096, 'lr': 0.00036, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7210923515548933
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8885745117609053
# {'batch_size': 4096, 'lr': 0.00071, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8429185344842489
# {'batch_size': 4096, 'lr': 0.00055, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8824422034683126
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8834091602024596
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7841100780319762
# {'batch_size': 4096, 'lr': 0.0007700000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8857098882481066
# {'batch_size': 4096, 'lr': 0.00039000000000000005, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8470171739517415
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8985888735662505
# {'batch_size': 4096, 'lr': 0.0007000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8900294313565204
# {'batch_size': 4096, 'lr': 0.00046, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9038767675272066
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8780139455087924
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8741747770038625
# {'batch_size': 4096, 'lr': 0.0005, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.864098354545265
# {'batch_size': 4096, 'lr': 0.00051, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.904500627029388
# {'batch_size': 4096, 'lr': 0.00045000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8794171973922045
# {'batch_size': 4096, 'lr': 0.0006900000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8897370707414529
# {'batch_size': 4096, 'lr': 0.0006000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8823957702264056
# {'batch_size': 4096, 'lr': 0.00035000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8779573935896998
# {'batch_size': 4096, 'lr': 0.00067, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9034402092088639
# {'batch_size': 4096, 'lr': 0.00058, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9015971631539591
# {'batch_size': 4096, 'lr': 0.0008500000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8728264905243733
# {'batch_size': 4096, 'lr': 0.0005300000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8609065348741899
# {'batch_size': 4096, 'lr': 0.00047000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9099475989314484
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9099475989314484
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8966113655403594
# {'batch_size': 4096, 'lr': 0.0008300000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9026393577644809
# {'batch_size': 4096, 'lr': 0.0006600000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9117271584834282
# {'batch_size': 4096, 'lr': 0.0008900000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.89261889510944
# {'batch_size': 4096, 'lr': 0.00088, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8995984739278038
# {'batch_size': 4096, 'lr': 0.0006100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8834091602024596
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8990221884290023
# {'batch_size': 4096, 'lr': 0.00076, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7594254468998497
# {'batch_size': 4096, 'lr': 0.0008100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8780430983522657
# {'batch_size': 4096, 'lr': 0.0008600000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7656479768742447
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8701750542012157
# {'batch_size': 4096, 'lr': 0.0006500000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.89261889510944
# {'batch_size': 4096, 'lr': 0.00088, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.7732698035993116
# {'batch_size': 4096, 'lr': 0.00079, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.8738844436045587
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# 100%|██████████| 50/50 [1:22:01<00:00, 98.42s/trial, best loss: -0.9117271584834282]
# Лучший Pair-score для my_classification: 0.9117271584834282
# Лучшие параметры: {'batch_size': 4096, 'num_timesteps': 1000, 'lr': 0.0008900000000000001, 'dropout': 0.0, 'transformation_num_type': 'None', 'n_layers_hidden': 6, 'n_units_hidden': 256}
# --------------------------------------------------
# Оптимизация для датасета: my_regression
# ==================================================
# Pair-score: 0.9240568197824164
# {'batch_size': 4096, 'lr': 0.00064, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9482316650728014
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9450840573641228
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9476067216877994
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9464337511040505
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9458418558458656
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9432638851411808
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9567213361029786
# {'batch_size': 4096, 'lr': 0.0007800000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9375429547083275
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9455075338905902
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9383650942229336
# {'batch_size': 4096, 'lr': 0.00036, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9424985178724089
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.950293485277116
# {'batch_size': 4096, 'lr': 0.00071, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9468270291195471
# {'batch_size': 4096, 'lr': 0.00055, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9486802827287013
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9344090233672476
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9303865325321681
# {'batch_size': 4096, 'lr': 0.0007700000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.943617561601862
# {'batch_size': 4096, 'lr': 0.00039000000000000005, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.943097789699813
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9431376969654837
# {'batch_size': 4096, 'lr': 0.0007000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.938655661859714
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9483048055866318
# {'batch_size': 4096, 'lr': 0.0006900000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9445108651898974
# {'batch_size': 4096, 'lr': 0.0008200000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9399475391805945
# {'batch_size': 4096, 'lr': 0.0008700000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.950293485277116
# {'batch_size': 4096, 'lr': 0.00071, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.938655661859714
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9420018250952124
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9467180180246545
# {'batch_size': 4096, 'lr': 0.00075, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9496838793911865
# {'batch_size': 4096, 'lr': 0.00067, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9420018250952124
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9535539361490774
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# Pair-score: 0.9463055372678323
# {'batch_size': 4096, 'lr': 0.00051, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
#  64%|██████▍   | 32/50 [22:53<11:42, 39.02s/trial, best loss: -0.9567213361029786]

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_pair_score'])

# %% [markdown]
# insurance 0.9411470889618799<br>
# my_classification 0.9117271584834282<br>
# my_regression 0.9567213361029786<br>
