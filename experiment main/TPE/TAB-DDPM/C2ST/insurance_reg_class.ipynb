# %%
import pandas as pd
import numpy as np
import torch
import random
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from synthcity.plugins import Plugins
from synthcity.plugins.generic.plugin_ddpm import TabDDPMPlugin as DDPM
from sdv.metadata import SingleTableMetadata
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import tqdm
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748447909.850657      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748447909.914710      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [KeOps] Compiling cuda jit compiler engine ... OK
# [pyKeOps] Compiling nvrtc binder for python ... OK

# %%
dir_datasets = '/kaggle/input/nir-exp-1/data/original/'

# Загрузка реальных датасетов
real_data_1 = pd.read_csv(dir_datasets+'abalone.csv')
#real_data_1['Rings'] = (real_data_1['Rings'] > 10).astype(int)
real_data_2 = pd.read_csv(dir_datasets+'insurance.csv')
real_data_3 = pd.read_csv(dir_datasets+'my_classification.csv')
real_data_4 = pd.read_csv(dir_datasets+'my_regression.csv')

# Словарь датасетов для удобства
datasets = {
    # 'abolone': {
    #             "data": real_data_1,
    #             "task": "classification",
    #             "target": "Rings",
    #             "num_columns":
    #             ["Length", "Diameter", "Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight"]
    #             },
    'insurance': {
                    "data": real_data_2,
                    "task": "regression",
                    "target": "expenses",
                    "num_columns":
                    ["age", "bmi", "children"]
                },
    'my_classification': {
                    "data": real_data_3,
                    "task": "classification",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3", "feature_4"]
                },
    'my_regression': {
                    "data": real_data_4,
                    "task": "regression",
                    "target": "target",
                    "num_columns":
                    ["feature_0", "feature_1", "feature_2", "feature_3"]
                },
}

for name, data in datasets.items():
    print(f" Информация о датасете {name}:")
    print(f" Количество строк: {data['data'].shape[0]}")
    print(f" Количество колонок: {data['data'].shape[1]}")
    print(f" Колонки: {list(data['data'].columns)}")
    print(f" Задача: {data['task']}")
    print(f" Целевая переменная: {data['target']}")
    print(f" Числовые признаки: {data['num_columns']}")
    print()
# Out:
#  Информация о датасете insurance:
#  Количество строк: 1338
#  Количество колонок: 7
#  Колонки: ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']
#  Задача: regression
#  Целевая переменная: expenses
#  Числовые признаки: ['age', 'bmi', 'children']
#
#  Информация о датасете my_classification:
#  Количество строк: 900
#  Количество колонок: 6
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'target']
#  Задача: classification
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4']
#
#  Информация о датасете my_regression:
#  Количество строк: 900
#  Количество колонок: 5
#  Колонки: ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'target']
#  Задача: regression
#  Целевая переменная: target
#  Числовые признаки: ['feature_0', 'feature_1', 'feature_2', 'feature_3']

# %%
RANDOM_SEED = 42

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)

# %%
def process_data(dataset, num_columns, transformation_num_type='None'):
    """
    Обрабатывает датасет с помощью CDF или PLE_CDF трансформации

    Parameters:
    -----------
    dataset : pd.DataFrame
        Исходный датасет
    num_columns : list
        Список числовых колонок для обработки
    transformation_type : str
        Тип трансформации: 'CDF' или 'PLE_CDF'

    Returns:
    --------
    pd.DataFrame
        Обработанный датасет
    """

    df_processed = dataset.copy()

    if transformation_num_type == 'CDF':
        # CDF трансформация: преобразует значения в их эмпирическую функцию распределения
        for col in num_columns:
            # Правильная формула для эмпирической CDF
            df_processed[col] = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

    elif transformation_num_type == 'PLE_CDF':
        # PLE_CDF (Probability Logit Envelope CDF) - более сложная трансформация
        for col in num_columns:
            # Сначала применяем CDF
            cdf_values = (df_processed[col].rank(method='average') - 0.5) / len(df_processed)

            # Затем применяем logit трансформацию с небольшим сглаживанием
            # Избегаем 0 и 1 для предотвращения бесконечности в logit
            epsilon = 1e-6
            cdf_values = np.clip(cdf_values, epsilon, 1 - epsilon)

            # Логит трансформация: ln(p/(1-p))
            df_processed[col] = np.log(cdf_values / (1 - cdf_values))


    return df_processed

# %%
# Определение пространства поиска гиперпараметров для DDPM
ddpm_space = {
    'batch_size': hp.choice('batch_size', [4096]),
    'lr': hp.qloguniform('lr', np.log(3.5e-4), np.log(9.2e-4), 1e-5),
    'num_timesteps': hp.choice('num_timesteps', [1000]),
    'n_layers_hidden': hp.choice('n_layers_hidden', [2, 4, 6]),
    'n_units_hidden': hp.choice('n_units_hidden', [256, 512, 1024]),
    'transformation_num_type': hp.choice('transformation_num_type', ['None'])
}

# %%
def evaluate_c2st(real, synthetic):
    real_copy = real.copy()
    if hasattr(synthetic, "dataframe"):
        synthetic = synthetic.dataframe()

    synthetic_copy = synthetic.copy()

    # Добавление меток
    real_copy['label'] = 1
    synthetic_copy['label'] = 0

    # Объединение данных
    df = pd.concat([real_copy, synthetic_copy], ignore_index=True)

    # Определение категориальных колонок
    categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()
    categorical_columns = [col for col in categorical_columns if col != 'label']

    # Label Encoding для категориальных признаков
    for col in categorical_columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))

    # Разделение на признаки и метки
    X = df.drop(columns='label')
    y = df['label']

    # Разделение на обучающую и тестовую выборки
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y, random_state=RANDOM_SEED
    )
    # Обучение XGBoost
    clf = XGBClassifier(
        random_state=RANDOM_SEED
    )
    clf.fit(X_train, y_train)

    # Предсказания
    y_pred_proba = clf.predict_proba(X_test)[:, 1]

    return roc_auc_score(y_test, y_pred_proba)

# %%
import sys
import os
import builtins
import contextlib

@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        old_print = builtins.print
        builtins.print = lambda *args, **kwargs: None
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr
            builtins.print = old_print

# %%
from sklearn.model_selection import KFold

def generate_and_evaluate(params, dataset_info, n_splits=3):
    warnings.filterwarnings("ignore", category=FutureWarning)
    warnings.filterwarnings("ignore", category=UserWarning)

    data = process_data(dataset_info['data'], dataset_info['num_columns'], params['transformation_num_type'])

    kf = KFold(n_splits=n_splits, shuffle=False)
    c2st_scores = []

    for train_index, test_index in kf.split(data):
        train_data = data.iloc[train_index].reset_index(drop=True)
        test_data = data.iloc[test_index].reset_index(drop=True)

        metadata = SingleTableMetadata()
        metadata.detect_from_dataframe(data=train_data)

        # Создание и обучение DDPM с заданными параметрами
        ddpm = DDPM(
            lr=params['lr'],
            num_timesteps=params['num_timesteps'],
            model_params = dict(n_layers_hidden=params['n_layers_hidden'],
                                n_units_hidden=params['n_units_hidden'],
                                dropout=0.0),
            batch_size=params['batch_size']
        )

        # Обучение модели на реальных данных
        with suppress_all_output():
          ddpm.fit(train_data)

        # Генерация синтетических данных
        synthetic_data = ddpm.generate(len(test_data))


        score = evaluate_c2st(test_data, synthetic_data)
        c2st_scores.append(score)

    return np.mean(c2st_scores)

# %%
def optimize_dataset(dataset_name, dataset, max_evals=30):
    print(f"Оптимизация для датасета: {dataset_name}")

    # Создаем объект для хранения истории поиска
    trials = Trials()

    # Определяем целевую функцию для оптимизации
    def objective(params):
        print("="*50)
        c2st_score = generate_and_evaluate(params, dataset)

        print(c2st_score)
        print(params)
        print("="*50)
        # Возвращаем словарь в формате, который ожидает hyperopt
        return {
            'loss': c2st_score,
            'status': STATUS_OK,
            'c2st_score': c2st_score
        }


    # Запускаем оптимизацию с помощью TPE алгоритма
    rng = np.random.default_rng(RANDOM_SEED)
    best = fmin(
        fn=objective,
        space=ddpm_space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials,
        rstate=rng
    )

    # Получаем лучшие параметры в читаемом виде
    best_params = {
        'batch_size': 4096,
        'num_timesteps': 1000,
        'lr': [best['lr']],
        'dropout': 0.0,
        'transformation_num_type': ['None'][best['transformation_num_type']],
        'n_layers_hidden': [2, 4, 6][best['n_layers_hidden']],
        'n_units_hidden': [256, 512, 1024][best['n_units_hidden']],
    }

    # Находим лучший результат
    best_trial = min(trials.trials, key=lambda x: x['result']['loss'])
    best_c2st = best_trial['result'].get('c2st_score', None)

    results = {
        'best_params': best_params,
        'best_c2st': best_c2st,
        'c2st_diff_from_optimal': best_trial['result']['loss']
    }

    print(f"Лучший C2ST для {dataset_name}: {best_c2st}")
    print(f"Лучшие параметры: {best_params}")
    print('-' * 50)

    return results

# %%
# Словарь для хранения результатов
all_results = {}

# Указываем количество итераций для каждого датасета
max_evals = 50

# Запускаем оптимизацию для каждого датасета
for dataset_name in datasets:
    data = datasets[dataset_name]
    all_results[dataset_name] = optimize_dataset(dataset_name, data, max_evals)
# Out:
# Оптимизация для датасета: insurance
# ==================================================
# 0.776527808717606
# {'batch_size': 4096, 'lr': 0.00064, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9860028217123339
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9842392515036756
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8476832256627311
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8814138263904359
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8895448132471969
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 1.0
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9610993539763867
# {'batch_size': 4096, 'lr': 0.0007800000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7132527660206431
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9896413455112497
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9909593821935102
# {'batch_size': 4096, 'lr': 0.00036, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8047449320561372
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9666778050048266
# {'batch_size': 4096, 'lr': 0.00071, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.996389322046484
# {'batch_size': 4096, 'lr': 0.00055, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9546669636890176
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.639025024133066
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9693324422662806
# {'batch_size': 4096, 'lr': 0.0007700000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9633177396599094
# {'batch_size': 4096, 'lr': 0.00039000000000000005, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9864297913417984
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7178287666146878
# {'batch_size': 4096, 'lr': 0.0007000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6535141456894632
# {'batch_size': 4096, 'lr': 0.00088, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.639025024133066
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8967290413603624
# {'batch_size': 4096, 'lr': 0.00048000000000000007, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.639025024133066
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6821768025543923
# {'batch_size': 4096, 'lr': 0.0008500000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8536979282691023
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7443101655899608
# {'batch_size': 4096, 'lr': 0.00067, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.660076483255365
# {'batch_size': 4096, 'lr': 0.0008300000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.768471077448578
# {'batch_size': 4096, 'lr': 0.0006000000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.639025024133066
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8884866711220019
# {'batch_size': 4096, 'lr': 0.00047000000000000004, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7414141976683745
# {'batch_size': 4096, 'lr': 0.0006600000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7132527660206431
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6880244300883641
# {'batch_size': 4096, 'lr': 0.00088, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7400868790376477
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8536979282691023
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7079527734462018
# {'batch_size': 4096, 'lr': 0.0008200000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6786218162916761
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9065307789411152
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6588327021608376
# {'batch_size': 4096, 'lr': 0.0007800000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8047449320561372
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6677248087918617
# {'batch_size': 4096, 'lr': 0.00088, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9193027400311872
# {'batch_size': 4096, 'lr': 0.00035000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9706690428454742
# {'batch_size': 4096, 'lr': 0.0007000000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7159445310759635
# {'batch_size': 4096, 'lr': 0.00067, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9625566198856464
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8772555134773893
# {'batch_size': 4096, 'lr': 0.00075, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9663622187569615
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6755866191430905
# {'batch_size': 4096, 'lr': 0.0008100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8884866711220019
# {'batch_size': 4096, 'lr': 0.00047000000000000004, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# 100%|██████████| 50/50 [1:44:48<00:00, 125.78s/trial, best loss: 0.639025024133066]
# Лучший C2ST для insurance: 0.639025024133066
# Лучшие параметры: {'batch_size': 4096, 'num_timesteps': 1000, 'lr': [0.0009100000000000001], 'dropout': 0.0, 'transformation_num_type': 'None', 'n_layers_hidden': 6, 'n_units_hidden': 256}
# --------------------------------------------------
# Оптимизация для датасета: my_classification
# ==================================================
# 0.7253909465020576
# {'batch_size': 4096, 'lr': 0.00064, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7323456790123456
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9137860082304528
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7148971193415639
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8859670781893003
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7472427983539095
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 1.0
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7307818930041153
# {'batch_size': 4096, 'lr': 0.0007800000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7055555555555554
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7510699588477366
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9142386831275721
# {'batch_size': 4096, 'lr': 0.00036, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9998765432098765
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7695473251028807
# {'batch_size': 4096, 'lr': 0.00071, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7629218106995884
# {'batch_size': 4096, 'lr': 0.00055, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6941563786008231
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.680164609053498
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 1.0
# {'batch_size': 4096, 'lr': 0.0007700000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.8621810699588478
# {'batch_size': 4096, 'lr': 0.00039000000000000005, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7843621399176954
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6609876543209876
# {'batch_size': 4096, 'lr': 0.0007000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7868724279835391
# {'batch_size': 4096, 'lr': 0.00048000000000000007, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6391358024691358
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7058024691358025
# {'batch_size': 4096, 'lr': 0.00068, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.624238683127572
# {'batch_size': 4096, 'lr': 0.00088, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.624238683127572
# {'batch_size': 4096, 'lr': 0.00088, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6716872427983539
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6657201646090534
# {'batch_size': 4096, 'lr': 0.0008500000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6930864197530865
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.699670781893004
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6964197530864197
# {'batch_size': 4096, 'lr': 0.0006600000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7176131687242798
# {'batch_size': 4096, 'lr': 0.0006100000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6861316872427983
# {'batch_size': 4096, 'lr': 0.0006000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7198353909465021
# {'batch_size': 4096, 'lr': 0.0005, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6397942386831276
# {'batch_size': 4096, 'lr': 0.0008600000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6790534979423869
# {'batch_size': 4096, 'lr': 0.0007300000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7138271604938272
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6623456790123456
# {'batch_size': 4096, 'lr': 0.00045000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6346502057613169
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6767078189300412
# {'batch_size': 4096, 'lr': 0.00075, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6378189300411523
# {'batch_size': 4096, 'lr': 0.0008700000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6055349794238684
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7480246913580247
# {'batch_size': 4096, 'lr': 0.00044, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7240740740740742
# {'batch_size': 4096, 'lr': 0.00035000000000000005, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.9980246913580246
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5933333333333333
# {'batch_size': 4096, 'lr': 0.00054, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7511522633744856
# {'batch_size': 4096, 'lr': 0.0005300000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.7627160493827162
# {'batch_size': 4096, 'lr': 0.00046, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6337037037037038
# {'batch_size': 4096, 'lr': 0.0005700000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.6868724279835391
# {'batch_size': 4096, 'lr': 0.0004, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5933333333333333
# {'batch_size': 4096, 'lr': 0.00054, 'n_layers_hidden': 4, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# 100%|██████████| 50/50 [1:04:05<00:00, 76.90s/trial, best loss: 0.5933333333333333]
# Лучший C2ST для my_classification: 0.5933333333333333
# Лучшие параметры: {'batch_size': 4096, 'num_timesteps': 1000, 'lr': [0.00054], 'dropout': 0.0, 'transformation_num_type': 'None', 'n_layers_hidden': 4, 'n_units_hidden': 1024}
# --------------------------------------------------
# Оптимизация для датасета: my_regression
# ==================================================
# 0.5246502057613168
# {'batch_size': 4096, 'lr': 0.00064, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5362139917695473
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5467078189300412
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5059670781893004
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5388065843621399
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5441563786008231
# {'batch_size': 4096, 'lr': 0.00041000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.578230452674897
# {'batch_size': 4096, 'lr': 0.00092, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5599588477366255
# {'batch_size': 4096, 'lr': 0.0007800000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5548559670781893
# {'batch_size': 4096, 'lr': 0.0007400000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5637448559670782
# {'batch_size': 4096, 'lr': 0.0005600000000000001, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.530329218106996
# {'batch_size': 4096, 'lr': 0.00036, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5461728395061729
# {'batch_size': 4096, 'lr': 0.00063, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5415226337448559
# {'batch_size': 4096, 'lr': 0.00071, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.539835390946502
# {'batch_size': 4096, 'lr': 0.00055, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5684362139917695
# {'batch_size': 4096, 'lr': 0.00084, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5605761316872427
# {'batch_size': 4096, 'lr': 0.0009100000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5387654320987655
# {'batch_size': 4096, 'lr': 0.0007700000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5461316872427983
# {'batch_size': 4096, 'lr': 0.00039000000000000005, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5487242798353908
# {'batch_size': 4096, 'lr': 0.0008, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5794238683127572
# {'batch_size': 4096, 'lr': 0.0007000000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5347325102880659
# {'batch_size': 4096, 'lr': 0.00046, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5681481481481482
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5388888888888889
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5404938271604938
# {'batch_size': 4096, 'lr': 0.00062, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5565432098765433
# {'batch_size': 4096, 'lr': 0.00045000000000000004, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5895061728395061
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5330864197530863
# {'batch_size': 4096, 'lr': 0.00044, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5486419753086419
# {'batch_size': 4096, 'lr': 0.00059, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5409053497942387
# {'batch_size': 4096, 'lr': 0.00067, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5348148148148147
# {'batch_size': 4096, 'lr': 0.00035000000000000005, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5135390946502058
# {'batch_size': 4096, 'lr': 0.00042, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5458024691358024
# {'batch_size': 4096, 'lr': 0.00042, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5493415637860083
# {'batch_size': 4096, 'lr': 0.0004900000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.535514403292181
# {'batch_size': 4096, 'lr': 0.0004, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5446502057613168
# {'batch_size': 4096, 'lr': 0.00036, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5459670781893003
# {'batch_size': 4096, 'lr': 0.00043000000000000004, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5350617283950617
# {'batch_size': 4096, 'lr': 0.00037000000000000005, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5496296296296296
# {'batch_size': 4096, 'lr': 0.0005300000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5434567901234568
# {'batch_size': 4096, 'lr': 0.00047000000000000004, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5313580246913581
# {'batch_size': 4096, 'lr': 0.0004, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5567901234567901
# {'batch_size': 4096, 'lr': 0.0006000000000000001, 'n_layers_hidden': 6, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5388065843621399
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5533333333333333
# {'batch_size': 4096, 'lr': 0.00042, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5895061728395061
# {'batch_size': 4096, 'lr': 0.0005200000000000001, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5352263374485596
# {'batch_size': 4096, 'lr': 0.00047000000000000004, 'n_layers_hidden': 2, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5464609053497941
# {'batch_size': 4096, 'lr': 0.00035000000000000005, 'n_layers_hidden': 6, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.52559670781893
# {'batch_size': 4096, 'lr': 0.00055, 'n_layers_hidden': 2, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5081069958847736
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 6, 'n_units_hidden': 256, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5505349794238684
# {'batch_size': 4096, 'lr': 0.00038, 'n_layers_hidden': 4, 'n_units_hidden': 512, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# ==================================================
# 0.5547736625514403
# {'batch_size': 4096, 'lr': 0.0004, 'n_layers_hidden': 2, 'n_units_hidden': 1024, 'num_timesteps': 1000, 'transformation_num_type': 'None'}
# ==================================================
# 100%|██████████| 50/50 [32:26<00:00, 38.92s/trial, best loss: 0.5059670781893004]
# Лучший C2ST для my_regression: 0.5059670781893004
# Лучшие параметры: {'batch_size': 4096, 'num_timesteps': 1000, 'lr': [0.00043000000000000004], 'dropout': 0.0, 'transformation_num_type': 'None', 'n_layers_hidden': 4, 'n_units_hidden': 512}
# --------------------------------------------------

# %%
for dataset_name in datasets:
    print(dataset_name, all_results[dataset_name]['best_c2st'])
# Out:
# insurance 0.639025024133066
# my_classification 0.5933333333333333
# my_regression 0.5059670781893004
