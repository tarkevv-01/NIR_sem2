# %% [markdown]
# <table>
#   <tr>
#     <td style="vertical-align:top">
#
# ### Личные показания — tab-ddpm
#
# |       | abalone | insurance | my_classification | my_regression |
# |-------|---------|-----------|-------------------|----------------|
# | c2st  |         |0.64           |0.59                   |0.51                |
# | ml-eff |        |0.90           |1.0                   |1.0                 |
# | pair  |         |0.94           |0.91                   |0.95(не досчитало)                |
# | shape |         |0.96           |0.92                   |0.94                |
#
# </td>
#     <td style="vertical-align:top">
#
# ### Показания из статьи — tab-ddpm
#
# |       | abalone | insurance | my_classification | my_regression |
# |-------|---------|-----------|-------------------|----------------|
# | c2st  |0.78±0.01         |0.61±0.02           |                   |                |
# | ml-eff |0.23±0.01        |0.83±0.03           |                   |                |
# | pair  |0.88        |0.89±0.02           |                   |                |
# | shape |0.95         | 0.94±0.01           |                   |                |
#
# </td>
#   </tr>
#   <tr>
#     <td style="vertical-align:top">
#
# ### Личные показания — ctgan
#
# |       | abalone | insurance | my_classification | my_regression |
# |-------|---------|-----------|-------------------|----------------|
# | c2st  |         |           |0.66                   |0.72                |
# | ml-eff |        |           |0.91                   |0.48                |
# | pair  |         |           |0.91                   |0.90                |
# | shape |         |           |0.89                   |0.89               |
#
# </td>
#     <td style="vertical-align:top">
#
# ### Показания из статьи — ctgan
#
# |       | abalone | insurance | my_classification | my_regression |
# |-------|---------|-----------|-------------------|----------------|
# | c2st  | 0.71±0.03         |0.67±0.02           |                   |                |
# | ml-eff |0.17±0.01        |0.66±0.04           |                   |                |
# | pair  | 0.86±0.04         |0.85±0.02           |                   |                |
# | shape |0.93±0.02         |0.94±0.01          |                   |                |
#
# </td>
#   </tr>
#   <tr>
#     <td style="vertical-align:top">
#
# ### Личные показания — tvae
#
# |       | abalone | insurance | my_classification | my_regression |
# |-------|---------|-----------|-------------------|----------------|
# | c2st  |         |           |                   |                |
# | ml-eff |        |           |                   |                |
# | pair  |         |           |                   |                |
# | shape |         |           |                   |                |
#
# </td>
#     <td style="vertical-align:top">
#
# ### Показания из статьи — tvae
#
# |       | abalone | insurance | my_classification | my_regression |
# |-------|---------|-----------|-------------------|----------------|
# | c2st  |         |           |                   |                |
# | ml-eff |        |           |                   |                |
# | pair  |         |           |                   |                |
# | shape |         |           |                   |                |
#
# </td>
#   </tr>
# </table>
